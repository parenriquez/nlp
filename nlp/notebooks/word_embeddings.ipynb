# %%
import pandas as pd
import joblib

from nltk import word_tokenize
import gensim
from keras.preprocessing.text import one_hot
from keras.utils import pad_sequences
from keras.layers import Embedding
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten

# %% [markdown]
# **Loading the tokens**

# %%
tweets_train_tokenized = pd.read_csv('csvs/tweets_train_tokens.csv', index_col=False)
tweets_train_tokenized_message = pd.Series(tweets_train_tokenized.message)
# Converting Panda series into Unicode datatype as required by vectorizers
tweets = tweets_train_tokenized_message.astype('U').values
tweets
# Out:
# array(['arirang simply kpop kim hyung jun cross ha yeong playback',
#        'read politico article donald trump running mate tom brady list likely choice',
#        'type bazura project google image image photo dad glenn moustache whatthe',
#        ..., 'bring dunkin iced coffee tomorrow hero',
#        'currently holiday portugal come home tomorrow poland tuesday holocaust memorial trip',
#        'ladykiller saturday aternoon'], dtype=object)

# %% [markdown]
# #### **C. Word Embeddings**
#
# Word embeddings are a type of word representation that allows words with similar meaning to have a similar representation.
#
# It is an improvement over more the traditional bag-of-word model encoding schemes where large sparse vectors were used to represent each word or to score each word within a vector to represent an entire vocabulary. These representations were sparse because the vocabularies were vast and a given word or document would be represented by a large vector comprised mostly of zero values.
#
# Key to the approach is the idea of using a **dense distributed representation** for each word.

# %%
# import image module
from IPython.display import Image

# get the image
Image(url="pictures/word-embedding-1.png", width=700, height=450)
# Out:
# <img src="pictures/word-embedding-1.png" width="700" height="450"/>

# %%
# import image module
from IPython.display import Image

# get the image
Image(url="pictures/word-embedding-2.png", width=700, height=600)
# Out:
# <img src="pictures/word-embedding-2.png" width="700" height="600"/>

# %% [markdown]
# **c.1. Creating Word embeddings using Keras**

# %%
# We tokenize each sentence to get every word
from nltk import word_tokenize
words=[word_tokenize(sentence) for sentence in tweets]
words
# Out:
# [['arirang',
#   'simply',
#   'kpop',
#   'kim',
#   'hyung',
#   'jun',
#   'cross',
#   'ha',
#   'yeong',
#   'playback'],
#  ['read',
#   'politico',
#   'article',
#   'donald',
#   'trump',
#   'running',
#   'mate',
#   'tom',
#   'brady',
#   'list',
#   'likely',
#   'choice'],
#  ['type',
#   'bazura',
#   'project',
#   'google',
#   'image',
#   'image',
#   'photo',
#   'dad',
#   'glenn',
#   'moustache',
#   'whatthe'],
#  ['fast',
#   'lerner',
#   'subpoena',
#   'tech',
#   'guy',
#   'work',
#   'hillary',
#   'private',
#   'server',
#   'plead',
#   'sound',
#   'familiar'],
#  ['sony',
#   'reward',
#   'app',
#   'like',
#   'lot',
#   'female',
#   'singer',
#   'non',
#   'retro',
#   'sale',
#   'no',
#   'info'],
#  ['watch',
#   'brooklyn',
#   'nets',
#   'new',
#   'york',
#   'knick',
#   'tonight',
#   'postpone',
#   'knick',
#   'butt',
#   'fuck',
#   'miami',
#   'tomorrow'],
#  ['guy', 'open', 'gate', 'naruto', 'save', 'ass', 'goat'],
#  ['triple',
#   'h',
#   'never',
#   'ric',
#   'flair',
#   'bitch',
#   'sunday',
#   'no',
#   'pressure',
#   'rollin',
#   'look',
#   'look',
#   'hhh',
#   'raw'],
#  ['joint',
#   'leader',
#   'amateur',
#   'paul',
#   'dunne',
#   'win',
#   'open',
#   'championship',
#   'tomorrow',
#   'padraig',
#   'harrington',
#   'jordan',
#   'spieth',
#   'market'],
#  ['glenn', 'beck', 'owner', 'box', 'redskin', 'game', 'sunday'],
#  ['guess', 'zayn', 'vma', 'tomorrow', 'bed', 'prepare', 'zayn', 'tv', 'aghh'],
#  ['rocket',
#   'today',
#   'new',
#   'team',
#   'asik',
#   'jeremy',
#   'lin',
#   'james',
#   'harden',
#   'watch',
#   'quarter',
#   'leave',
#   'party'],
#  ['watch',
#   'mission',
#   'impossible',
#   'watch',
#   'edge',
#   'tomorrow',
#   'like',
#   'tom',
#   'cruise'],
#  ['sit', 'metlife', 'annoying', 'not', 'let', 'ruin', 'amazing', 'night'],
#  ['tgif',
#   'love',
#   'day',
#   'weekend',
#   'enjoy',
#   'weekend',
#   'laborday',
#   'sun',
#   'cocktail'],
#  ['bad', 'thing', 'hulk', 'hogan'],
#  ['secret',
#   'rocket',
#   'ship',
#   'kill',
#   'sharknado',
#   'nasa',
#   'look',
#   'like',
#   'hoff',
#   'save'],
#  ['happy',
#   'capitol',
#   'cup',
#   'result',
#   'come',
#   'beat',
#   'chelsea',
#   'tomorrow',
#   'aswell',
#   'cup',
#   'mufc'],
#  ['apple',
#   'september',
#   'special',
#   'event',
#   'tonight',
#   'd',
#   'iphone',
#   'apple',
#   'live',
#   'september'],
#  ['bruce',
#   'dickinson',
#   'form',
#   'book',
#   'soul',
#   'not',
#   'enjoy',
#   'iron',
#   'maiden',
#   'album',
#   'listen',
#   'matter',
#   'life',
#   'death'],
#  ['watch',
#   'draft',
#   'day',
#   'tonight',
#   'deserve',
#   'big',
#   'thumb',
#   'know',
#   'nfl',
#   'buy',
#   'nfl',
#   'game',
#   'tomorrow'],
#  ['cuse', 'game', 'pop'],
#  ['blanchett',
#   'brilliant',
#   'carol',
#   'weinstein',
#   'cate',
#   'blanchett',
#   'carol',
#   'aird',
#   'right',
#   'rooney',
#   'mar'],
#  ['skinny',
#   'jean',
#   'tuck',
#   'cardigan',
#   'tomorrow',
#   'no',
#   'heel',
#   'week',
#   'leg',
#   'hurt',
#   'like',
#   'crazayyy'],
#  ['vote',
#   'ukip',
#   'partly',
#   'responsible',
#   'happen',
#   'calais',
#   'today',
#   'ukip',
#   'never',
#   'tolerate'],
#  ['rt',
#   'breaker',
#   'win',
#   'clinch',
#   'fourth',
#   'final',
#   'playoff',
#   'spot',
#   'play',
#   'magicjack',
#   'wednesday',
#   'florida'],
#  ['nirvana',
#   'gallon',
#   'rub',
#   'alcohol',
#   'flow',
#   'strip',
#   'utero',
#   'anniversary',
#   'edition'],
#  ['odd',
#   'sort',
#   'clearance',
#   'sale',
#   'kremlin',
#   'announce',
#   'monday',
#   'draft',
#   'horse',
#   'pony'],
#  ['fun',
#   'ben',
#   'affleck',
#   'address',
#   'msu',
#   'football',
#   'team',
#   'thursday',
#   'practice'],
#  ['iron',
#   'maiden',
#   'remember',
#   'tomorrow',
#   'tune',
#   'day',
#   'old',
#   'school',
#   'iron',
#   'maiden'],
#  ['think', 'kesha', 'mother', 'mean', 'help'],
#  ['national',
#   'woman',
#   'day',
#   'southafrica',
#   'thursday',
#   'august',
#   'promote',
#   'gender',
#   'equality',
#   'end',
#   'abuse',
#   'woman',
#   'africa',
#   'world'],
#  ['no',
#   'ridiculous',
#   'thor',
#   'movie',
#   'marvel',
#   'melinda',
#   'beat',
#   'guy',
#   'agent',
#   'shield'],
#  ['week',
#   'good',
#   'week',
#   'nba',
#   'package',
#   'free',
#   'direct',
#   'tv',
#   'nov',
#   'nba',
#   'fantastic'],
#  ['like',
#   'critical',
#   'dreamteam',
#   'info',
#   'early',
#   'morning',
#   's',
#   'm',
#   'sleep',
#   'lol',
#   'nov'],
#  ['king',
#   'bear',
#   'profound',
#   'thought',
#   'day',
#   'drunk',
#   'watch',
#   'lady',
#   'gaga',
#   'video',
#   'monday',
#   'gay'],
#  ['game',
#   'emile',
#   'heskey',
#   'bag',
#   'opener',
#   'newcastle',
#   'jet',
#   'score',
#   'want',
#   'x',
#   'g'],
#  ['maxwell',
#   'mix',
#   'catch',
#   'friday',
#   'night',
#   'chico',
#   'g',
#   'guest',
#   'cc',
#   'disco',
#   'groove',
#   'control'],
#  ['extra',
#   'ticket',
#   'kenny',
#   'chesney',
#   'jason',
#   'aldean',
#   'saturday',
#   'metlife',
#   'want',
#   'let',
#   'know'],
#  ['tomorrow',
#   'monday',
#   'look',
#   'forward',
#   'hang',
#   'old',
#   'shatec',
#   'friend',
#   'ying',
#   'manhattan',
#   'ice',
#   'skating',
#   'd'],
#  ['love',
#   'sun',
#   'weekend',
#   'lechlade',
#   'picnic',
#   'hollie',
#   'yesterday',
#   'soon',
#   'head',
#   'mum',
#   'bbq'],
#  ['yes',
#   'near',
#   'winspear',
#   'opera',
#   'house',
#   'dallas',
#   'arts',
#   'district',
#   'mon',
#   'fri',
#   'map'],
#  ['morgan',
#   'state',
#   'hampton',
#   'univ',
#   'head',
#   'head',
#   'nyulclassic',
#   'nov',
#   'yankee',
#   'stadium',
#   'love'],
#  ['tell',
#   'ted',
#   'fork',
#   'amp',
#   'screen',
#   'downtown',
#   'disney',
#   'sit',
#   'august'],
#  ['yes',
#   'ofcourse',
#   'bo',
#   'wise',
#   'pawan',
#   'ramcharan',
#   'position',
#   'chiru',
#   'fan',
#   'support'],
#  ['year',
#   'old',
#   'spot',
#   'mtv',
#   'video',
#   'music',
#   'award',
#   'sunday',
#   'night',
#   'support',
#   'pal',
#   'taylor',
#   'swift',
#   'home',
#   'video'],
#  ['imperfect',
#   'human',
#   'receive',
#   'second',
#   'multiple',
#   'chance',
#   'good',
#   'work',
#   'shawn',
#   'sicembear'],
#  ['threshold',
#   'sun',
#   'come',
#   'folsom',
#   'amp',
#   'rest',
#   'ur',
#   'weary',
#   'foot',
#   'play',
#   'fungeon',
#   'boogie',
#   'dance',
#   'floor'],
#  ['ed', 'sheeran', 'town', 'tomorrow', 'year', 'live', 'hahah'],
#  ['brock',
#   'lesnar',
#   'announce',
#   'october',
#   'wwe',
#   'live',
#   'event',
#   'new',
#   'york',
#   'city'],
#  ['share',
#   'bed',
#   'way',
#   'niall',
#   'sunday',
#   'morning',
#   'tell',
#   'pish',
#   'speak',
#   'night'],
#  ['hear',
#   'janet',
#   'jackson',
#   'soulful',
#   'new',
#   'song',
#   'unbreakable',
#   'fresh',
#   'unveil',
#   'track',
#   'list',
#   'cover',
#   'l'],
#  ['fly', 'eagle', 'wing', 'frank', 'gifford', 'rip'],
#  ['upcoming',
#   'exhibition',
#   'tell',
#   'story',
#   'christianity',
#   'islam',
#   'amp',
#   'judaism',
#   'egypt',
#   'pharaohs'],
#  ['look',
#   'statistic',
#   'yt',
#   'account',
#   'year',
#   'old',
#   'male',
#   'south',
#   'korea',
#   'landing',
#   'place',
#   'audience',
#   'list'],
#  ['liverpool',
#   'football',
#   'club',
#   'roll',
#   'red',
#   'carpet',
#   'rnli',
#   'nov',
#   'joe',
#   'longthorne',
#   'asa',
#   'murphy',
#   'ticket',
#   'send',
#   'msg',
#   'ticket'],
#  ['paul', 'dunne', 'find', 'courage', 'attack', 'tee', 'day', 'sorry', 'air'],
#  ['nsync',
#   'account',
#   'tweet',
#   'tomorrow',
#   'night',
#   'want',
#   'nsync',
#   'not',
#   'justin',
#   'jimmy'],
#  ['david',
#   'beckham',
#   'brad',
#   'pitt',
#   'pose',
#   'ultimate',
#   'wedding',
#   'snap',
#   'guy',
#   'ritchie',
#   'nuptial',
#   'guy',
#   'ritchie',
#   'big',
#   'day',
#   'dav'],
#  ['kanye', 'west', 'hollywood', 'bowl', 'sept', 'amazing', 'tbh'],
#  ['zac',
#   'brown',
#   'band',
#   'play',
#   'citi',
#   'field',
#   'big',
#   'deal',
#   'able',
#   'tell'],
#  ['dustin',
#   'johnson',
#   'contention',
#   'stop',
#   'royally',
#   'screw',
#   'thing',
#   'sunday',
#   'major'],
#  ['lol',
#   'desperate',
#   'af',
#   'dana',
#   'white',
#   'confirm',
#   'ufc',
#   'brisbane',
#   'australia',
#   'march'],
#  ['italy',
#   'pm',
#   'silvio',
#   'berlusconi',
#   'indict',
#   'tuesday',
#   'new',
#   'criminal',
#   'charge',
#   'break',
#   'news',
#   'buzz'],
#  ['yoga', 'running', 'thursday', 'e', 'book', 'turn', 'wellbee', 'getinvolve'],
#  ['janet', 'jackson', 'bring', 'extra', 'saggy', 'pamper', 'pant'],
#  ['superbowl',
#   'revel',
#   'finally',
#   'release',
#   'dvd',
#   'nov',
#   'day',
#   'complete',
#   'oh',
#   'love',
#   'bey'],
#  ['jacksonville', 'sound', 'like', 'tomorrow'],
#  ['rick',
#   'stein',
#   'reckon',
#   'tuna',
#   'like',
#   'roast',
#   'beef',
#   'japanese',
#   'tuna',
#   'yorkshire',
#   'pudding',
#   'sunday',
#   'roast',
#   'goodfoodchannel'],
#  ['dana',
#   'white',
#   'announce',
#   'holm',
#   'rousey',
#   'schedule',
#   'july',
#   'wait',
#   'rematch'],
#  ['mysa',
#   'close',
#   'laurel',
#   'point',
#   'field',
#   'weather',
#   'condition',
#   'session',
#   'monday',
#   'cancel'],
#  ['hrs',
#   'sit',
#   'dfw',
#   'miss',
#   'connect',
#   'milan',
#   'miss',
#   'flight',
#   'connect',
#   'today',
#   'update',
#   'plane'],
#  ['paul', 'dunne', 'tee', 'open', 'classic', 'big', 'small', 'lol'],
#  ['price',
#   'lay',
#   'fraundley',
#   'harrison',
#   'pretty',
#   'bad',
#   'easily',
#   'klitschko',
#   'brother',
#   'wipe',
#   'floor',
#   'box'],
#  ['justin', 'bieber', 'concert', 'time', 'happy'],
#  ['completely', 'different', 'milan', 'half'],
#  ['williams', 'williams', 'match', 'serena', 'save', 'good'],
#  ['paul', 'dunne', 'nail', 'tomorrow', 'place', 'pro', 'cash'],
#  ['john',
#   'cena',
#   'use',
#   'center',
#   'piece',
#   'wall',
#   'john',
#   'cena',
#   'near',
#   'future'],
#  ['look',
#   'forward',
#   'tomorrow',
#   'bell',
#   'ring',
#   'amp',
#   'home',
#   'amp',
#   'like',
#   'hour',
#   'nap',
#   'watch',
#   'yesterday',
#   'ah'],
#  ['hell',
#   'frank',
#   'ocean',
#   'jhene',
#   'aiko',
#   'thank',
#   'bre',
#   'grade',
#   'mf',
#   'tori',
#   'kelly',
#   'remember',
#   'youtube',
#   'day',
#   'lmao'],
#  ['tour',
#   'madonna',
#   'tattoo',
#   'wonder',
#   'rebelheart',
#   'happen',
#   'rebelhearttour'],
#  ['wonder',
#   'taylor',
#   'swift',
#   'bring',
#   'onstage',
#   'perform',
#   'houston',
#   'tomorrow'],
#  ['game', 'play', 'week', 'interesting', 'super', 'sunday'],
#  ['red',
#   'sox',
#   'lineup',
#   'david',
#   'ortiz',
#   'return',
#   'leave',
#   'sunday',
#   'game',
#   'sore',
#   'calf'],
#  ['mubb',
#   'pick',
#   'preseason',
#   'big',
#   'east',
#   'coach',
#   'poll',
#   'no',
#   'individual',
#   'honor',
#   'buzz',
#   'williams',
#   'squad',
#   'peyton',
#   'siva',
#   'preseason',
#   'poy'],
#  ['find',
#   'win',
#   'ticket',
#   'fleetwood',
#   'mac',
#   'tribute',
#   'band',
#   'tomorrow',
#   'night',
#   'sad',
#   'excited'],
#  ['good',
#   'idea',
#   'week',
#   'espy',
#   'award',
#   'project',
#   'runway',
#   'anniversary',
#   'party',
#   'calgary',
#   'stampede'],
#  ['yes', 'k', 'ow', 'time', 'today', 'kris', 'bryant', 'hit', 'walkoff'],
#  ['rt',
#   'lucy',
#   'hale',
#   'trend',
#   'worldwide',
#   'girl',
#   'prettylittleliar',
#   'love',
#   'fan',
#   'tonight',
#   'congra'],
#  ['t', 'mobile', 'tomorrow'],
#  ['lol',
#   'super',
#   'awkward',
#   'hella',
#   'foggy',
#   'rim',
#   'tomorrow',
#   'game',
#   'suppose',
#   'tv',
#   'lol',
#   'uhhhh',
#   'ball',
#   'lol'],
#  ['super',
#   'awkward',
#   'moment',
#   'qadianis',
#   'tell',
#   'muslim',
#   'follow',
#   'islam',
#   'allah',
#   'quide',
#   'islam',
#   'protect',
#   'muslim'],
#  ['ed', 'sheeran', 'concert', 'wednesday'],
#  ['u',
#   'run',
#   'white',
#   'sox',
#   'future',
#   'baseman',
#   'amp',
#   'realize',
#   'u',
#   'teacher',
#   'fullcircle',
#   'adorb',
#   'vansonman'],
#  ['dive',
#   'deep',
#   'world',
#   'stefan',
#   'struve',
#   'stipe',
#   'miocic',
#   'lead',
#   'fuel',
#   'tv',
#   'main',
#   'event',
#   'saturday'],
#  ['long',
#   'kriya',
#   'followup',
#   'tomo',
#   'oct',
#   'tok',
#   'koramangala',
#   'walk',
#   'weekly',
#   'servicing'],
#  ['friday', 'celebrate', 'mock', 'love', 'avril', 'chad'],
#  ['think',
#   'guy',
#   'little',
#   'excited',
#   'national',
#   'hot',
#   'dog',
#   'day',
#   'july'],
#  ['uncut',
#   'ultimate',
#   'music',
#   'guide',
#   'dedicate',
#   'fleetwood',
#   'mac',
#   'sale',
#   'uk',
#   'thursday',
#   'sept',
#   'read'],
#  ['love', 'crimson', 'tide', 'roll', 'tide', 'quarter'],
#  ['hey', 'pope', 'miss', 'communique', 'look', 'christians'],
#  ['rousey',
#   'dana',
#   'white',
#   'aj',
#   'eddie',
#   'hearn',
#   'wee',
#   'pet',
#   'project',
#   'great',
#   'eddy',
#   'wee',
#   'pet',
#   'career',
#   'hit',
#   'dec'],
#  ['miss', 'doccie', 'kurt', 'cobain', 'montage', 'heck', 'tomorrow', 'july'],
#  ['literally',
#   'sit',
#   'talk',
#   'mom',
#   'tronnor',
#   'amp',
#   'troye',
#   'amp',
#   'con',
#   'amp',
#   'shawn',
#   'role',
#   'model',
#   'wild',
#   'amp'],
#  ['word',
#   'patch',
#   'amp',
#   'dlc',
#   'file',
#   'size',
#   'gb',
#   'leave',
#   'data',
#   'allowance',
#   'til',
#   'rural',
#   'internet',
#   'boo'],
#  ['brock',
#   'lesnar',
#   'conquer',
#   'undertaker',
#   'undertaker',
#   'rip',
#   'lesnar',
#   'watch',
#   'august',
#   'summerslam',
#   'wwenetwork'],
#  ['attn', 'time', 'join', 'sunday', 'seminar', 'tryout', 'info'],
#  ['gucci',
#   'wack',
#   'good',
#   'song',
#   'kitchen',
#   'future',
#   'trash',
#   'af',
#   'nobody',
#   'know',
#   'lmao'],
#  ['yeah',
#   'kj',
#   'send',
#   'email',
#   'yesterday',
#   'info',
#   'follow',
#   'email',
#   'tomorrow',
#   'detail'],
#  ['james',
#   'meredith',
#   'black',
#   'student',
#   'ole',
#   'miss',
#   's',
#   'definition',
#   'real',
#   'nigga',
#   'ball'],
#  ['photo',
#   'nationalpostsport',
#   'buzz',
#   'steeler',
#   'shut',
#   'robert',
#   'griffin',
#   'iii',
#   'redskin',
#   'sunday'],
#  ['monday',
#   'mean',
#   'work',
#   'movie',
#   'premier',
#   'hustle',
#   'flow',
#   'monday',
#   'dj',
#   'table',
#   'afrojack',
#   'tonight'],
#  ['talk', 'july', 'th', 'like', 'beyonce', 'new', 'cd', 'gtfo'],
#  ['selena', 'new', 'album', 'release', 'november', 'information', 'title'],
#  ['christians',
#   'tomorrow',
#   'morning',
#   'gathering',
#   'believer',
#   'divine',
#   'appointment',
#   'god',
#   't'],
#  ['mr', 'scoggin', 'knoxville', 'saturday', 'stop', 'hi'],
#  ['promise', 'niece', 'ac', 'dc', 'tomorrow', 'soooo', 'not', 'mood'],
#  ['seth',
#   'rollin',
#   'appear',
#   'tuesday',
#   'place',
#   'manchester',
#   'trend',
#   'trndnl'],
#  ['big',
#   'dilemma',
#   'draft',
#   'aaron',
#   'rodger',
#   'joke',
#   'rd',
#   'tom',
#   'brady',
#   'start'],
#  ['generally',
#   'invoke',
#   'islamophobia',
#   'describe',
#   'fear',
#   'msm',
#   'terrorist',
#   'attack',
#   'hate',
#   'muslim'],
#  ['teach',
#   'basketball',
#   'school',
#   'spend',
#   'day',
#   'watch',
#   'larry',
#   'bird',
#   'videos',
#   'rest',
#   'care'],
#  ['daylight',
#   'saving',
#   'time',
#   'end',
#   'weekend',
#   'know',
#   'mean',
#   'timing',
#   'sunday'],
#  ['like', 'electable', 'leader', 'labour', 'party', 'tony', 'blair'],
#  ['little',
#   'facebook',
#   'fun',
#   'friday',
#   'like',
#   'post',
#   'chance',
#   'win',
#   'gift',
#   'card',
#   'dunkin',
#   'donut'],
#  ['need',
#   'sleep',
#   'early',
#   'tomorrow',
#   'morning',
#   'begin',
#   'watch',
#   'jurassic',
#   'world',
#   'hundreth',
#   'time'],
#  ['yolo',
#   'u',
#   'tell',
#   'live',
#   'life',
#   'not',
#   'use',
#   'love',
#   'life',
#   'way',
#   'mother',
#   'rn'],
#  ['film',
#   'mtnfest',
#   'winged',
#   'seduction',
#   'bird',
#   'paradise',
#   'sexy',
#   'movie',
#   'banff',
#   'think',
#   'mate',
#   'bird',
#   'sexy'],
#  ['sunday',
#   'morning',
#   'grandpa',
#   'office',
#   'like',
#   'church',
#   'hymn',
#   'grateful',
#   'dead'],
#  ['lool',
#   'samsung',
#   'launch',
#   'galaxy',
#   'note',
#   'ii',
#   'canada',
#   'psy',
#   'gangnam',
#   'perform',
#   'launch'],
#  ['sad',
#   'challenge',
#   'battle',
#   'season',
#   'tonight',
#   'guess',
#   'wait',
#   'wednesday'],
#  ['want', 'ticket', 'zac', 'brown', 'band', 'saturday', 'night'],
#  ['friend',
#   'barca',
#   'saturday',
#   'travel',
#   'round',
#   'spain',
#   'like',
#   'possible'],
#  ['icymi',
#   'big',
#   'time',
#   'lsu',
#   'recruit',
#   'highlight',
#   'expect',
#   'visitor',
#   'list',
#   'saturday',
#   'game',
#   'kentucky',
#   'free'],
#  ['ed', 'sheeran', 'tomorrow', 'mean', 'like', 'hour'],
#  ['tip', 'season', 'ws', 'tuesday', 'night', 'daily', 'zap'],
#  ['wait',
#   'wake',
#   'sunday',
#   'cuse',
#   'family',
#   'enjoyin',
#   'nice',
#   'big',
#   'breakfast',
#   'lotta',
#   'laugh',
#   'time',
#   'awhile'],
#  ['know', 'bear', 'november', 'parent', 'valentine', 'day'],
#  ['shame',
#   'government',
#   'ex',
#   'tory',
#   'disgust',
#   'soldier',
#   'arrest',
#   'bloody',
#   'sunday',
#   'whilst',
#   'ira',
#   'walk',
#   'free'],
#  ['trust', 'issue', 'zayn', 'instagram', 'yes', 'think', 'post'],
#  ['look', 'like', 'david', 'beckham'],
#  ['find',
#   'guilty',
#   'violate',
#   'scotus',
#   'decision',
#   'regard',
#   'ssm',
#   'amp',
#   'order',
#   'comply',
#   'contempt'],
#  ['everybody', 'talk', 'adele', 'guy', 'new', 'david', 'bowie', 'tomorrow'],
#  ['look',
#   'forward',
#   'passion',
#   'pink',
#   'event',
#   'tomorrow',
#   'night',
#   'medusa',
#   'brownsville',
#   'perfect'],
#  ['watch', 'john', 'cena', 'video', 'develop', 'sense'],
#  ['start',
#   'hope',
#   'joe',
#   'biden',
#   'enter',
#   'race',
#   'time',
#   'alternative',
#   'debate',
#   'joe',
#   'trump',
#   'epic'],
#  ['nfl',
#   'diss',
#   'tom',
#   'brady',
#   'social',
#   'medium',
#   'sunday',
#   'night',
#   'nfl',
#   'official',
#   'twitter',
#   'account',
#   'post',
#   'photo',
#   'abou'],
#  ['dustin', 'johnson', 'love', 'pain', 'sunday'],
#  ['low',
#   'moment',
#   'think',
#   'tuesday',
#   'noel',
#   'gallagher',
#   'close',
#   'good',
#   'boy',
#   'world',
#   'smile'],
#  ['david', 'price', 'start', 'hope', 'fri', 'ticket', 'game', 'vs', 'yankee'],
#  ['paul', 'dunne', 'wish', 'specific', 'lead', 'sunday', 'open', 'bbcgolf'],
#  ['winter', 'classic', 'lock', 'tomorrow', 'season'],
#  ['john',
#   'cena',
#   'block',
#   'seth',
#   'rollin',
#   'knee',
#   'face',
#   'raw',
#   'past',
#   'monday'],
#  ['safe', 'chicago', 'style', 'popcorn', 'big', 'brother', 'sunday'],
#  ['david',
#   'bowie',
#   'blackstar',
#   'saturday',
#   'morning',
#   'freak',
#   'new',
#   'minute',
#   'video',
#   'mr',
#   'bowie'],
#  ['blame', 'snoop', 'dogg', 'izzy', 'stick', 'body', 'sun', 'roof'],
#  ['ben',
#   'lederman',
#   'end',
#   'american',
#   'play',
#   'barca',
#   'time',
#   'sound',
#   'like',
#   'head',
#   'florida'],
#  ['immediately', 'fight', 'saturday', 'rousey', 'point', 'envy'],
#  ['weekend',
#   'playlist',
#   'friday',
#   'm',
#   'post',
#   'weekend',
#   'playlist',
#   'favorite',
#   'tune'],
#  ['rewatche',
#   'saturday',
#   'night',
#   'superstar',
#   'not',
#   'version',
#   'blaze',
#   'glory',
#   'epic'],
#  ['hope',
#   'john',
#   'cena',
#   'win',
#   'wwe',
#   'world',
#   'heavyweight',
#   'champion',
#   'time',
#   'amp',
#   'seth',
#   'rollin',
#   'right',
#   'future',
#   'titlefortitle'],
#  ['good',
#   'flashback',
#   'tuesday',
#   'deezer',
#   'tonight',
#   'enjoy',
#   'good',
#   'hit',
#   'biggie',
#   'g'],
#  ['thinkin',
#   'wear',
#   'direction',
#   'nirvana',
#   'shirt',
#   'courtesy',
#   'tomorrow',
#   'not',
#   'want',
#   'fun'],
#  ['big', 'time', 'movie', 'tomorrow', 'sure', 'watch', 'great', 'movie'],
#  ['sam', 'smith', 'bad', 'choice', 'bond', 'song', 'spectre', 'like'],
#  ['chelsea', 'poor', 'start', 'season', 'point', 'ammer', 'october'],
#  ['bea', 'want', 'dunkin', 'donut', 'tomorrow'],
#  ['kris', 'bryant', 'favorite', 'ball', 'player', 'time'],
#  ['rock', 'face', 'wwe', 'title', 'royal', 'rumble', 'vote', 'rockpunk'],
#  ['bye',
#   'felicia',
#   'ice',
#   'cube',
#   'line',
#   'friday',
#   'suge',
#   'knight',
#   'blood',
#   'red',
#   'wardrobe',
#   'amp',
#   'immediate',
#   'conflict',
#   'snoop'],
#  ['katie',
#   'let',
#   'watch',
#   'friday',
#   'night',
#   'light',
#   'mom',
#   'let',
#   'watch',
#   'new',
#   'nichola',
#   'spark',
#   'movie',
#   'wan',
#   'na',
#   'watch',
#   'naruto',
#   'gtfo',
#   'ethan'],
#  ['david', 'wright', 'good', 'friend', 'ground'],
#  ['happy',
#   'birthday',
#   'namja',
#   'bias',
#   'kpop',
#   'lee',
#   'taemin',
#   'taem',
#   'love',
#   'u',
#   'miss',
#   'u',
#   'past',
#   'happytaeminday'],
#  ['thank',
#   'follow',
#   'econokit',
#   'like',
#   'use',
#   'bizikent',
#   'hashtag',
#   'rt',
#   'follow',
#   'local',
#   'business',
#   'bizitalk'],
#  ['ticket',
#   'troy',
#   'stub',
#   'hub',
#   'sad',
#   'youngin',
#   'saturday',
#   'great',
#   'day'],
#  ['google',
#   'hot',
#   'news',
#   'eva',
#   'longoria',
#   'appear',
#   'obama',
#   'thursday',
#   'teamfollowback',
#   'yanew'],
#  ['widely', 'recent', 'article', 'mehdi', 'hasan', 'guradian', 'good'],
#  ['yakubtohang',
#   'matter',
#   'fate',
#   'yakub',
#   'hang',
#   'tomorrow',
#   'apart',
#   'v',
#   'sud',
#   'not',
#   'forget',
#   'dat',
#   'pay',
#   'sin'],
#  ['boko',
#   'haram',
#   'militant',
#   'arrest',
#   'nigeria',
#   'nigeria',
#   'security',
#   'agency',
#   'sunday',
#   'signi'],
#  ['not', 'come', 'uk', 'miss', 'galaxy', 'note'],
#  ['sun',
#   'newspaper',
#   'disrespect',
#   'war',
#   'dead',
#   'labour',
#   'woman',
#   'leader',
#   'think',
#   'know',
#   'respect',
#   'ira',
#   'bbcqt'],
#  ['enjoy', 'vibe', 'moto', 'g', 'gen', 'motobffreveale'],
#  ['kris',
#   'bryant',
#   'pretty',
#   'good',
#   'baseball',
#   'think',
#   'future',
#   'youhearditherefirst'],
#  ['preview',
#   'new',
#   'hu',
#   'wayne',
#   'knight',
#   'premiere',
#   'tonight',
#   'pt',
#   'reelz'],
#  ['ancelotti',
#   'khedira',
#   'recover',
#   'ready',
#   'play',
#   'not',
#   'completely',
#   'match',
#   'fit',
#   'imagine',
#   'minute',
#   'tomorrow',
#   'realmadrid'],
#  ['end',
#   'watch',
#   'twilight',
#   'movie',
#   'entertaining',
#   'super',
#   'boring',
#   'meh'],
#  ['celebrate',
#   'national',
#   'hot',
#   'dog',
#   'day',
#   'thursday',
#   'national',
#   'hot',
#   'dog',
#   'day',
#   'business',
#   'offer',
#   'deal',
#   'hampt'],
#  ['roster', 'release', 'rise', 'star', 'game', 'sit'],
#  ['interesting',
#   'unveil',
#   'tomorrow',
#   'aapl',
#   'ipad',
#   'tv',
#   'tm',
#   'new',
#   'prius',
#   'prius'],
#  ['help',
#   'end',
#   'discrimination',
#   'muslims',
#   'right',
#   'kill',
#   'non',
#   'muslims',
#   'america'],
#  ['estella',
#   'dramatic',
#   'sudden',
#   'cute',
#   'feel',
#   'like',
#   'point',
#   'problem',
#   'girl',
#   'boy'],
#  ['tomorrow',
#   'shooting',
#   'day',
#   'spend',
#   'day',
#   'venice',
#   'beach',
#   'maybe',
#   'look',
#   'gold',
#   'gym'],
#  ['suppose', 'hand', 'deca', 'money', 'monday', 'melleby'],
#  ['james',
#   'big',
#   'brother',
#   'throw',
#   'coup',
#   'meg',
#   'seriously',
#   'jame',
#   'thursday',
#   'laugh'],
#  ['federer',
#   'face',
#   'high',
#   'rank',
#   'guy',
#   'draw',
#   'tricky',
#   'fed',
#   'reach',
#   'qfs',
#   'meet',
#   'berdy'],
#  ['head',
#   'coach',
#   'super',
#   'eagle',
#   'sunday',
#   'oliseh',
#   'speak',
#   'relationship',
#   'team',
#   'm',
#   'badotweet'],
#  ['rabbi',
#   'lead',
#   'way',
#   'unite',
#   'jews',
#   'christians',
#   'world',
#   'cbn',
#   'news',
#   'christian',
#   'news'],
#  ['davos',
#   'coach',
#   'del',
#   'curto',
#   'expect',
#   'rick',
#   'nash',
#   'return',
#   'tonight',
#   'davos',
#   'fairly',
#   'bad',
#   'table',
#   'point',
#   'gp',
#   'nyranger'],
#  ['human',
#   'capable',
#   'feel',
#   'emotion',
#   'love',
#   'hate',
#   'relationship',
#   'ss',
#   'music',
#   'tragedy'],
#  ['tell',
#   'time',
#   'throw',
#   'dart',
#   'mon',
#   'rudd',
#   'let',
#   'pay',
#   'drink',
#   'rotterdam'],
#  ['jews', 'christian', 'hypocrite', 'muslim', 'god', 'guide', 'destroy'],
#  ['wan', 'na', 'ac', 'dc', 'bad'],
#  ['lecture',
#   'day',
#   'monday',
#   'like',
#   'pancake',
#   'day',
#   'fat',
#   'kid',
#   'dreamy'],
#  ['lighting',
#   'tragic',
#   'pic',
#   'shawn',
#   'fan',
#   'energy',
#   'event',
#   'san',
#   'diego',
#   'saturday'],
#  ['hopefully',
#   'come',
#   'thursday',
#   'cuz',
#   'preschool',
#   'right',
#   'tegan',
#   'dad'],
#  ['band',
#   'announce',
#   'line',
#   'rock',
#   'ring',
#   'june',
#   'rock',
#   'm',
#   'park',
#   'june',
#   'festival'],
#  ['right',
#   'levinson',
#   'stupid',
#   'spy',
#   'iran',
#   'cigarette',
#   'smuggling',
#   'guy',
#   'retard'],
#  ['thing',
#   'roll',
#   'stone',
#   'today',
#   'question',
#   'want',
#   'know',
#   'not',
#   'ignorant',
#   'stereotype'],
#  ['new',
#   'iron',
#   'maiden',
#   'album',
#   'star',
#   'war',
#   'aftermath',
#   'novel',
#   'release',
#   'tomorrow',
#   'busy',
#   'friday'],
#  ['kane', 'minute', 'england', 'penalty', 'engvswi', 'rooney', 'kane'],
#  ['phillips',
#   'idowu',
#   'pull',
#   'london',
#   'grand',
#   'prix',
#   'mean',
#   'spot',
#   'grab'],
#  ['deloitte',
#   'winner',
#   'appear',
#   'sunday',
#   'times',
#   'virginactivesa',
#   'miway',
#   'strate',
#   'good',
#   'employer',
#   'sa'],
#  ['selena',
#   'great',
#   'hit',
#   'album',
#   'set',
#   'come',
#   'november',
#   'sign',
#   'interscope',
#   'record',
#   'finally'],
#  ['smith', 'sack', 'jpp', 'loss', 'andy', 'lee', 'time'],
#  ['bet', 'site', 'tip', 'favor', 'roma', 'tomorrow', 'play', 'juventus'],
#  ['damn', 'able', 'today', 'watch', 'advanced', 'screening', 'terra', 'nova'],
#  ['dustin', 'johnson', 'lead', 'major', 'thursday', 'course'],
#  ['himmatwala',
#   'set',
#   'holi',
#   'release',
#   'march',
#   'sure',
#   'shoot',
#   'blockbuster',
#   'row',
#   'bb',
#   'sos',
#   'himmatwala'],
#  ['wednesday',
#   'episode',
#   'big',
#   'brother',
#   'boring',
#   'no',
#   'battle',
#   'block',
#   'competition'],
#  ['kris', 'bryant', 'find', 'bomb', 'threat', 'sunday'],
#  ['angela',
#   'merkel',
#   'french',
#   'president',
#   'francois',
#   'hollande',
#   'meet',
#   'monday',
#   'berlin',
#   'discuss',
#   'current',
#   'migrant',
#   'crisis',
#   'solution'],
#  ['patriot', 'cheat', 'tom', 'brady', 'innocent', 'win', 'ring', 'season'],
#  ['beijing',
#   'summer',
#   'olympics',
#   'close',
#   'august',
#   'book',
#   'olympic',
#   'find'],
#  ['teen',
#   'wolf',
#   'movie',
#   'series',
#   'confusing',
#   'think',
#   'listen',
#   'movie',
#   'past',
#   'year',
#   'turn'],
#  ['thing',
#   'learn',
#   'milan',
#   'empoli',
#   'milan',
#   'record',
#   'victory',
#   'season',
#   'saturday',
#   'night'],
#  ['anniv',
#   'twilight',
#   'book',
#   'meyer',
#   'release',
#   'version',
#   'w',
#   'main',
#   'character',
#   'gender',
#   'swap',
#   'true',
#   'original',
#   'story',
#   'writing',
#   'suck'],
#  ['guess', 'gucci', 'come', 'tomorrow'],
#  ['know',
#   'mcgregor',
#   'hype',
#   'like',
#   'rousey',
#   'amp',
#   'know',
#   'lose',
#   'tomorrow',
#   'dana',
#   'white',
#   'stroke'],
#  ['miss',
#   'new',
#   'ballet',
#   'west',
#   'reality',
#   'tv',
#   'series',
#   'cw',
#   'tomorrow'],
#  ['find', 'kendrick', 'lamar', 'concert', 'friday', 'no', 'idea', 'ticket'],
#  ['congrat',
#   'team',
#   'compete',
#   'include',
#   'place',
#   'washington',
#   'place',
#   'air',
#   'force',
#   'academy',
#   'place',
#   'texas'],
#  ['mlb',
#   'brewer',
#   'ryan',
#   'braun',
#   'not',
#   'starting',
#   'lineup',
#   'wednesday',
#   'game',
#   'vs',
#   'cleveland'],
#  ['er', 'edinburgh', 'derby', 'hibs'],
#  ['remember', 'nash', 'new', 'video', 'skylynn', 'tomorrow'],
#  ['glad',
#   'watch',
#   'good',
#   'paul',
#   'rudd',
#   'movie',
#   'instead',
#   'sit',
#   'mess',
#   'paul',
#   'rudd',
#   'love',
#   'interest'],
#  ['madonna',
#   'half',
#   'play',
#   'huws',
#   'come',
#   'strong',
#   'half',
#   'end',
#   'game',
#   'scoreless',
#   'final',
#   'score'],
#  ['unfollowe',
#   'cousin',
#   'post',
#   'facebook',
#   'david',
#   'cameron',
#   'pussy',
#   'need',
#   'accept',
#   'migrant'],
#  ['rt',
#   'come',
#   'boot',
#   'ride',
#   'rally',
#   'son',
#   'anarchy',
#   'navy',
#   'seal',
#   'marcus',
#   'luttrell',
#   'today',
#   'pm',
#   'pm',
#   'ride',
#   'ht'],
#  ['revoke',
#   'justin',
#   'black',
#   'card',
#   'dance',
#   'ugly',
#   'amp',
#   'hang',
#   'travis'],
#  ['word',
#   'peacecamp',
#   'george',
#   'osborne',
#   'faslane',
#   'tomorrow',
#   'tomorrow',
#   'piece',
#   'mind'],
#  ['remember',
#   'time',
#   'play',
#   'nirvana',
#   'grade',
#   'dance',
#   'mosh',
#   'pit',
#   'happen',
#   'video',
#   'lolol'],
#  ['rick',
#   'no',
#   'matter',
#   'venu',
#   'play',
#   'poorly',
#   'serena',
#   'play',
#   'outcome',
#   'set',
#   'easy',
#   'lose',
#   'point',
#   'tennis'],
#  ['de', 'la', 'soul', 'song', 'hear'],
#  ['continue',
#   'bond',
#   'offspring',
#   'marvel',
#   'movie',
#   'superhero',
#   'saturday',
#   'thank',
#   'funny',
#   'ant',
#   'man',
#   'fb'],
#  ['rt', 'u', 'rick', 'perry', 'not', 'money', 'active', 'grass', 'root'],
#  ['play', 'grateful', 'dead', 'excited', 'love', 'try', 'play', 'mayer'],
#  ['harris',
#   'look',
#   'owen',
#   'murray',
#   'amp',
#   'argo',
#   'gamble',
#   'cfl',
#   'ldc',
#   'torvsham'],
#  ['chelsea',
#   'ucl',
#   'finalist',
#   'milan',
#   'know',
#   'know',
#   'play',
#   'final',
#   'winning',
#   'game'],
#  ['wow', 'august', 'release', 'day', 'gim', 'me', 'galaxy', 'note'],
#  ['excellent',
#   'd',
#   'box',
#   'porto',
#   'goody',
#   'studio',
#   'enforce',
#   'redvelvetcupcakebreakfast'],
#  ['m', 'november', 'aka', 'hood', 'ollg', 'pay', 'chicken', 'nugget'],
#  ['vietnamese',
#   'ultimate',
#   'realist',
#   'survivalist',
#   'monsanto',
#   'nestle',
#   'comingfullcircle'],
#  ['ramlila',
#   'ground',
#   'baba',
#   'ramdev',
#   'fast',
#   'pm',
#   'day',
#   'hot',
#   'humid',
#   'day',
#   'cover',
#   'area',
#   'jam',
#   'pack'],
#  ['drone',
#   'drop',
#   'door',
#   'happen',
#   'faa',
#   'deliver',
#   'nasa',
#   'convention',
#   'july',
#   'amazon',
#   'amazon'],
#  ['good',
#   'shit',
#   'hear',
#   'day',
#   'espn',
#   'sc',
#   'nfl',
#   'lock',
#   'official',
#   'return',
#   'field',
#   'soon',
#   'positive',
#   'negotiation',
#   'chris',
#   'mortensen'],
#  ['point',
#   'curtis',
#   'possible',
#   'monk',
#   'departure',
#   'team',
#   'improve',
#   'swan',
#   'scfc'],
#  ['macdougall',
#   'kill',
#   'raider',
#   'mad',
#   'dog',
#   'score',
#   'good',
#   'leadup',
#   'work',
#   'gidley',
#   'houston',
#   'gidley',
#   'miss',
#   'kick',
#   'knight'],
#  ['successive', 'winner', 'pakistan', 'semi', 'final', 'lose', 'final'],
#  ['super',
#   'pac',
#   'gov',
#   'bobby',
#   'jindal',
#   'relegate',
#   'second',
#   'tier',
#   'debate',
#   'panel',
#   'thursday',
#   'cleveland',
#   'broadcast',
#   'ad'],
#  ['true',
#   'like',
#   'kdrama',
#   'watch',
#   'quiet',
#   'popular',
#   'country',
#   'kpop',
#   'time'],
#  ['new',
#   'plymouth',
#   'run',
#   'state',
#   'end',
#   'west',
#   'high',
#   'tonight',
#   'marse',
#   'host',
#   'salmon',
#   'tomorrow',
#   'q',
#   'final'],
#  ['yakub',
#   'finance',
#   'blast',
#   'die',
#   'brother',
#   'not',
#   'care',
#   'tiger',
#   'not',
#   'come',
#   'surrender',
#   't'],
#  ['hope',
#   'social',
#   'medium',
#   'week',
#   'event',
#   'glasgow',
#   'tomorrow',
#   'smwfilmcamp'],
#  ['gandhi',
#   'ji',
#   'present',
#   'plenary',
#   'session',
#   'intuc',
#   'talkatora',
#   'stadium',
#   'new',
#   'delhi'],
#  ['seth',
#   'rollin',
#   'coward',
#   'sellout',
#   'definitely',
#   'awesome',
#   'little',
#   'ninja',
#   'summerslam',
#   'titlefortitle',
#   'cenavsrollin'],
#  ['representin',
#   'seat',
#   'rosa',
#   'park',
#   'sit',
#   'malcolm',
#   'x',
#   'shoot',
#   'martin',
#   'luther',
#   'pop'],
#  ['lion', 'park', 'tomorrow'],
#  ['damn', 'like', 'post', 'gucci', 'slap'],
#  ['know', 'guy', 'tempe', 'week', 'claim', 'parking', 'spot', 'lol'],
#  ['deca',
#   'meet',
#   'tomorrow',
#   'medium',
#   'center',
#   'lot',
#   'stuff',
#   'talk',
#   'breakfast',
#   'provide'],
#  ['guest', 'axschat', 'charming', 'bbc', 'video'],
#  ['worried', 'bit', 'john', 'cena', 'kennedy', 'assassination', 'happen'],
#  ['dress',
#   'like',
#   'hulk',
#   'hogan',
#   'wweraw',
#   'monday',
#   'security',
#   'usher',
#   'room',
#   'watch',
#   'wwe',
#   'use',
#   'head'],
#  ['oh', 'wan', 'na', 'drop', 'kendrick', 'train'],
#  ['force',
#   'reckon',
#   'thur',
#   'dec',
#   'star',
#   'war',
#   'day',
#   'battery',
#   'not',
#   'include',
#   'assembly',
#   'require'],
#  ['write',
#   'dennis',
#   'kucinich',
#   'president',
#   'november',
#   'good',
#   'member',
#   'congress',
#   'good',
#   'politician',
#   'dc'],
#  ['people', 'lie', 'direction', 'album', 'lie', 'direction', 'unbroken'],
#  ['nokia',
#   'small',
#   'fry',
#   'trick',
#   'devil',
#   'care',
#   'equal',
#   'exclusive',
#   'chromesthesia',
#   'wavuvw'],
#  ['photoset',
#   'friday',
#   'lucky',
#   'ticket',
#   'chelsea',
#   'flower',
#   'fantastic',
#   'evening'],
#  ['tomorrow',
#   'wake',
#   'early',
#   'zayn',
#   'erformance',
#   'vma',
#   'true',
#   'regret',
#   'play',
#   'emotion',
#   'sleep'],
#  ['help',
#   'friend',
#   'setup',
#   'new',
#   'moto',
#   'g',
#   'gen',
#   'weekend',
#   'no',
#   'iphone',
#   'money',
#   'amazing'],
#  ['nero', 'ridiculously', 'gay', 'dante', 'world', 'never', 'know'],
#  ['grassroot',
#   'race',
#   'good',
#   'return',
#   'marana',
#   'saturday',
#   'october',
#   'gladden',
#   'farm'],
#  ['andrew', 'luck', 'september', 'cover', 'roll', 'stone', 'badass'],
#  ['oh',
#   'man',
#   'feeling',
#   'sunday',
#   'packer',
#   'hang',
#   'beat',
#   'dolphin',
#   'lol'],
#  ['tango', 'night', 'fleetwood', 'mac', 'uk', 'album', 'chart', 'august'],
#  ['justin',
#   'bieber',
#   'mexico',
#   'city',
#   'monterrey',
#   'perform',
#   'hope',
#   'ride',
#   'bus',
#   'night'],
#  ['sun', 'shine', 'noche', 'de', 'nirvana'],
#  ['rest', 'life', 'convince', 'people', 'watch', 'ant', 'man'],
#  ['watch', 'labyrinth', 'time', 'david', 'bowie', 'bad'],
#  ['taiwan',
#   'thousand',
#   'people',
#   'march',
#   'taipei',
#   'saturday',
#   'push',
#   'legalisation',
#   'sex'],
#  ['milan', 'sit', 'high', 'year', 'shevchenko', 'want', 'time', 'coach'],
#  ['time', 'soon', 'good', 'idea', 'loan', 'longo', 'espanyol'],
#  ['sound',
#   'like',
#   'angry',
#   'naruto',
#   'way',
#   'kind',
#   'train',
#   'good',
#   'know',
#   'okay'],
#  ['hope',
#   'know',
#   'play',
#   'practice',
#   'thursday',
#   'chris',
#   'brown',
#   'concert',
#   'sorry',
#   'not',
#   'sorry'],
#  ['hector',
#   'gomez',
#   'gomez',
#   'leave',
#   'team',
#   'cactus',
#   'league',
#   'game',
#   'thursday',
#   'run',
#   'mlb',
#   'col'],
#  ['monday',
#   'night',
#   'raw',
#   'surprise',
#   'sting',
#   'come',
#   'end',
#   'seth',
#   'rollin',
#   'triple',
#   'h',
#   'baby',
#   'boy'],
#  ['saturday', 'night', 'eric', 'church'],
#  ['ufc',
#   'fuel',
#   'tv',
#   'preliminary',
#   'card',
#   'preview',
#   'saturday',
#   'ufc',
#   'come',
#   'fuel',
#   'tv',
#   'come',
#   'ufc',
#   'mma'],
#  ['tomorrow', 'smile', 'bring', 'sorrow', 'hottieoftheweek', 'demi', 'lovato'],
#  ['agree', 'milan', 'fair'],
#  ['mitch',
#   'daniel',
#   'stephen',
#   'colbert',
#   'purdue',
#   'hat',
#   'thursday',
#   'hope',
#   'burn',
#   'rage',
#   'flame',
#   'glory'],
#  ['hour', 'dunkin'],
#  ['airtime',
#   'new',
#   'video',
#   'chat',
#   'service',
#   'start',
#   'star',
#   'shawn',
#   'fan',
#   'sean',
#   'parker',
#   'spin',
#   'tuesday'],
#  ['yankees', 'win', 'pull', 'game', 'place', 'red', 'sox', 'beat', 'toronto'],
#  ['close',
#   'eye',
#   'sun',
#   'alright',
#   'no',
#   'hurt',
#   'morning',
#   'light',
#   'safe',
#   'sound'],
#  ['imo', 'gagner', 'develop', 'depth', 'slot', 'nice', 'centre'],
#  ['listen', 'david', 'bowie', 'fashion', 'mood', 'wait', 'sat', 'night'],
#  ['think',
#   'comedy',
#   'central',
#   'friday',
#   'download',
#   'virgin',
#   'demand',
#   'tv',
#   'xl'],
#  ['tina',
#   'fey',
#   'look',
#   'like',
#   'sarah',
#   'palin',
#   'sure',
#   'hell',
#   'lot',
#   'brain',
#   'region',
#   'bossypant'],
#  ['delicious',
#   'comfort',
#   'food',
#   'cold',
#   'saturday',
#   'braised',
#   'rib',
#   'apple',
#   'onion',
#   'potato',
#   'sauerkraut'],
#  ['tuesday',
#   'reader',
#   'alzheimer',
#   'dwarf',
#   'stonehenge',
#   'human',
#   'hillary',
#   'value',
#   'college'],
#  ['tomorrow', 'way', 'home', 'alabama'],
#  ['robert',
#   'pattinson',
#   'anna',
#   'kendrick',
#   'annual',
#   'elle',
#   'woman',
#   'hollywood',
#   'celebration'],
#  ['funny',
#   'monsanto',
#   'begin',
#   'spray',
#   'city',
#   'chemical',
#   'design',
#   'people',
#   'not',
#   'hate',
#   'monsanto'],
#  ['nah', 'start', 'beginning', 'evolution', 'madonna', 'album', 'perf'],
#  ['harvey',
#   'shawn',
#   'no',
#   'access',
#   'list',
#   'bo',
#   'carl',
#   'pelini',
#   'tomorrow'],
#  ['john',
#   'kasich',
#   'live',
#   'murky',
#   'middle',
#   'energy',
#   'policy',
#   'home',
#   'state',
#   'force',
#   'hand',
#   'soon'],
#  ['photo', 'charlie', 'hebdo', 'attack', 'want', 'delete', 'tweet'],
#  ['network',
#   'nirvana',
#   'start',
#   'september',
#   'want',
#   'learn',
#   'networking',
#   'help',
#   'grow',
#   'business'],
#  ['dana',
#   'white',
#   'lose',
#   'ufc',
#   'meal',
#   'ticket',
#   'month',
#   'tonight',
#   'rousey',
#   'vanzant',
#   'mcgregor',
#   'betonaldo',
#   'ufzzz'],
#  ['marvel',
#   'charge',
#   'no',
#   'way',
#   'sony',
#   'involved',
#   'mess',
#   'time',
#   'plus',
#   'good',
#   'director',
#   'writer'],
#  ['thor', 'sexy', 'know', 'sexy', 'shirt'],
#  ['account', 'audience', 'paper', 'town', 'bad', 'review', 'movie', 'hottake'],
#  ['kylie',
#   'jenner',
#   'steal',
#   'spotlight',
#   'paper',
#   'town',
#   'west',
#   'hollywood',
#   'saturday',
#   'sister',
#   'kendall',
#   'turn'],
#  ['lady',
#   'michelle',
#   'obama',
#   'beat',
#   'odd',
#   'summit',
#   'tomorrow',
#   'excite',
#   'cameyyboo',
#   'whitehouse',
#   'usa'],
#  ['lorax',
#   'pay',
#   'surprise',
#   'visit',
#   'check',
#   'place',
#   'saturday',
#   'come',
#   'meet'],
#  ['able',
#   'enjoy',
#   'tea',
#   'tuesday',
#   'want',
#   'drink',
#   'cup',
#   'without',
#   'feel',
#   'hurl'],
#  ['day', 'work', 'ok', 'need', 'sunday', 'ticket', 'seth', 'rollin'],
#  ['nice',
#   'love',
#   'arlene',
#   'think',
#   'good',
#   'friday',
#   'movie',
#   'character',
#   'ice',
#   'cube',
#   'amp',
#   'chris',
#   'tucker',
#   'love'],
#  ['sible', 'game', 'scott', 'chris', 'evans'],
#  ['exclusive',
#   'extract',
#   'amy',
#   'lawrence',
#   'new',
#   'book',
#   'invincible',
#   'arsenal',
#   'manager',
#   'talk'],
#  ['debate',
#   'skip',
#   'class',
#   'tomorrow',
#   'bc',
#   'wan',
#   'na',
#   'deal',
#   'crazy',
#   'people',
#   'bc',
#   'obama'],
#  ['btw', 'yakub', 'good', 'terrorist', 'never', 'rest', 'peace'],
#  ['m',
#   'ready',
#   'saturday',
#   'chapel',
#   'hill',
#   'watch',
#   'mike',
#   'glennon',
#   'company',
#   'tarheel',
#   'business',
#   'gopack',
#   'wolfblood',
#   'ncsuvsunc'],
#  ['rise',
#   'planet',
#   'ape',
#   'sunday',
#   'appear',
#   'm',
#   'shout',
#   'draco',
#   'malfoy',
#   'd',
#   'x'],
#  ['rock',
#   'm',
#   'park',
#   'awesome',
#   'need',
#   'write',
#   'band',
#   'tired',
#   'tomorrow',
#   'goodnight'],
#  ['dear',
#   'italian',
#   'harmonizer',
#   'able',
#   'girl',
#   'milan',
#   'nothing',
#   'guess'],
#  ['beautiful',
#   'flat',
#   'meal',
#   'cook',
#   'lovely',
#   'nicely',
#   'half',
#   'tub',
#   'ben',
#   'jerrys',
#   'diet',
#   'start',
#   'tomorrow',
#   'fatty'],
#  ['pll',
#   'halloween',
#   'special',
#   'air',
#   'tue',
#   'instead',
#   'tue',
#   'creep',
#   'consider',
#   'day',
#   'halloween'],
#  ['paul', 'mccartney', 'sing', 'jet', 'vote', 'tail'],
#  ['dear',
#   'twitterverse',
#   'gif',
#   'murray',
#   'f',
#   'bomb',
#   'espn',
#   'camera',
#   'need',
#   'future',
#   'monday',
#   'pls',
#   'thank'],
#  ['look', 'like', 'release', 'nike', 'jordan', 'raffle', 'dig', 'fck', 'bot'],
#  ['talk',
#   'illuminati',
#   'kanye',
#   'west',
#   'president',
#   'tell',
#   'find',
#   'pr',
#   'stunt',
#   'tomorrow'],
#  ['snoop',
#   'dogg',
#   'son',
#   'cordell',
#   'broadus',
#   'quit',
#   'game',
#   'prove',
#   've',
#   'come',
#   'forksup',
#   't'],
#  ['seriously', 'free', 'ticket', 'ed', 'sheeran', 'saturday', 'catch'],
#  ['believe',
#   'mariah',
#   'carey',
#   'want',
#   'christmas',
#   'play',
#   'right',
#   'september'],
#  ['sigh', 'sadly', 'beckon', 'arm', 'like', 'tegan', 'right'],
#  ['pop',
#   'head',
#   'reply',
#   'post',
#   'leave',
#   'member',
#   'alonso',
#   'future',
#   'not'],
#  ['register', 'act', 'sit', 'minute', 'tired'],
#  ['cate',
#   'blanchett',
#   'award',
#   'honour',
#   'aacta',
#   'award',
#   'hold',
#   'sydney',
#   'australian',
#   'academy',
#   'cinema'],
#  ['rick', 'perry', 'drop', 'drop', 'com', 'tier'],
#  ['carlo',
#   'ancelotti',
#   'isco',
#   'important',
#   'player',
#   'tomorrow',
#   'james',
#   'rodriguez',
#   'start',
#   'rest',
#   'wednesday',
#   'haalmadrid'],
#  ['happy',
#   'birthday',
#   'niece',
#   'mommy',
#   'jess',
#   'love',
#   'heart',
#   'miss',
#   'payton',
#   'day'],
#  ['friday',
#   'bologna',
#   'til',
#   'sunday',
#   'morning',
#   'train',
#   'milan',
#   'monza',
#   'italian',
#   'grand',
#   'prix',
#   'yeah',
#   'boy'],
#  ['kerry', 'write', 'freaking', 'book', 'read'],
#  ['subtitle',
#   'film',
#   'mk',
#   'week',
#   'inside',
#   'tonight',
#   'pm',
#   'ant',
#   'man',
#   'thursday',
#   'gallow',
#   'monday'],
#  ['time', 'old', 'advice', 'hillary', 'recycle', 'news', 'problem'],
#  ['samsung', 'confirm', 'august', 'launch', 'date', 'galaxy', 'note'],
#  ['excited',
#   'new',
#   'tomb',
#   'raider',
#   'game',
#   'come',
#   'march',
#   'talk',
#   'start',
#   'know'],
#  ['rt',
#   'observe',
#   'clemson',
#   'linebacker',
#   'early',
#   'today',
#   'safe',
#   'position',
#   'undergo',
#   'drastic',
#   'change',
#   'th'],
#  ['live', 'feed', 'big', 'brother', 'fan', 'sun', 'time', 'month'],
#  ['tv',
#   'rating',
#   'v',
#   'rockie',
#   'tonight',
#   'mnf',
#   'texan',
#   'jet',
#   'reg',
#   'season',
#   'hardball',
#   'v',
#   'preseason',
#   'football'],
#  ['naruto', 'son', 'confident', 'naruto', 'control'],
#  ['welp', 'let', 'tony', 'romo', 'today', 'fantasyfootball'],
#  ['different',
#   'type',
#   'player',
#   'messi',
#   'ronaldo',
#   'good',
#   'not',
#   'remember',
#   'way'],
#  ['happen', 'raw', 'brock', 'lesnar'],
#  ['feel',
#   'like',
#   'kid',
#   'wait',
#   'christmas',
#   'come',
#   'bike',
#   'want',
#   'kenda',
#   'release',
#   'honey',
#   'badger'],
#  ['harmony',
#   'waste',
#   'space',
#   'triple',
#   'ho',
#   'ed',
#   'sheeran',
#   'selena',
#   'gomez',
#   'kelly',
#   'clarkson',
#   'trash'],
#  ['oh',
#   'shit',
#   'ray',
#   'lewis',
#   'able',
#   'come',
#   'hopefully',
#   'young',
#   'cause',
#   'ask',
#   'raven',
#   'win',
#   'superbpwl',
#   'cundiff'],
#  ['check',
#   'derby',
#   'big',
#   'screen',
#   'tomorrow',
#   'night',
#   'screening',
#   'creative',
#   'alliance'],
#  ['paper',
#   'town',
#   'yesterday',
#   'sit',
#   'person',
#   'like',
#   'look',
#   'like',
#   'freak',
#   'bit'],
#  ['odin',
#   'far',
#   'wanderer',
#   'grant',
#   'wisdom',
#   'courage',
#   'victory',
#   'friend',
#   'thor',
#   'grant',
#   'strength'],
#  ['not', 'right', 'scotus', 'constitution', 'follow', 'scotu', 'fuck'],
#  ['mariah', 'carey', 'star', 'walk', 'damn', 'time'],
#  ['try',
#   'suffer',
#   'cast',
#   'plan',
#   'parenthood',
#   'facility',
#   'gift',
#   'decision',
#   'work',
#   'p'],
#  ['blum', 'poe', 'send', 'email', 'announcement', 'chuck', 'close', 'opening'],
#  ['baltimore',
#   'sun',
#   'report',
#   'redskin',
#   'cundiff',
#   'ed',
#   'billy',
#   'cundiff'],
#  ['home',
#   'opener',
#   'tomorrow',
#   'night',
#   'vs',
#   'marlie',
#   'lot',
#   'future',
#   'montreal',
#   'canadien',
#   'let',
#   'sell',
#   'low'],
#  ['case', 'grab', 'offer', 'free', 'fantasy', 'ebook', 'amazon', 'google'],
#  ['haha', 'wait', 'remain', 'excellent', 'hope', 'enjoy'],
#  ['ok',
#   'saturday',
#   'sm',
#   'bacolod',
#   'meet',
#   'crush',
#   'boom',
#   'xd',
#   'hahahahqa'],
#  ['dirt',
#   'poor',
#   'kid',
#   'world',
#   'country',
#   'manage',
#   'money',
#   'kid',
#   'valley'],
#  ['like',
#   'not',
#   'complain',
#   'tomorrow',
#   'cheer',
#   'traffic',
#   'foo',
#   'fighter',
#   'revs',
#   'later'],
#  ['record',
#   'ryan',
#   'braun',
#   'smack',
#   'career',
#   'robin',
#   'yount',
#   'wild',
#   'brewer',
#   'marlin',
#   'd',
#   'matinee',
#   'story',
#   'fox',
#   'sport'],
#  ['threshold',
#   'new',
#   'video',
#   'stare',
#   'sun',
#   'select',
#   'fan',
#   'video',
#   'contest'],
#  ['sharknado', 'tomorrow', 'not', 'excited', 'live', 'right'],
#  ['chris',
#   'evans',
#   'captain',
#   'america',
#   'avenger',
#   'little',
#   'bro',
#   'captain',
#   'america'],
#  ['new',
#   'match',
#   'add',
#   'summerslam',
#   'card',
#   'sunday',
#   'randy',
#   'orton',
#   'sheamus',
#   'add',
#   'card',
#   'thi'],
#  ['reason',
#   'scared',
#   'gay',
#   'u',
#   'hide',
#   'true',
#   'feeling',
#   'hate',
#   'fear',
#   'u',
#   'thought',
#   'picture'],
#  ['great',
#   'screen',
#   'analysis',
#   'brief',
#   'jinni',
#   'semantic',
#   'discovery',
#   'smart',
#   'social',
#   'recommendation',
#   'ce'],
#  ['happy', 'birthday', 'conor', 'mcgregor', 'great', 'day'],
#  ['degale', 'mate', 'think', 'murray', 'cause', 'problem', 'half', 'fight'],
#  ['think', 'green', 'day', 'tomorrow', 'remember', 'white', 'day', 'cry'],
#  ['m',
#   'travis',
#   'garland',
#   'janet',
#   'jackson',
#   'week',
#   'october',
#   'life',
#   'blissful'],
#  ['reason',
#   'dad',
#   'cool',
#   'human',
#   'currently',
#   'obsess',
#   'friday',
#   'night',
#   'light',
#   'netflix'],
#  ['kca', 'happy', 'birthday', 'prince', 'george', 'wee', 'dote', 't'],
#  ['unfollow', 'spelling', 'snoop', 'dogg', 'g'],
#  ['hit', 'shawn', 'tomorrow'],
#  ['gay',
#   'marriage',
#   'mention',
#   'constitution',
#   'no',
#   'marriage',
#   'prevent',
#   'state',
#   'unequal',
#   'law'],
#  ['play', 'friday', 'watch'],
#  ['beautiful',
#   'daughter',
#   'april',
#   'mother',
#   'day',
#   'shoot',
#   'lovely',
#   'jo',
#   'rutherford',
#   'x'],
#  ['rich',
#   'guy',
#   'rich',
#   'guy',
#   'look',
#   'bad',
#   'law',
#   'rich',
#   'guy',
#   'end',
#   'sony'],
#  ['anybody',
#   'radio',
#   'station',
#   'tomorrow',
#   'shawn',
#   'friend',
#   'like',
#   'new',
#   'friend',
#   'meet'],
#  ['hammond',
#   'clarkson',
#   'sign',
#   'amazon',
#   'prime',
#   'amazonprime',
#   'hammond',
#   'clarkson'],
#  ['bro', 'confirm', 'jlin', 'tomorrow'],
#  ['look',
#   'forward',
#   'preach',
#   'plant',
#   'city',
#   'baptist',
#   'sunday',
#   'new',
#   'city',
#   'church',
#   'baptize',
#   'kingdom',
#   'praise',
#   'god'],
#  ['spend',
#   'sunday',
#   'family',
#   'galvin',
#   'hilton',
#   'hotel',
#   'great',
#   'view',
#   'great',
#   'food',
#   'drink'],
#  ['m', 'watch', 'katy', 'perry', 'movie', 'saturday', 'night', 'lol'],
#  ['hey',
#   'monday',
#   'come',
#   'watch',
#   'white',
#   'sox',
#   'red',
#   'sox',
#   'miller',
#   'lite',
#   'draft',
#   'svedka',
#   'cocktail'],
#  ['probably', 'star', 'war', 'day'],
#  ['gucci',
#   'plenty',
#   'breath',
#   'hopeful',
#   'prognosis',
#   'widen',
#   'brace',
#   'physiological',
#   'individual',
#   'entrance',
#   'proliferation'],
#  ['seth',
#   'rollin',
#   'great',
#   'champion',
#   'thing',
#   'monday',
#   'night',
#   'raw',
#   'middle',
#   'ring'],
#  ['celebrate',
#   'birthday',
#   'beautiful',
#   'prince',
#   'george',
#   'offer',
#   'personalise',
#   'child',
#   'relate'],
#  ['burger',
#   'ale',
#   'wine',
#   'magic',
#   'mike',
#   'xxl',
#   'way',
#   'monday',
#   'bearable',
#   'magicmikexxl'],
#  ['need',
#   'job',
#   'amazon',
#   'campus',
#   'tomorrow',
#   'prepare',
#   'offer',
#   'job',
#   'spot',
#   'cst'],
#  ['beginning',
#   'real',
#   'change',
#   'saudi',
#   'arabia',
#   'woman',
#   'councillor',
#   'elect',
#   'empowerwoman',
#   'womenissue'],
#  ['lol',
#   'rt',
#   'jul',
#   'louis',
#   'amp',
#   'briana',
#   'meet',
#   'actually',
#   'kind',
#   'embarrassing'],
#  ['guy',
#   'want',
#   'alarm',
#   'think',
#   'hulk',
#   'hogan',
#   'not',
#   'feature',
#   'season',
#   'celebrityapprentice'],
#  ['sunday',
#   'funday',
#   'lunch',
#   'magic',
#   'mike',
#   'xxl',
#   'lady',
#   'swimming',
#   'channingishot',
#   'gim',
#   'me'],
#  ['twilight',
#   'hometown',
#   'kura',
#   'sunset',
#   'papakura',
#   'road',
#   'bp',
#   'gas',
#   'station',
#   'sneak',
#   'sun',
#   'shot'],
#  ['tehran',
#   'mon',
#   'amour',
#   'obama',
#   'try',
#   'establish',
#   'tie',
#   'mullah',
#   'no',
#   'barack',
#   'obama',
#   'vote',
#   'mitt',
#   'romney'],
#  ['great',
#   'chat',
#   'jk',
#   'simmon',
#   'amp',
#   'damien',
#   'chazelle',
#   'excellent',
#   'whiplash',
#   'film',
#   'not',
#   'till',
#   'jan',
#   'x'],
#  ['tfi',
#   'friday',
#   'chris',
#   'evans',
#   'yellow',
#   'mr',
#   'happy',
#   'tshirt',
#   'tonight',
#   'al',
#   'chant',
#   'namesake',
#   'tonight'],
#  ['yesterday', 'shock', 'ireland', 'moment', 'game', 'away', 'today'],
#  ['think', 'frank', 'ocean', 'delay', 'release', 'till', 'tomorrow'],
#  ['marty',
#   'nebraska',
#   'yesterday',
#   'talk',
#   'include',
#   'bullying',
#   'news',
#   'fun',
#   'time',
#   'learn'],
#  ['tweet', 'moto', 'g', 'gen', 'wish', 'fhd', 'display'],
#  ['jose', 'iglesia', 'amazing', 'play', 'row', 'derek', 'jeter'],
#  ['follow', 'meet', 'november', 'outside', 'bell', 'center'],
#  ['africanbaze',
#   'kris',
#   'caitlyn',
#   'jenner',
#   'photo',
#   'kylie',
#   'birthday',
#   'bash',
#   'family',
#   'pic'],
#  ['rt',
#   'no',
#   'way',
#   'underestimate',
#   'madness',
#   'cynicism',
#   'frank',
#   'open',
#   'loathing',
#   'country',
#   'characterize',
#   'today',
#   'republican'],
#  ['tomorrow', 'come', 'barcelona', 'want'],
#  ['viking', 'big', 'hit', 'stop', 'knight', 'deep', 'viking', 'end'],
#  ['cute',
#   'animal',
#   'hire',
#   'clickbait',
#   'work',
#   'directly',
#   'bring',
#   'jennifer',
#   'lawrence',
#   'tomorrow'],
#  ['think', 'probably', 'prefer', 'not', 'mention', 'ira', 'year', 'tbh'],
#  ['univb',
#   'big',
#   'weekend',
#   'season',
#   'far',
#   'start',
#   'tonight',
#   'missouri',
#   'state',
#   'pm',
#   'wichita',
#   'state',
#   'tomorrow'],
#  ['white', 'sox', 'lead', 'mariner', 'white', 'sox'],
#  ['add',
#   'man',
#   'battle',
#   'royal',
#   'wednesday',
#   'randy',
#   'orton',
#   'spot',
#   'worry',
#   'ambrose'],
#  ['thank', 'invite', 'join', 'ibcshow', 'amsterdam', 'thursday'],
#  ['realise', 'paper', 'town', 'tomorrow'],
#  ['happen',
#   'lead',
#   'people',
#   'israel',
#   'know',
#   'not',
#   'easy',
#   'promise',
#   'thank'],
#  ['wisconsin',
#   'gov',
#   'scott',
#   'walker',
#   'roll',
#   'big',
#   'policy',
#   'proposal',
#   'tuesday',
#   'minnesota',
#   'unveil',
#   'plan',
#   'repeal'],
#  ['gucci',
#   'raft',
#   'coconscious',
#   'occult',
#   'march',
#   'uncover',
#   'biform',
#   'solitary',
#   'modish',
#   'development',
#   'authority',
#   'arden'],
#  ['saudi',
#   'defense',
#   'minister',
#   'work',
#   'hit',
#   'terrorist',
#   'organization',
#   'afghanistan',
#   'wtf',
#   'saudi',
#   'arabia',
#   'recognize',
#   'taliban'],
#  ['score', 'winner', 'man', 'utd', 'kane', 'january', 'enjoy', 'adebyor', 'x'],
#  ['non', 'chase', 'driver', 'kyle', 'busch', 'mark', 'martin'],
#  ['mma',
#   'espn',
#   'video',
#   'night',
#   'explosive',
#   'win',
#   'dan',
#   'henderson',
#   'relive'],
#  ['tomorrow',
#   'work',
#   'people',
#   'talk',
#   'slap',
#   'crotch',
#   'twerk',
#   'response',
#   'reaction',
#   'nicki'],
#  ['lot',
#   'spare',
#   'jar',
#   'marmalade',
#   'jam',
#   'not',
#   'glad',
#   'u',
#   'find',
#   'ash',
#   'd',
#   'easy',
#   'uplift'],
#  ['allah', 'protect', 'muslims', 'ummah', 'oppressor'],
#  ['kick',
#   'world',
#   'cup',
#   'friday',
#   'black',
#   'vs',
#   'tonga',
#   'yeeeaah',
#   'look',
#   'forward',
#   'laxe',
#   'popcorn',
#   'glass',
#   'bubbly'],
#  ['dramatic',
#   'day',
#   'usopen',
#   'federer',
#   'amp',
#   'murray',
#   'march',
#   'bouchard',
#   'suffer',
#   'freak',
#   'fall'],
#  ['rt', 'mantra', 'republicans', 'democrat', 'today', 'like', 'plan', 'plan'],
#  ['george',
#   'aluo',
#   'super',
#   'eagle',
#   'head',
#   'coach',
#   'sunday',
#   'oliseh',
#   'declare',
#   'demne',
#   'win'],
#  ['rt',
# ...
#   'rahul',
#   'kumawat',
#   'etal',
#   'sangam',
#   'university',
#   'bhilwara',
#   'oct'],
#  ['ryan', 'braun', 'tie', 'game', 'base', 'hit'],
#  ['tour',
#   'start',
#   'today',
#   'super',
#   'pump',
#   'greensboro',
#   'nc',
#   'kick',
#   'tonight',
#   'tomorrow',
#   'asheville',
#   'atl',
#   'sunday'],
#  ['john', 'kasich', 'cut', 'main', 'gopdebate', 'stage', 'thursday', 'night'],
#  ['aston',
#   'villa',
#   'midfielder',
#   'karim',
#   'el',
#   'ahmadi',
#   'miss',
#   'saturday',
#   'trip',
#   'sunderland',
#   'suspension',
#   'follow',
#   'fifth',
#   'booking',
#   'season'],
#  ['aston',
#   'villa',
#   'line',
#   'january',
#   'bid',
#   'danish',
#   'midfielder',
#   'aston',
#   'villa',
#   'reportedly',
#   'monitor',
#   'availability'],
#  ['torre',
#   'respect',
#   'player',
#   'feuds',
#   'cross',
#   'line',
#   'saturday',
#   'morning',
#   'torre',
#   'ipad',
#   'chime',
#   'news'],
#  ['finally', 'home', 'shopping', 'time', 'thor', 'finish'],
#  ['think',
#   'brown',
#   'trade',
#   'manziel',
#   'idiot',
#   'aaron',
#   'rodger',
#   'sit',
#   'favre',
#   'multiple',
#   'year'],
#  ['paul', 'mccartney', 'toronto', 'oct', 'want', 'bad'],
#  ['offspring',
#   'amazing',
#   'set',
#   'bar',
#   'high',
#   'foo',
#   'fighter',
#   'bar',
#   'night',
#   'brand',
#   'new',
#   'friday'],
#  ['mt',
#   'syria',
#   'deir',
#   'ezzor',
#   'bokamal',
#   'indiscriminate',
#   'mortar',
#   'shell',
#   'different',
#   'city',
#   'sunday',
#   'oct'],
#  ['fuck', 'love', 'hope', 'drag', 'day', 'tomorrow', 'join', 'real', 'madrid'],
#  ['want',
#   'away',
#   'hope',
#   'rafe',
#   'station',
#   'serena',
#   'murder',
#   'hope',
#   'flower',
#   'aiden',
#   'time'],
#  ['eth',
#   'hm',
#   'ask',
#   'delhi',
#   'police',
#   'ensure',
#   'swachh',
#   'bharat',
#   'drive',
#   'october',
#   'modi',
#   'pay',
#   'surprise',
#   'visit',
#   'ma'],
#  ['murray',
#   'form',
#   'tremendous',
#   'year',
#   'win',
#   'tonight',
#   'reach',
#   'victory',
#   'season',
#   'time'],
#  ['listen',
#   'unforgettable',
#   'fire',
#   'night',
#   'stop',
#   'think',
#   'grade',
#   'w',
#   'concert',
#   'banner',
#   'amp',
#   'mum'],
#  ['kim',
#   'kardashian',
#   'reveal',
#   'plan',
#   'eat',
#   'placenta',
#   'snack',
#   'placenta',
#   'sound',
#   'like',
#   'pret'],
#  ['start', 'soa', 'episode', 'definitely', 'check', 'spartacus'],
#  ['tomorrow',
#   'national',
#   'dog',
#   'day',
#   'not',
#   'confuse',
#   'national',
#   'hot',
#   'dog',
#   'day',
#   'live',
#   'south',
#   'lot',
#   'heat'],
#  ['saudi',
#   'arabia',
#   'hike',
#   'petrol',
#   'price',
#   'pump',
#   'waec',
#   'release',
#   'nov',
#   'dec',
#   'gce',
#   'result',
#   'pass',
#   'record'],
#  ['dustin',
#   'johnson',
#   'major',
#   'belt',
#   'thursday',
#   'friday',
#   'round',
#   'count'],
#  ['dear',
#   'sun',
#   'shine',
#   'confirm',
#   'maillot',
#   'jaune',
#   'tt',
#   'sungodonamission'],
#  ['decent', 'bruv', 'n', 'look', 'espanyol', 'game', 'jan'],
#  ['cloud',
#   'cloud',
#   'computing',
#   'big',
#   'data',
#   'strategy',
#   'ceo',
#   'power',
#   'panel',
#   'international',
#   'cloud',
#   'expo',
#   'modera'],
#  ['easy',
#   'way',
#   'ice',
#   'cream',
#   'sandwich',
#   'national',
#   'ice',
#   'cream',
#   'day',
#   'sunday',
#   'vine'],
#  ['december', 'january', 'nyc', 'nc', 'fl'],
#  ['good',
#   'luck',
#   'love',
#   'london',
#   'spain',
#   'wednesday',
#   'work',
#   'hope',
#   'ticket',
#   'milan'],
#  ['person',
#   'tuesday',
#   'kill',
#   'bomb',
#   'allegedly',
#   'plant',
#   'member',
#   'boko',
#   'haram',
#   'sect',
#   'explode'],
#  ['look',
#   'like',
#   'winter',
#   'classic',
#   'cancel',
#   'tomorrow',
#   'bar',
#   'minute',
#   'agreement'],
#  ['not', 'school', 'yolo', 'essay', 'not', 'ready', 'tomorrow'],
#  ['junichi',
#   'tazawa',
#   'record',
#   'save',
#   'scoreless',
#   'ninth',
#   'wednesday',
#   'white',
#   'sox',
#   'redsox'],
#  ['mariah', 'carey', 'actually', 'fit', 'bird', 'time'],
#  ['vatican',
#   'pedrocalungsod',
#   'beatify',
#   'pope',
#   'john',
#   'paul',
#   'ii',
#   'march',
#   'year',
#   'canonize'],
#  ['marami',
#   'sis',
#   'moon',
#   'embrace',
#   'sun',
#   'love',
#   'rain',
#   'scent',
#   'woman',
#   'fashion',
#   'king',
#   'king',
#   'heart',
#   'queen',
#   'hyun',
#   'man',
#   'd'],
#  ['want', 'jason', 'aldean', 'september'],
#  ['george',
#   'osborne',
#   'adorable',
#   'medium',
#   'person',
#   'think',
#   'help',
#   'greece'],
#  ['want',
#   'buy',
#   'chelsea',
#   'ticket',
#   'game',
#   'aston',
#   'villa',
#   'home',
#   'october',
#   'good',
#   'seat',
#   'goal',
#   'dm'],
#  ['wicket',
#   'bad',
#   'afghans',
#   'slip',
#   'karim',
#   'sadiq',
#   'run',
#   'jos',
#   'buttler'],
#  ['walcott',
#   'sterling',
#   'kane',
#   'sit',
#   'bench',
#   'insult',
#   'vardy',
#   'play',
#   'hard',
#   'worker',
#   'not',
#   'international',
#   'lvl'],
#  ['gucci',
#   'trouser',
#   'atman',
#   'conviction',
#   'bring',
#   'match',
#   'implicative',
#   'avant',
#   'garde',
#   'elevation',
#   'supporti'],
#  ['adorable', 'loveable', 'man', 'song', 'joongki', 'happy', 'birthday'],
#  ['new',
#   'cent',
#   'mixtape',
#   'hospitalize',
#   'mystery',
#   'illness',
#   'today',
#   'new',
#   'cent',
#   'song',
#   'gangsta',
#   'grillz'],
#  ['follow', 'need', 'obsess', 'ah', 'wednesday'],
#  ['monthly',
#   'theme',
#   'ata',
#   'ang',
#   'floor',
#   'namin',
#   'month',
#   'north',
#   'pole',
#   'ngayon',
#   'naman',
#   'africa',
#   'anglamigeh'],
#  ['roll', 'day', 'school', 'tomorrow', 'gucci', 'flip', 'flop'],
#  ['cherington',
#   'awful',
#   'free',
#   'agent',
#   'decision',
#   'stack',
#   'red',
#   'sox',
#   'team',
#   'amazing',
#   'youth'],
#  ['remember',
#   'idea',
#   'january',
#   'charlie',
#   'hebdo',
#   'attack',
#   'fraction',
#   'scale',
#   'game',
#   'changer'],
#  ['wear', 'nike', 'slide', 'tomorrow', 'tweet'],
#  ['love',
#   'aggressive',
#   'serena',
#   'amp',
#   'venu',
#   'serve',
#   'return',
#   'murray',
#   'lose',
#   'match'],
#  ['tomorrow', 'day', 'valentine'],
#  ['guess', 'knick', 'heat', 'pretty', 'clear', 'tomorrow', 'game', 'happen'],
#  ['mtv',
#   'vmas',
#   'seven',
#   'presidential',
#   'moment',
#   'kanye',
#   'west',
#   'stump',
#   'speech',
#   'kanye',
#   'west',
#   'stand',
#   'stage',
#   'sunday',
#   'night',
#   'mtv',
#   'v'],
#  ['pgachampionship',
#   'dustin',
#   'johnson',
#   'leader',
#   'hole',
#   'august',
#   'whistle',
#   'strait',
#   'play',
#   'progress'],
#  ['watch', 'till', 'naruto', 'face', 'demon'],
#  ['round',
#   'group',
#   'book',
#   'battle',
#   'broken',
#   'empire',
#   'malazan',
#   'harry',
#   'potter',
#   'discworld',
#   'hdm',
#   'amp',
#   'ketty',
#   'jay',
#   'advance'],
#  ['superb', 'interview', 'iron', 'maiden', 'bruce', 'dickinson'],
#  ['neil',
#   'degrasse',
#   'tyson',
#   'person',
#   'walk',
#   'mar',
#   'likely',
#   'middle',
#   'school',
#   'student',
#   'china',
#   'sad'],
#  ['scott',
#   'walker',
#   'tell',
#   'wisconsin',
#   'not',
#   'alabama',
#   'answer',
#   'politic'],
#  ['game',
#   'james',
#   'play',
#   'te',
#   'late',
#   'heat',
#   'vs',
#   'knick',
#   'year',
#   'row',
#   'fort'],
#  ['tomorrow',
#   'night',
#   'practice',
#   'team',
#   'black',
#   'vs',
#   'gold',
#   'baseball',
#   'game',
#   'mizzou',
#   'vs',
#   'sc',
#   'volleyball',
#   'game',
#   'onemizzou'],
#  ['auspol',
#   'australian',
#   'prime',
#   'minister',
#   'julia',
#   'gillard',
#   'criminal',
#   'history',
#   'hypocrisy',
#   'wikileak',
#   'julian',
#   'assange'],
#  ['interesting', 'challenge', 'apple', 'netflix', 'original', 'oitnb'],
#  ['lee',
#   'soo',
#   'man',
#   'deep',
#   'sympathy',
#   'amp',
#   'family',
#   'struggle',
#   'grief',
#   'sadness',
#   'ur',
#   'wife',
#   'rest',
#   'peace'],
#  ['oh', 'god', 'hit', 'sam', 'smith', 'tomorrow', 'night'],
#  ['fair', 'saturday', 'town', 'mann', 'bullshit'],
#  ['sxsw', 'axs', 'tv', 'sunday', 'november', 'dig'],
#  ['free',
#   'ticket',
#   'watch',
#   'saigon',
#   'heat',
#   'vs',
#   'singapore',
#   'slinger',
#   'apr',
#   'fan',
#   'email'],
#  ['thursday',
#   'night',
#   'want',
#   'find',
#   'true',
#   'self',
#   'zen',
#   'reach',
#   'nirvana',
#   'little',
#   'free'],
#  ['israel',
#   'voluntary',
#   'offer',
#   'community',
#   'hold',
#   'coat',
#   'ocean',
#   'enjoy',
#   'church',
#   'useful'],
#  ['kendrick', 'pimp', 'butterfly', 'track', 'album', 'end', 'conversation'],
#  ['never',
#   'life',
#   'root',
#   'conor',
#   'mcgregor',
#   'day',
#   'day',
#   'never',
#   'come',
#   'demolish',
#   'oneday'],
#  ['christians',
#   'twitter',
#   'bless',
#   'sunday',
#   'tweeter',
#   'great',
#   'day',
#   'amp',
#   'happy',
#   'tweeting'],
#  ['josh', 'freeman', 'pass', 'vincent', 'jackson', 'minnesota', 'yard'],
#  ['frank',
#   'gifford',
#   'legendary',
#   'monday',
#   'night',
#   'football',
#   'sportscaster',
#   'die',
#   'age'],
#  ['jason',
#   'year',
#   'anniversary',
#   'today',
#   'baby',
#   'month',
#   'today',
#   'm',
#   'happy',
#   'lucky',
#   'lady',
#   'earth'],
#  ['tomorrow',
#   'vol',
#   'ole',
#   'miss',
#   'oxford',
#   'sit',
#   'vfl',
#   'robert',
#   'peace',
#   'discuss',
#   'matchup'],
#  ['england', 'vs', 'aus', 'twicker', 'oooosh'],
#  ['happy', 'eid', 'greeting', 'allah', 'bless'],
#  ['sam', 'smith', 'tonight', 'prob', 'voice', 'tomorrow'],
#  ['trump', 'lead', 'like', 'scott', 'walker'],
#  ['jose',
#   'aldo',
#   'conor',
#   'mcgregor',
#   'set',
#   'square',
#   'december',
#   'dallas',
#   'cowboy',
#   'stadium',
#   'ufc',
#   'president',
#   'dana',
#   'white',
#   'reveal',
#   'hope'],
#  ['remember',
#   'thor',
#   'sit',
#   'exact',
#   'place',
#   'year',
#   'ago',
#   'manipulate',
#   'thor',
#   'attack',
#   'jotunheim'],
#  ['gucci',
#   'bag',
#   'alter',
#   'certainty',
#   'january',
#   'evince',
#   'symptomatic',
#   'present',
#   'time',
#   'relationship',
#   'technical',
#   'ta'],
#  ['game',
#   'curtis',
#   'caretaker',
#   'manager',
#   'grow',
#   'opportunity',
#   'cost',
#   'jenkin',
#   'act',
#   'diligently',
#   'not',
#   'reflect'],
#  ['murray',
#   'real',
#   'trouble',
#   'break',
#   'usopen',
#   'look',
#   'angry',
#   'frustrated'],
#  ['time',
#   'christian',
#   'hung',
#   'gay',
#   'tell',
#   'time',
#   'islam',
#   'hung',
#   'gay',
#   'yesterday',
#   'today',
#   'amp',
#   'tomorrow',
#   'etc',
#   'etc'],
#  ['honesty',
#   'live',
#   'teen',
#   'wolf',
#   'sad',
#   'new',
#   'season',
#   'start',
#   'till',
#   'january'],
#  ['tsipra', 'look', 'strengthen', 'authority', 'party', 'mutiny', 'bailout'],
#  ['little',
#   'trip',
#   'old',
#   'town',
#   'albuquerque',
#   'easily',
#   'mexico',
#   'spain',
#   'vegas',
#   'monday',
#   'morning'],
#  ['liam',
#   'payne',
#   'david',
#   'beckham',
#   'video',
#   'never',
#   'know',
#   'dragmedownmusicvideoisout'],
#  ['yahweh',
#   'willing',
#   'jews',
#   'world',
#   'reunite',
#   'israel',
#   'find',
#   'stay',
#   'jewry',
#   'migration',
#   'today'],
#  ['mariah', 'carey', 'cover', 'tomorrow'],
#  ['know', 'january', 'not', 'wait', 'royal', 'rumble', 'wwe'],
#  ['tweet', 'amp', 'gotg', 'chris', 'evans', 'nova', 'security'],
#  ['shawn', 'nyc', 'tomorrow'],
#  ['toi',
#   'israel',
#   'admit',
#   'killing',
#   'arafat',
#   'deputy',
#   'israel',
#   'time',
#   'thursday',
#   'admit',
#   'responsibility'],
#  ['everyday',
#   'dress',
#   'spartacus',
#   'costume',
#   'miss',
#   'halloween',
#   'catch',
#   'anytime'],
#  ['roman', 'century', 'bc', 'roman', 'war', 'hannibal', 'army', 'mercenary'],
#  ['rock', 'okinawa', 'stylish', 'airport', 'fashion', 'october'],
#  ['david',
#   'letterman',
#   'interesting',
#   'monday',
#   'locate',
#   'new',
#   'york',
#   'city',
#   'hurricane'],
#  ['good',
#   'attitude',
#   'live',
#   'pain',
#   'reason',
#   'somebody',
#   'laugh',
#   'laugh',
#   'never',
#   'reason',
#   'somebody',
#   'pain'],
#  ['anthem',
#   'choke',
#   'flag',
#   'proud',
#   'gandhi',
#   'look',
#   'happy',
#   'proud',
#   'independence',
#   'day',
#   'fb'],
#  ['half',
#   'dead',
#   'sun',
#   'work',
#   'point',
#   'jvm',
#   'xen',
#   'know',
#   'oracle',
#   'project',
#   'alive'],
#  ['plan',
#   'watch',
#   'teen',
#   'choice',
#   'award',
#   'tonight',
#   'spoiler',
#   'alert',
#   'winner',
#   'justin',
#   'bieber',
#   'twilight'],
#  ['spend',
#   'minute',
#   'watch',
#   'poo',
#   'traverse',
#   'sewer',
#   'simcity',
#   'flush',
#   'loo'],
#  ['dublin', 'november'],
#  ['lady',
#   'gaga',
#   'add',
#   'new',
#   'tour',
#   'date',
#   'bornthiswayball',
#   'oslo',
#   'norway',
#   'december'],
#  ['mixin', 'playlist', 'winan', 'tomorrow', 'today', 'good', 'day', 'yup'],
#  ['nokia',
#   'runt',
#   'bumper',
#   'crop',
#   'exhilarate',
#   'not',
#   'mention',
#   'substantial',
#   'd',
#   'exchange',
#   'wspjek'],
#  ['black', 'friday', 'kendrick', 'lamar', 'find', 'listen'],
#  ['beyonce', 'wonder', 'world'],
#  ['kca',
#   'millkesmoov',
#   'viral',
#   'lip',
#   'sync',
#   'car',
#   'beyonce',
#   'birthday',
#   'happy',
#   'friday'],
#  ['start', 'watch', 'teen', 'wolf', 'day', 'wear', 'bright', 'colour'],
#  ['discover',
#   'complete',
#   'season',
#   'star',
#   'war',
#   'rebel',
#   'available',
#   'free',
#   'demand',
#   'tomorrow',
#   'work',
#   'day',
#   'awesome'],
#  ['tuesday',
#   'tv',
#   'pick',
#   'grand',
#   'finale',
#   'style',
#   'rock',
#   'riri',
#   'challenge'],
#  ['wide', 'training', 'gig', 'hard', 'play', 'super', 'rugby', 'weigh'],
#  ['santorum',
#   'campaign',
#   'debt',
#   'romney',
#   'vote',
#   'party',
#   'people',
#   'bad',
#   'bho'],
#  ['grateful', 'dead', 'concert', 'help', 'chicago', 'july', 'destina'],
#  ['divine',
#   'frame',
#   'present',
#   'official',
#   'south',
#   'alabama',
#   'football',
#   'season',
#   'kick',
#   'club',
#   'insanity',
#   'september'],
#  ['beautiful',
#   'bestfriend',
#   'convert',
#   'islam',
#   'laylat',
#   'al',
#   'qadr',
#   'allah',
#   'bless',
#   'amp',
#   'set',
#   'right',
#   'path'],
#  ['come',
#   'saturday',
#   'support',
#   'semi',
#   'final',
#   'round',
#   'battle',
#   'effn',
#   'rock',
#   'ii',
#   'concert'],
#  ['tomorrow',
#   'starter',
#   'david',
#   'price',
#   'mike',
#   'wright',
#   'wright',
#   'mound',
#   'price',
#   'right',
#   'bluejay'],
#  ['soon', 'sit', 'row', 'kim', 'kardashian', 'kanye', 'west'],
#  ['patriot',
#   'beat',
#   'jet',
#   'giant',
#   'royal',
#   'world',
#   'series',
#   'coffee',
#   'damn',
#   'good',
#   'friday',
#   'far',
#   'itsthelittlething'],
#  ['yd',
#   'td',
#   'run',
#   'ross',
#   'terps',
#   'lead',
#   'ross',
#   'yes',
#   'rushing',
#   'likely',
#   'return',
#   'yard',
#   'david',
#   'price',
#   'shut',
#   'o'],
#  ['singapore',
#   'tonight',
#   'excite',
#   'skyfall',
#   'penny',
#   'boarding',
#   'tomorrow'],
#  ['watch',
#   'time',
#   'vote',
#   'nta',
#   'award',
#   'good',
#   'factual',
#   'program',
#   'mite',
#   'need',
#   'watch',
#   'rest',
#   'itvplayer'],
#  ['start', 'watch', 'twilight', 'joke', 'basically', 'sit', 'movie'],
#  ['david',
#   'cameron',
#   'theresa',
#   'head',
#   'sand',
#   'people',
#   'flee',
#   'life',
#   'try',
#   'come',
#   'safe'],
#  ['work',
#   'yesterday',
#   'chris',
#   'brown',
#   'concert',
#   'work',
#   'today',
#   'day',
#   'tomorrow',
#   'm',
#   'ready',
#   'cruise',
#   'vacation'],
#  ['hear',
#   'frank',
#   'ocean',
#   'album',
#   'suppose',
#   'release',
#   'tomorrow',
#   'stay',
#   'minute',
#   'hope',
#   'crush'],
#  ['excited',
#   'find',
#   'amy',
#   'lee',
#   'birthday',
#   'decemember',
#   'guy',
#   'day',
#   'birthday',
#   'close'],
#  ['procrastinating',
#   'need',
#   'ready',
#   'district',
#   'chicago',
#   'police',
#   'rally',
#   'violence',
#   'chi',
#   'town',
#   'cheer',
#   'perform',
#   'king',
#   'dr'],
#  ['catch', 'tomorrow', 'friday', 'ready', 'daylight', 'save', 'time'],
#  ['bloody',
#   'sunday',
#   'big',
#   'recruitment',
#   'drive',
#   'ira',
#   'multiply',
#   'decade',
#   'large',
#   'population'],
#  ['david',
#   'beckham',
#   'joey',
#   'barton',
#   'central',
#   'big',
#   'game',
#   'french',
#   'football',
#   'sunday'],
#  ['tuesday',
#   'night',
#   'man',
#   'city',
#   'v',
#   'ajax',
#   'itv',
#   'follow',
#   'election',
#   'night',
#   'till',
#   'good',
#   'job',
#   'uni',
#   'wednesday'],
#  ['starwar', 'theforceawaken', 'open', 'cinema', 'twilight', 'movie'],
#  ['love', 'air', 'today', 'valentine', 'day', 'china', 'need', 'know'],
#  ['haha',
#   'jeb',
#   'bush',
#   'bore',
#   'guy',
#   'background',
#   'vid',
#   'totally',
#   'not',
#   'shit',
#   'dirtbag'],
#  ['rt',
#   'andy',
#   'rooney',
#   'minute',
#   'appearance',
#   'sunday',
#   'grumpiest',
#   'moment'],
#  ['work', 'monday', 'not', 'come', 'calibraska', 'come'],
#  ['apple',
#   'showtime',
#   'event',
#   'g',
#   'ipod',
#   'shuffle',
#   'introduction',
#   'steve',
#   'job',
#   'introduce',
#   'generatio'],
#  ['watch', 'sharknado'],
#  ['yay', 'inbetweener', 'cinema', 'august', 'funny'],
#  ['kim', 'lose', 'circuit', 'scotu'],
#  ['consider',
#   'edge',
#   'tomorrow',
#   'b',
#   'c',
#   'mind',
#   'tom',
#   'cruise',
#   'video',
#   'game',
#   'movie'],
#  ['rahul',
#   'gandhi',
#   'stop',
#   'refer',
#   'person',
#   'creepy',
#   'address',
#   'shakurbasti',
#   'people'],
#  ['night', 'kremlin', 'friday', 'bring', 'good', 'whigfield', 'costume'],
#  ['jeb', 'bush', 'not', 'jeb', 'john', 'let', 'accurate', 'news', 'reporting'],
#  ['rmt',
#   'play',
#   'bob',
#   'marley',
#   'wailer',
#   'sun',
#   'shine',
#   'listener',
#   'request'],
#  ...]

# %%
# First, we need to determing the vocabulary size of our corpus
# We can estimate it to be much larger than actual to reduce the probability of collisions from the hash function.
# We need to have a clue of how many are they using Word2Vec
w2v_model = gensim.models.Word2Vec(words,window=5,vector_size=100, min_count=1)

# model.wv.index_to_key provides us a list of vocabularies
wv_words = w2v_model.wv.index_to_key
len(wv_words)
# Out:
# 35776

# %%
# We can estimate it to be around 36000
vocab_size = 36000

# %%
# Second, we need to create a onehot-representation for each vocabulary word
# The vocab_size is used to assign a specific index to each word, so the same word will have the same index
onehot_repr = [one_hot(word, vocab_size) for word in tweets]
onehot_repr
# Out:
# [[34022, 13415, 25650, 2777, 17095, 15230, 30631, 17220, 6963, 3518],
#  [19291,
#   13706,
#   10502,
#   15899,
#   15657,
#   30308,
#   6074,
#   23259,
#   14253,
#   21087,
#   33330,
#   24450],
#  [13788, 32266, 35165, 27934, 11083, 11083, 22017, 15412, 867, 1354, 32762],
#  [32660,
#   16450,
#   17246,
#   35347,
#   32929,
#   35082,
#   12602,
#   35839,
#   16918,
#   35744,
#   27949,
#   35400],
#  [21251,
#   23999,
#   6367,
#   10664,
#   31771,
#   1248,
#   28074,
#   32929,
#   27969,
#   5814,
#   5764,
#   2660],
#  [15613,
#   23050,
#   9429,
#   3346,
#   6469,
#   12524,
#   8077,
#   9905,
#   12524,
#   24759,
#   17878,
#   11892,
#   6669],
#  [32929, 9548, 14516, 5882, 21760, 9495, 2754],
#  [18358,
#   14662,
#   12997,
#   12567,
#   33773,
#   15787,
#   19480,
#   5764,
#   2556,
#   10671,
#   12486,
#   12486,
#   6093,
#   13410],
#  [34286,
#   23282,
#   17392,
#   15822,
#   7291,
#   16685,
#   9548,
#   6709,
#   6669,
#   5263,
#   31326,
#   26173,
#   21798,
#   25530],
#  [867, 33220, 4304, 11154, 9464, 20242, 19480],
#  [3174, 7516, 5385, 6669, 10157, 14014, 7516, 14282, 10265],
#  [10464,
#   21282,
#   3346,
#   24726,
#   3238,
#   9219,
#   8055,
#   4126,
#   1343,
#   15613,
#   30642,
#   23837,
#   4739],
#  [15613, 21634, 29357, 15613, 8412, 6669, 10664, 23259, 6960],
#  [899, 8288, 14148, 28745, 22357, 25390, 28721, 10909],
#  [5537, 30559, 13655, 35801, 11936, 35801, 19797, 27624, 26518],
#  [27402, 33089, 1583, 9296],
#  [14576, 10464, 9722, 7223, 26736, 24309, 12486, 10664, 1077, 21760],
#  [4648, 28257, 607, 837, 31028, 21761, 19407, 6669, 7996, 607, 21955],
#  [9758, 26836, 7803, 24903, 8077, 9792, 34720, 9758, 18518, 26836],
#  [20597,
#   31477,
#   20521,
#   601,
#   35475,
#   28745,
#   11936,
#   12863,
#   14805,
#   22564,
#   30763,
#   26838,
#   23086,
#   28727],
#  [15613,
#   9877,
#   13655,
#   8077,
#   21862,
#   708,
#   1525,
#   28780,
#   18539,
#   9977,
#   18539,
#   20242,
#   6669],
#  [15958, 20242, 6932],
#  [24042, 27908, 20235, 22625, 9978, 24042, 20235, 13026, 22991, 21662, 18262],
#  [16838,
#   24500,
#   35852,
#   2172,
#   6669,
#   5764,
#   9907,
#   29157,
#   3353,
#   11206,
#   10664,
#   19994],
#  [20380, 25324, 2996, 17731, 1671, 16366, 21282, 25324, 12997, 8478],
#  [12378,
#   8117,
#   16685,
#   22090,
#   10830,
#   15632,
#   11269,
#   18815,
#   23311,
#   28690,
#   18234,
#   42],
#  [17217, 28268, 17674, 24085, 5377, 25255, 8543, 19797, 24286],
#  [18369, 19387, 20377, 5814, 17289, 35314, 14798, 9877, 6484, 469],
#  [12053, 26371, 33201, 33671, 9710, 23453, 24726, 18534, 14062],
#  [12863, 14805, 34481, 6669, 17315, 13655, 8532, 13415, 12863, 14805],
#  [15365, 31740, 31571, 318, 30383],
#  [12889,
#   32303,
#   13655,
#   24105,
#   18534,
#   25582,
#   18295,
#   11522,
#   16851,
#   7553,
#   21000,
#   32303,
#   16640,
#   24406],
#  [5764, 257, 20005, 12362, 11909, 23090, 21761, 32929, 814, 32653],
#  [29157, 29307, 29157, 28440, 8409, 11432, 23948, 14282, 34633, 28440, 27078],
#  [10664, 2476, 29543, 2660, 2409, 28974, 12929, 13195, 20860, 3556, 34633],
#  [35026,
#   14720,
#   22793,
#   15789,
#   13655,
#   675,
#   15613,
#   28613,
#   17370,
#   3456,
#   14798,
#   19110],
#  [20242, 7582, 17046, 9343, 18910, 23957, 28415, 3970, 13398, 31132, 27790],
#  [28669,
#   11259,
#   26096,
#   8901,
#   10909,
#   29065,
#   27790,
#   32325,
#   16302,
#   26369,
#   2613,
#   3751],
#  [21015, 34479, 12104, 9959, 14488, 26038, 27273, 8288, 13398, 22357, 28780],
#  [6669,
#   14798,
#   12486,
#   29454,
#   15810,
#   8532,
#   15560,
#   33134,
#   19636,
#   22638,
#   769,
#   29924,
#   9792],
#  [30559, 27624, 35801, 9319, 23093, 2783, 20648, 11129, 31686, 29186, 5561],
#  [28630, 4451, 20154, 2306, 4625, 25389, 9382, 35012, 6725, 4973, 22180],
#  [416, 16084, 16764, 7962, 31686, 31686, 11841, 34633, 23626, 20913, 30559],
#  [13429, 34516, 28884, 26952, 11617, 28871, 2628, 899, 25582],
#  [28630, 14282, 23335, 8008, 9180, 32136, 23675, 17182, 11891, 16632],
#  [12687,
#   8532,
#   18815,
#   29731,
#   3456,
#   32000,
#   1769,
#   19480,
#   10909,
#   16632,
#   4972,
#   28255,
#   29395,
#   2584,
#   3456],
#  [33825, 30031, 29515, 25725, 32336, 18153, 29307, 35082, 28805, 19587],
#  [30645,
#   27624,
#   31028,
#   11739,
#   26952,
#   14572,
#   32825,
#   21667,
#   2859,
#   23311,
#   17706,
#   6071,
#   23104,
#   29139],
#  [8843, 18483, 19884, 6669, 12687, 18518, 23057],
#  [27975, 17485, 35314, 27228, 18018, 18518, 24903, 3346, 6469, 13741],
#  [23354, 10157, 16396, 22388, 19480, 28974, 13429, 1770, 26758, 10909],
#  [21783,
#   13464,
#   10411,
#   5532,
#   3346,
#   11577,
#   29288,
#   15595,
#   4450,
#   464,
#   21087,
#   13906,
#   26854],
#  [30138, 18589, 10217, 33186, 18281, 10736],
#  [24487, 6663, 13429, 18668, 34513, 32574, 26952, 31929, 12102, 26675],
#  [12486,
#   9801,
#   28630,
#   25757,
#   12687,
#   8532,
#   23841,
#   13132,
#   6286,
#   24443,
#   9110,
#   2315,
#   21087],
#  [20007,
#   23453,
#   7109,
#   7167,
#   12932,
#   32328,
#   13509,
#   34633,
#   35418,
#   30216,
#   30705,
#   309,
#   34479,
#   12968,
#   18283,
#   34479],
#  [15822, 7291, 23472, 3034, 24838, 29475, 13655, 818, 2931],
#  [23515, 25757, 5594, 6669, 10909, 13398, 23515, 28745, 27301, 21118],
#  [26052,
#   33135,
#   25107,
#   21121,
#   22436,
#   35429,
#   29178,
#   17991,
#   32929,
#   21255,
#   35302,
#   32929,
#   21255,
#   708,
#   13655,
#   19518],
#  [18137, 13898, 31762, 7438, 28880, 28721, 12237],
#  [14724, 17973, 34, 23311, 2267, 29725, 708, 24765, 24522, 13429],
#  [25676, 7705, 30663, 12973, 20449, 10805, 33089, 19480, 21881],
#  [3556, 20907, 21795, 21244, 9611, 7499, 24227, 35313, 16607, 15116],
#  [35429,
#   28256,
#   16529,
#   34436,
#   11245,
#   10507,
#   3346,
#   10615,
#   1634,
#   24084,
#   21305,
#   30694],
#  [32916, 30308, 18534, 4709, 601, 28316, 29831, 29782],
#  [13464, 10411, 14667, 21015, 35731, 33568, 27398],
#  [23548, 8803, 4539, 28008, 23580, 34633, 13655, 12934, 1192, 30559, 32725],
#  [32298, 27949, 10664, 6669],
#  [26067,
#   4628,
#   19846,
#   5123,
#   10664,
#   19501,
#   17273,
#   13654,
#   5123,
#   28636,
#   28801,
#   19480,
#   19501,
#   16551],
#  [21244, 9611, 35314, 5569, 22397, 32924, 5770, 17268, 35307],
#  [13830, 28881, 23596, 21623, 29725, 28635, 2866, 15077, 14798, 29157],
#  [31247,
#   899,
#   11180,
#   13733,
#   13367,
#   33526,
#   13733,
#   32967,
#   13367,
#   21282,
#   33198,
#   29458],
#  [15822, 7291, 29475, 9548, 16218, 708, 34919, 3556],
#  [5311,
#   21566,
#   23341,
#   16338,
#   29250,
#   27402,
#   35761,
#   35669,
#   19438,
#   17129,
#   29139,
#   11154],
#  [27301, 259, 31262, 14905, 4648],
#  [799, 2122, 33526, 19248],
#  [25427, 25427, 190, 26909, 21760, 29307],
#  [15822, 7291, 12687, 6669, 9110, 31472, 25155],
#  [13678, 4511, 34830, 29697, 10192, 12746, 13678, 4511, 4451, 14892],
#  [12486,
#   29454,
#   6669,
#   8103,
#   1454,
#   26952,
#   2584,
#   26952,
#   10664,
#   5935,
#   20399,
#   15613,
#   20648,
#   16357],
#  [14060,
#   33186,
#   33136,
#   12958,
#   4640,
#   27723,
#   16348,
#   27141,
#   17434,
#   12774,
#   25163,
#   34481,
#   6216,
#   13655,
#   32040],
#  [28393, 4377, 7261, 32199, 6817, 1671, 33420],
#  [32199, 28255, 29395, 14667, 29001, 34447, 34663, 6669],
#  [20242, 23311, 29157, 23269, 4352, 19480],
#  [12932, 7284, 6882, 26052, 34852, 27827, 23837, 19480, 20242, 30076, 3928],
#  [6624,
#   13449,
#   8665,
#   708,
#   33478,
#   28628,
#   25151,
#   5764,
#   35745,
#   21767,
#   30694,
#   25427,
#   23805,
#   18668,
#   19659,
#   8665,
#   21502],
#  [23472, 16685, 34479, 7436, 8844, 28410, 34, 6669, 10909, 14103, 24354],
#  [29307, 2058, 29157, 32711, 1769, 35165, 11739, 19797, 4739, 29176, 22744],
#  [28630, 9048, 16329, 14905, 21282, 4530, 21887, 30848, 25523],
#  [12378, 30622, 9876, 15967, 2285, 375, 23768, 30559, 11891, 8077, 23555],
#  [30001, 33591, 6669],
#  [3556,
#   4352,
#   35928,
#   15241,
#   34590,
#   34755,
#   6669,
#   20242,
#   19083,
#   14282,
#   3556,
#   14920,
#   10927,
#   3556],
#  [4352,
#   35928,
#   28863,
#   35851,
#   13429,
#   27578,
#   4999,
#   32574,
#   30234,
#   30204,
#   32574,
#   3633,
#   27578],
#  [8843, 18483, 31262, 18234],
#  [69,
#   19626,
#   9611,
#   7284,
#   14892,
#   12165,
#   26952,
#   2875,
#   69,
#   15275,
#   15641,
#   8500,
#   21697],
#  [17829,
#   11123,
#   24406,
#   28681,
#   12269,
#   29643,
#   21758,
#   11575,
#   6415,
#   14282,
#   16330,
#   24903,
#   27273],
#  [16756, 17372, 15662, 1316, 17487, 6693, 11437, 29923, 20351, 11979],
#  [8901, 24993, 8828, 30559, 28887, 27613],
#  [15365, 32929, 25876, 24354, 12889, 8248, 22809, 13655, 5770],
#  [6580,
#   35429,
#   32000,
#   35294,
#   24430,
#   7436,
#   8844,
#   5814,
#   11172,
#   18534,
#   28880,
#   19291],
#  [30559, 16403, 33292, 7167, 33292, 30642],
#  [32531, 9996, 13733, 25268, 12486, 8909],
#  [22397,
#   21244,
#   9611,
#   33644,
#   8691,
#   17597,
#   34841,
#   21719,
#   35165,
#   30853,
#   22798,
#   34841,
#   21719,
#   2758,
#   30848,
#   8064],
#  [13733, 35439, 31832, 22687, 31859, 14265, 6669, 5770],
#  [33451,
#   899,
#   11084,
#   26156,
#   31675,
#   26952,
#   16168,
#   26952,
#   2127,
#   26952,
#   28805,
#   25841,
#   13222,
#   826,
#   26952],
#  [12323,
#   18669,
#   26952,
#   3730,
#   17276,
#   8178,
#   11054,
#   23837,
#   25190,
#   28841,
#   29293,
#   1145,
#   7636,
#   8535],
#  [27975, 17485, 2863, 9060, 9060, 10736, 17485, 15613, 25582, 4781, 15989],
#  [5450, 14905, 29237, 19480, 15670, 33482, 2660],
#  [33987, 24881, 29307, 11577, 23439, 14892, 4473, 21795, 32954, 28780, 32040],
#  [30534, 29899, 12968, 22233, 20648, 2660, 4999, 22233, 6669, 19452],
#  [4126, 34013, 4785, 35155, 22830, 13733, 12929, 25084, 15981, 24798, 10927],
#  [22017, 26137, 30694, 23338, 25808, 7407, 20094, 10820, 9464, 19480],
#  [14798,
#   318,
#   35082,
#   12362,
#   32519,
#   33090,
#   5377,
#   14798,
#   1642,
#   21623,
#   22023,
#   8077],
#  [11084, 5770, 12924, 10664, 3284, 3346, 31599, 1195],
#  [33266, 3346, 22564, 28008, 25919, 2888, 27605],
#  [8909, 6669, 28974, 30237, 4205, 30743, 6407, 32455, 30001],
#  [5058, 642, 20251, 27273, 12973, 7198],
#  [33075, 29049, 13655, 11998, 6669, 22430, 28745, 25426],
#  [20925, 10671, 21507, 10507, 9110, 1972, 15967, 30964],
#  [708, 30241, 9877, 25921, 18247, 5094, 26492, 23259, 14253, 31148],
#  [10445, 31838, 2480, 32396, 13414, 2607, 12114, 24838, 29315, 27578],
#  [14780, 15819, 13415, 32461, 13655, 15613, 14794, 6519, 15322, 14572, 11032],
#  [20642, 7592, 14905, 7553, 35801, 28780, 318, 1576, 19480],
#  [10664, 25751, 23282, 5608, 4739, 12753, 16880],
#  [25876,
#   24454,
#   12053,
#   8901,
#   10664,
#   30335,
#   18153,
#   16685,
#   31422,
#   11883,
#   20174,
#   17859],
#  [6169, 20860, 2409, 6669, 28974, 27056, 15613, 31411, 24406, 31845, 14905],
#  [16986,
#   69,
#   13429,
#   18518,
#   23086,
#   28745,
#   34830,
#   30559,
#   23086,
#   16396,
#   31571,
#   21789],
#  [17221,
#   11464,
#   5469,
#   24760,
#   6519,
#   33276,
#   19635,
#   12362,
#   23174,
#   15365,
#   6074,
#   6519,
#   19635],
#  [19480, 28974, 23240, 27792, 10664, 14900, 31962, 25542, 32984],
#  [7377, 2246, 2501, 11841, 10251, 31829, 150, 22023, 4746, 34447, 2501],
#  [14103, 22438, 376, 14233, 8077, 3174, 17268, 18234],
#  [13398, 34479, 14724, 17973, 34, 27273, 10909],
#  [33134, 26912, 27273, 30321, 4146, 18328, 10664, 19945],
#  [8558,
#   708,
#   14905,
#   14289,
#   5240,
#   6165,
#   2572,
#   20582,
#   21087,
#   27273,
#   20242,
#   14246,
#   11432],
#  [8843, 18483, 6669, 318, 10664, 5935],
#  [26960, 14233, 1980, 10507, 10909, 8953, 30658],
#  [17268,
#   15561,
#   19480,
#   15958,
#   34014,
#   28859,
#   15364,
#   708,
#   3942,
#   33434,
#   22845,
#   14905,
#   2369],
#  [28780, 14720, 25919, 9554, 29011, 13655],
#  [26197,
#   3275,
#   32145,
#   27968,
#   28682,
#   34338,
#   11151,
#   32368,
#   19480,
#   6783,
#   11594,
#   29923,
#   11432],
#  [26637, 11953, 7516, 29110, 28630, 15365, 30335],
#  [12486, 10664, 26052, 33135],
#  [23472, 30363, 30054, 4332, 52, 22689, 35783, 26952, 1064, 22700, 3080],
#  [34845, 11084, 1429, 32929, 3346, 26052, 7667, 6669],
#  [12486, 29454, 19207, 4732, 24903, 6669, 10909, 18914, 23482, 6691],
#  [15613, 13678, 4511, 3456, 11814, 26461],
#  [31148,
#   8722,
#   35418,
#   22162,
#   30493,
#   15232,
#   14905,
#   33862,
#   9987,
#   35418,
#   15657,
#   31275],
#  [18539,
#   17572,
#   23259,
#   14253,
#   12154,
#   33658,
#   19480,
#   10909,
#   18539,
#   12843,
#   25758,
#   25757,
#   30335,
#   22017,
#   14344],
#  [25676, 7705, 30559, 11775, 19480],
#  [23458, 28863, 15365, 10507, 17217, 20696, 28881, 29307, 12951, 24406, 19360],
#  [26052, 5311, 31148, 8722, 4973, 34479, 20242, 24860, 23626],
#  [15822, 7291, 11445, 6251, 11575, 19480, 9548, 23423],
#  [17396, 16218, 14285, 6669, 14233],
#  [13678, 4511, 5540, 20925, 10671, 33947, 18548, 13410, 32573, 14798],
#  [31496, 23480, 30141, 10350, 708, 19438, 19480],
#  [26052, 7667, 28336, 27273, 28974, 4723, 3346, 26380, 3456, 5058, 7667],
#  [5586, 15029, 11855, 1958, 837, 3209, 27624, 1801],
#  [26371, 16685, 7553, 27006, 23311, 26912, 14905, 27949, 10664, 31686, 42],
#  [27764, 28408, 27273, 22397, 21623, 11525],
#  [35801, 4925, 8901, 13195, 30335, 35801, 4925, 17125, 17315],
#  [15675, 27273, 10909, 25322, 28745, 18755, 2789, 13287, 31275],
#  [8722,
#   13678,
#   4511,
#   16685,
#   18018,
#   24406,
#   562,
#   30019,
#   14905,
#   26952,
#   20925,
#   10671,
#   22991,
#   14892,
#   28817],
#  [29307, 2641, 10507, 33783, 8077, 11936, 29307, 30848, 15137, 27790],
#  [23195, 13657, 28731, 17217, 21621, 9337, 6669, 28745, 13398, 12053],
#  [708, 14905, 12362, 6669, 14536, 15613, 30853, 12362],
#  [742, 35898, 27402, 24450, 9521, 11577, 21510, 10664],
#  [19407, 11226, 31148, 14233, 21623, 17801, 27228],
#  [34832, 13398, 20174, 17859, 6669],
#  [4530, 21887, 17125, 10927, 22643, 14905],
#  [30458, 18548, 18018, 27605, 32502, 33763, 20380, 14986],
#  [3790,
#   13855,
#   769,
#   19399,
#   27190,
#   8901,
#   25451,
#   30413,
#   22328,
#   12932,
#   2371,
#   26952,
#   33859,
#   18502,
#   15029],
#  [6737,
#   22357,
#   15613,
#   8901,
#   10909,
#   169,
#   26156,
#   22357,
#   15613,
#   3346,
#   35757,
#   19443,
#   12362,
#   9370,
#   15613,
#   5882,
#   1195,
#   20758],
#  [26052, 14083, 29307, 33134, 18182],
#  [4648,
#   28509,
#   28163,
#   9128,
#   25650,
#   34205,
#   20703,
#   18587,
#   30559,
#   69,
#   13733,
#   69,
#   32573,
#   33294],
#  [27723,
#   4999,
#   177,
#   10664,
#   34830,
#   29488,
#   18154,
#   12378,
#   4999,
#   24433,
#   34015,
#   34393],
#  [34479, 3403, 10902, 26751, 14103, 13604, 27273, 30853, 13655],
#  [27934, 8248, 21305, 23424, 2899, 21507, 35999, 18534, 9511, 12688],
#  [10319, 32394, 10502, 14586, 26614, 25233, 29307],
#  [21426,
#   26838,
#   528,
#   10079,
#   15810,
#   6669,
#   16126,
#   2081,
#   20283,
#   28745,
#   6068,
#   139,
#   29167,
#   29375],
#  [1734, 11274, 10385, 11151, 9404, 9404, 29893, 16888, 19480, 8430],
#  [28745, 31028, 11172, 13733, 11841, 10251],
#  [27624,
#   30815,
#   21031,
#   26765,
#   32984,
#   5608,
#   32303,
#   23282,
#   15365,
#   28780,
#   20592,
#   11594,
#   24599],
#  [11936, 27535, 21913, 27790, 30364, 22331],
#  [4530, 21887, 29250, 29307, 17791, 15365, 14892, 23512],
#  [13534, 3346, 4934, 13285, 30413, 5765, 8077, 4771, 11642],
#  [28399,
#   6549,
#   4382,
#   23990,
#   23311,
#   28745,
#   799,
#   190,
#   9746,
#   35494,
#   26380,
#   6669,
#   8094],
#  [7553, 15613, 1357, 12362, 20691, 4352, 2203, 27006],
#  [24993,
#   12889,
#   8248,
#   22809,
#   13655,
#   18534,
#   12889,
#   8248,
#   22809,
#   13655,
#   34015,
#   27718,
#   24765,
#   22748],
#  [4810, 28008, 26842, 9255, 20242, 899],
#  [23269, 4450, 6669, 4080, 1695, 14282, 34501, 3346, 33728, 33728],
#  [30383, 7553, 12486, 18745, 22991, 7223, 32929, 18745, 29080],
#  [35825, 2856, 29297, 23328, 24050, 10664, 21623, 25271, 375, 12951],
#  [6669, 1877, 13655, 32461, 13655, 1537, 20303, 2735, 12486, 2995, 33865],
#  [19083, 7434, 3791, 26397, 14798, 5327],
#  [4126, 708, 19438, 24611, 1304, 13073, 10427, 25652, 18534, 22845],
#  [21303,
#   18548,
#   32553,
#   17464,
#   32929,
#   17332,
#   10495,
#   8456,
#   10849,
#   25508,
#   17758,
#   14028],
#  [31686, 28628, 4352, 18589, 19480, 2516, 26758, 5245, 24726, 13195, 24972],
#  [585, 11575, 16396, 2945, 4003, 8909, 24406, 14636, 21305, 20574, 21305],
#  [148,
#   28628,
#   35110,
#   34750,
#   2572,
#   26067,
#   1812,
#   27827,
#   8077,
#   148,
#   18774,
#   27402,
#   21623,
#   21623,
#   734,
#   12999],
#  [30031, 22681, 24050, 7256, 30559, 29315, 5245, 18671, 32000, 25377],
#  [13429, 14905, 24611, 19592, 6725, 842, 22357, 29167, 15452, 1737],
#  [4003, 20574, 20564, 27578, 32455, 35294, 21319],
#  [9370, 13655, 11998, 27402],
#  [28419, 13655, 14798, 10664, 18323, 13655, 23403, 34469, 3112],
#  [30908, 24838, 27921, 28805, 11891, 20687, 24903, 28924, 18393, 27273],
#  [16119, 31028, 18534, 3549, 35018, 22991, 27801, 15412],
#  [34, 35314, 27190, 30458, 1454, 34901, 30458, 13195, 1899, 34901, 31473],
#  [22991, 29745, 19953, 13435, 34193, 22106, 30958, 32929, 15076],
#  [33089, 7167, 34475, 21282, 24821, 13398, 28780, 28745, 14408, 31307],
#  [3346,
#   12863,
#   14805,
#   22564,
#   9255,
#   26765,
#   9928,
#   31611,
#   28008,
#   6669,
#   31067,
#   8901],
#  [33934, 26380, 34869, 33942, 1046, 21662, 33934],
#  [34743, 28942, 974, 18567, 34837, 20630, 318, 18815, 3338],
#  [32157, 5404, 21507, 19480, 27164, 20770, 26126, 33539, 29307, 22653, 21658],
#  [33266, 30853, 30848, 22564, 17069, 31028, 25919, 956, 12229, 20886, 4539],
#  [35898, 28304, 3406, 28230, 34744, 34205, 14905],
#  [7970, 8399, 26960, 10010, 22279, 6669, 23311, 18310],
#  [34025, 24522, 21282, 15613, 8813, 2989, 15722, 26327],
#  [25676, 7705, 11575, 21881, 18534, 16278],
#  [14586,
#   17069,
#   18281,
#   28008,
#   15116,
#   14536,
#   10928,
#   26830,
#   23578,
#   8973,
#   12898,
#   14586],
#  [18234, 1245, 708, 19438, 2203, 5764, 376, 5540, 1411],
#  [4530, 21887, 23472, 35779, 32964, 19480],
#  [30883,
#   2554,
#   12744,
#   25092,
#   13490,
#   29429,
#   17758,
#   14798,
#   10307,
#   16898,
#   9902,
#   32088,
#   26464,
#   25012],
#  [20854, 7328, 23259, 14253, 6041, 16685, 1454, 14233],
#  [32215, 21765, 27723, 28881, 25582, 601, 31940, 23472],
#  [13254, 8840, 12362, 11002, 35641, 15365, 30763, 12362, 32573, 12687, 28316],
#  [33089, 17745, 33526, 8429, 33526, 20886, 3746, 14233, 27273, 10909],
#  [23460,
#   1357,
#   601,
#   27131,
#   28008,
#   18755,
#   34257,
#   16330,
#   23628,
#   11522,
#   27465,
#   29608,
#   32832,
#   18668,
#   60,
#   4439],
#  [3174, 33987, 31028, 6669],
#  [28780,
#   7085,
#   35338,
#   10664,
#   22397,
#   26952,
#   28780,
#   17320,
#   6669,
#   21244,
#   9611,
#   20457],
#  [13733, 3346, 35663, 13898, 31056, 14282, 11002, 16209, 6669],
#  [23472, 28521, 18967, 31262, 8901, 5764, 2058, 34479],
#  [20534,
#   24726,
#   7986,
#   2922,
#   9110,
#   33101,
#   9110,
#   2931,
#   13769,
#   15643,
#   9110,
#   21006],
#  [15251, 24001, 28605, 23152, 28745, 10650, 6882, 18234, 20242, 24860, 33831],
#  [9151, 30556, 21081, 1412],
#  [34481, 1812, 3346, 3456, 13158, 6669],
#  [25611,
#   15613,
#   29307,
#   15822,
#   842,
#   12362,
#   8172,
#   899,
#   32178,
#   15822,
#   842,
#   30559,
#   22555],
#  [4377,
#   19248,
#   23311,
#   8332,
#   31028,
#   20995,
#   19248,
#   7553,
#   20242,
#   15811,
#   15632,
#   3970],
#  [12496, 34701, 30335, 24454, 26052, 4284, 33748, 6169, 18825, 32088],
#  [12378,
#   31028,
#   241,
#   27279,
#   16599,
#   24954,
#   25626,
#   8435,
#   22118,
#   25092,
#   32164,
#   21282,
#   28256,
#   28256,
#   27279,
#   35038],
#  [2970, 27301, 4785, 11883, 23104, 20231, 26952, 15810, 24969],
#  [12323, 7044, 13034, 32360, 35494, 6669, 6669, 10192, 17501],
#  [34481, 14905, 23311, 17217, 27141, 23104, 23355, 15701, 1671, 3456, 15018],
#  [26067,
#   5764,
#   26838,
#   1755,
#   23311,
#   35523,
#   26909,
#   23311,
#   24558,
#   17069,
#   28963,
#   17320,
#   21623,
#   2635],
#  [3176, 26066, 35475, 11577, 21783],
#  [27543,
#   9521,
#   27317,
#   11909,
#   12362,
#   11992,
#   27273,
#   27723,
#   12295,
#   28156,
#   20848,
#   540],
#  [12378, 69, 26067, 111, 28745, 26397, 17661, 16140, 17959],
#  [23311, 25542, 32984, 24354, 30559, 15613, 23311, 24153],
#  [14296, 12486, 29054, 16591, 26952, 32300, 6844, 31405, 11362, 3835],
#  [19407, 4450, 28640, 33526, 28780, 28780, 23311, 15632, 16320, 20242],
#  [32795, 25582, 28008, 13655, 15156, 11841, 10251],
#  [21139, 9792, 11154, 17001, 19974, 7126, 21755, 2386],
#  [13195, 25919, 28324, 12974, 9701, 29167, 25569, 35263],
#  [4523, 35429, 24332, 7525, 16501, 22792, 30236],
#  [17351,
#   18182,
#   34516,
#   19102,
#   32660,
#   28256,
#   13655,
#   8248,
#   6849,
#   13655,
#   13906,
#   5425,
#   8197,
#   16750],
#  [29902, 13070, 20837, 1671, 28735, 34924, 24309, 346, 5770, 24338, 24338],
#  [29307,
#   13619,
#   21783,
#   13655,
#   18718,
#   29732,
#   18539,
#   14285,
#   12843,
#   27827,
#   29725,
#   11129,
#   20975,
#   33589,
#   35288,
#   1691],
#  [21623, 13796, 19945, 30492, 17823, 24726, 24486, 15498, 336],
#  [12525,
#   7223,
#   26282,
#   7693,
#   22809,
#   3970,
#   29307,
#   3372,
#   35082,
#   13777,
#   34663,
#   13777,
#   13733,
#   6199,
#   30413],
#  [9891, 5404, 10203, 4444, 15632, 17320, 15632],
#  [4352,
#   28711,
#   28225,
#   29323,
#   30812,
#   33646,
#   25725,
#   1411,
#   9987,
#   10488,
#   18534,
#   33831,
#   17448,
#   7546],
#  [29608, 10664, 8604, 15613, 3153, 26560, 29621, 25650, 14905],
#  [3346,
#   7367,
#   19626,
#   16084,
#   7553,
#   13898,
#   32553,
#   8077,
#   8020,
#   5385,
#   6423,
#   6669,
#   15839,
#   15632],
#  [10079,
#   28106,
#   10139,
#   4638,
#   19438,
#   28745,
#   11032,
#   32989,
#   28745,
#   31028,
#   13174,
#   30001],
#  [8722, 12154, 33658, 29157, 24903, 3976, 6669, 2291],
#  [4545, 1832, 7244, 9895, 15077, 12563, 2292, 20913, 3346, 14975],
#  [20925, 10671, 29869, 15422, 2866, 33488, 25876, 26173, 4781, 28817, 12225],
#  [9397, 15137, 20443, 1899, 899, 4319, 31132, 10928, 32977, 1346, 6932],
#  [1872, 1899, 6669],
#  [34025, 10664, 30335, 33987, 25561],
#  [28780, 32929, 33503, 29157, 30337, 34234, 18815, 3556],
#  [3791, 17758, 6669, 33658, 29697, 31771, 17549, 11084, 3942, 13316],
#  [32325, 19276, 937, 35214, 3456],
#  [21031, 4951, 13678, 4511, 23536, 16447, 1671],
#  [11647,
#   10664,
#   1583,
#   9296,
#   24981,
#   14798,
#   29893,
#   591,
#   7586,
#   15613,
#   18018,
#   34830,
#   31686],
#  [1192, 9370, 13070, 28521, 32117],
#  [13769,
#   19846,
#   25858,
#   8064,
#   9255,
#   26765,
#   13655,
#   32394,
#   28745,
#   2922,
#   23463,
#   31987],
#  [13209, 22532, 10406, 25092, 25919, 29307, 4342, 18328, 29307, 72, 11998],
#  [20702, 34208, 28731, 22564, 34208, 28731, 13340],
#  [34301, 34919, 23345, 29305, 16727, 11032, 2848, 5030, 2376, 10583],
#  [33787, 8901, 12908, 34479, 19407, 24161, 27078, 1922],
#  [6669, 15561, 2409, 7516, 295, 5385, 29608, 25228, 23311, 7256, 20860],
#  [30383,
#   33134,
#   31499,
#   3346,
#   21913,
#   27790,
#   30364,
#   35801,
#   5764,
#   34720,
#   26397,
#   28721],
#  [27208, 12654, 19110, 22074, 24406, 12997, 28780],
#  [7577, 15232, 29307, 27827, 28654, 27273, 27228, 30786, 16358],
#  [1309, 35541, 26836, 13906, 7167, 34475, 21382],
#  [1192, 20848, 34778, 19480, 33552, 15810, 21761, 2571, 3556],
#  [15522, 10909, 7436, 8844, 11172, 22564, 28847, 25582],
#  [27301, 259, 16, 13741, 18271, 34447, 8722, 27279, 12144, 10909],
#  [27624, 26188, 20086, 3176, 17217],
#  [14572, 23086, 7237, 20702, 15613, 28156, 20848],
#  [15613, 17175, 14905, 26052, 7667, 27402],
#  [23440, 11497, 20702, 15116, 32526, 27273, 14856, 29694, 18453],
#  [33526, 899, 32553, 12687, 25982, 13398, 14905, 28628],
#  [14905, 11129, 29307, 2058, 14208, 4489, 33118],
#  [27949, 10664, 35574, 5882, 16396, 22095, 32117, 29307, 28780, 29785],
#  [8722, 28780, 23311, 14062, 18534, 35288, 17973, 31262, 818, 28745, 818],
#  [27608,
#   10884,
#   10884,
#   23837,
#   24726,
#   24699,
#   22344,
#   20242,
#   18534,
#   19626,
#   15251,
#   24306],
#  [14798,
#   10909,
#   13410,
#   18659,
#   2313,
#   31028,
#   7553,
#   20925,
#   10671,
#   18358,
#   14662,
#   10304,
#   12951],
#  [27273, 10909, 21574, 14900],
#  [24227,
#   6415,
#   14282,
#   16325,
#   11883,
#   13534,
#   27273,
#   24227,
#   31028,
#   6415,
#   14282,
#   31028,
#   24227,
#   33070],
#  [6669, 19360, 14667, 5283, 22597, 3935, 35439],
#  [26367, 33526, 29397],
#  [33265,
#   9660,
#   16835,
#   30227,
#   2658,
#   31879,
#   18534,
#   8722,
#   16159,
#   27627,
#   34613,
#   13287],
#  [5935, 20174],
#  [20785,
#   3346,
#   3456,
#   9133,
#   21139,
#   31148,
#   9255,
#   28805,
#   11891,
#   21064,
#   1324,
#   7196,
#   10507],
#  [19901, 16685, 974, 20242, 9110, 12932, 7284, 21761, 24518],
#  [28881, 1123, 27624, 26479, 5764, 11206, 28974, 169, 31496, 27949],
#  [23999, 10443, 11814, 24678, 5756, 15364, 13649],
#  [30763, 26052, 7667, 2719, 25426, 17268, 18354, 10909],
#  [15365, 1287, 15074, 8901, 19442, 27551, 4604, 14282, 12759],
#  [6526,
#   29099,
#   12486,
#   10664,
#   7496,
#   6307,
#   14536,
#   14060,
#   31771,
#   13729,
#   16142,
#   26203],
#  [22375, 28514, 16648, 17639, 27273, 15285, 20565, 9758, 20474, 21445, 21137],
#  [10507, 21326, 28545, 29474, 11616, 30031, 12602, 12917, 33769],
#  [6669, 16396, 2584, 11175],
#  [7407, 2404, 5148, 28521, 21936, 34552, 32303, 31762, 16750],
#  [12295, 16501, 27056, 10566, 13741, 23263, 11282, 20702, 28745, 29315, 16501],
#  [17017, 31148, 6578, 26615, 4377, 22564, 33414],
#  [20844, 28805, 5764, 4483, 21087, 23335, 14603, 9937, 6669],
#  [13678,
#   19905,
#   18518,
#   26545,
#   14499,
#   20687,
#   27309,
#   2584,
#   16084,
#   13769,
#   7434,
#   11129],
#  [22017, 14690, 28268, 24838, 13398, 32227, 5594],
#  [32396, 17217, 31148, 26836, 13398, 17745, 34986, 30383, 13104, 34015],
#  [21244,
#   9611,
#   17320,
#   24227,
#   18838,
#   34479,
#   35286,
#   8077,
#   22397,
#   10396,
#   7085,
#   1174,
#   29958],
#  [11909,
#   1634,
#   5764,
#   16396,
#   21251,
#   16842,
#   32178,
#   14905,
#   25220,
#   29307,
#   20906,
#   2855],
#  [20005, 19635, 28780, 19635, 21621],
#  [25757, 2315, 22870, 19884, 27402, 25440, 12362, 1934],
#  [3384,
#   16395,
#   22546,
#   24232,
#   22870,
#   19884,
#   13898,
#   31762,
#   27273,
#   559,
#   17864,
#   28316],
#  [28613, 14913, 35999, 21761, 18369, 16685, 6669, 28877, 7850, 1153, 15584],
#  [770, 29167, 18659, 27272, 19954, 9110, 27273, 31028, 17758],
#  [24522, 11936, 12254, 10507, 13398, 15452, 607, 13441, 24050, 23927],
#  [13655, 35082, 32757, 6169, 19480, 34479, 20925, 10671],
#  [15364,
#   30559,
#   29931,
#   15365,
#   29307,
#   8901,
#   12362,
#   23628,
#   769,
#   19399,
#   26952,
#   35288,
#   20966,
#   30559],
#  [27808, 20242, 23882, 35288, 11205],
#  [5030, 25424, 5439, 13658, 3346, 601, 13389, 9604, 9648, 11084],
#  [9987, 976, 20590, 6669, 622, 9370, 24765, 14800, 20702, 622, 35999],
#  [9586, 10079, 29307, 12114, 12997, 14572, 23380],
#  [13195,
#   23990,
#   27273,
#   7413,
#   2024,
#   15613,
#   8830,
#   33413,
#   29157,
#   3137,
#   34015,
#   34230,
#   7154,
#   2125],
#  [26842, 27553, 34565, 19480, 21507, 13195, 21917, 22324, 24459, 9792, 31132],
#  [30458, 13195, 1899, 33488, 6169, 13209, 34, 18972, 6669, 3740],
#  [28590, 26015, 2858, 24522, 375, 33526, 22209, 3174],
#  [18390,
#   6722,
#   18838,
#   17755,
#   10999,
#   4209,
#   19248,
#   14632,
#   26371,
#   19063,
#   23776,
#   31148,
#   6669,
#   35190],
#  [10888, 11610, 7803, 2931, 3690, 8172, 3690, 7861, 5222, 13655, 11610],
#  [15822, 9277, 19160, 28415, 20380, 27685],
#  [28590,
#   29244,
#   10795,
#   16591,
#   21759,
#   35779,
#   18718,
#   25887,
#   6169,
#   14892,
#   14798,
#   13328,
#   27723],
#  [12486, 10664, 28008, 34997, 26173, 11855, 12150, 5027, 19723],
#  [11084, 25988, 18137, 13898, 25092, 13429, 23472, 20332, 7484, 6669],
#  [15029,
#   11855,
#   24954,
#   27370,
#   30105,
#   2584,
#   20242,
#   4994,
#   10515,
#   31028,
#   4673,
#   30001],
#  [10427, 11432, 34479, 8843, 18483, 27273, 26096],
#  [29742, 23963, 19210, 13398, 1764, 23311, 22991, 26836],
#  [25005, 19835, 25529, 30389, 10664, 27801, 22991],
#  [6932, 31686, 12363, 30335, 23837, 4342, 31710, 14892, 28745],
#  [6566, 11298, 899, 26380, 18972],
#  [9978, 24042, 1769, 11157, 21636, 1769, 8986, 13525, 15869, 15643, 6592],
#  [26067, 111, 13070, 13070, 34546, 1411],
#  [23992,
#   28399,
#   18464,
#   11238,
#   22643,
#   6669,
#   4126,
#   25893,
#   31148,
#   14572,
#   18234,
#   7547],
#  [4648, 28509, 29049, 18600, 31644, 30559, 31921, 13733, 32003, 13655],
#  [8901,
#   4867,
#   29293,
#   19480,
#   28974,
#   32117,
#   33526,
#   31438,
#   26015,
#   34837,
#   20630,
#   30534,
#   12951],
#  [6299, 13209, 17261, 601, 19291],
#  [5468,
#   17221,
#   22194,
#   29157,
#   628,
#   8077,
#   28256,
#   28156,
#   20848,
#   18534,
#   1063,
#   14798],
#  [14905, 8532, 17604, 12602, 8390, 21305, 25271],
#  [2246, 7499, 25582, 2501, 23069, 11841, 10251],
#  [24354, 3346, 1512, 26282, 20242, 31028, 15116, 11084, 31148, 28780],
#  [12378,
#   32945,
#   33653,
#   5522,
#   2409,
#   21282,
#   31496,
#   23675,
#   31607,
#   7612,
#   19151,
#   12924],
#  [18518, 24981, 708, 19438, 11891, 27624, 14905, 35286],
#  [14282,
#   22797,
#   2081,
#   10788,
#   8077,
#   12896,
#   6417,
#   28415,
#   19392,
#   14233,
#   15064,
#   2081,
#   8665,
#   23453],
#  [5882, 24954, 3692, 5882, 3751],
#  [30157, 22357, 12753, 7468, 21282, 35583],
#  [2122, 13788, 22643, 27316, 7958, 29307, 28745, 34481, 16396],
#  [1671, 13410, 27975, 17485],
#  [24050,
#   10664,
#   34469,
#   17268,
#   1764,
#   31028,
#   13724,
#   13398,
#   26871,
#   28008,
#   27977,
#   8180],
#  [5581,
#   17726,
#   14423,
#   18358,
#   2404,
#   8843,
#   18483,
#   33266,
#   10884,
#   25163,
#   11417,
#   4473],
#  [1192,
#   13619,
#   33037,
#   18488,
#   24522,
#   31028,
#   16119,
#   31431,
#   21981,
#   21043,
#   26203,
#   16685,
#   3870,
#   1620],
#  [19954, 21081, 708, 11617, 6669, 10909, 2989, 5209, 8619],
#  [22870, 19884, 20648, 899, 11376, 10664, 12486, 10664, 4723, 4951],
#  [10139, 3436, 25442, 710, 18593, 3034, 3746, 33134, 20005, 710, 22892],
#  [28745, 22991, 4332, 26754, 4999, 9810, 17878],
#  [23963, 19210, 9255, 29923, 34025, 14905],
#  [15613, 21236, 28576, 13451, 969, 10822, 31422, 52, 35082, 15462],
#  [16262, 4901, 12968, 22233, 21561, 20254, 28881, 451],
#  [21887, 27624, 16779, 9464, 1620, 8843, 13724, 1620],
#  [2584,
#   18910,
#   6669,
#   10909,
#   24860,
#   4580,
#   31771,
#   14892,
#   24165,
#   11070,
#   22357,
#   17000,
#   23458],
#  [33, 3338, 27718, 11432, 10485, 17172, 24338, 27934],
#  [15972, 17268, 26469, 21139, 8722, 11936],
#  [32757, 27273, 112, 12332, 17758, 21308, 15521, 1811, 25537],
#  [6633, 11226, 34469, 24406, 29621, 33652, 26397, 34469, 31561],
#  [10664, 28745, 1201, 6669, 19025, 6401, 4199, 3831, 31390, 35429],
#  [20886,
#   28605,
#   23152,
#   14183,
#   2758,
#   14719,
#   4585,
#   826,
#   24001,
#   18899,
#   9792,
#   13704,
#   18668,
#   16680,
#   19167],
#  [30645, 3346, 3456, 18050, 27624, 27509, 11891, 3456, 18617],
#  [26736, 6669, 28745, 24354, 18518, 22991],
#  [35288, 11205, 9519, 29080, 35580, 25876, 4849, 9519, 29080],
#  [3346,
#   190,
#   14670,
#   4781,
#   11883,
#   19480,
#   16497,
#   34128,
#   6104,
#   14670,
#   11883,
#   34342],
#  [22952,
#   28308,
#   19110,
#   69,
#   12205,
#   29608,
#   34778,
#   29315,
#   13414,
#   69,
#   15789,
#   14407],
#  [30853, 11617, 25033, 9990, 10860, 34122, 31930, 16021, 12154, 10969, 35350],
#  [4648, 28509, 32326, 7085, 30853, 13655],
#  [4719, 6074, 15365, 16591, 21981, 25271, 19248, 28408],
#  [15365, 12109, 13655, 6669, 34481, 9611, 13655, 20537],
#  [13195, 24969, 9666, 13464, 10411, 29157, 27228, 23086, 32031],
#  [22952, 15412, 19900, 30031, 22280, 26105, 8901, 10909, 169, 29278],
#  [35679, 4648, 28509, 35745, 13034, 34841, 12283, 30001],
#  [13659, 5269, 15029, 11855, 27790],
#  [30848, 28805, 6669],
#  [19110, 23904, 29701, 26754, 5764, 23904, 29953, 16084, 13606, 13168],
#  [23311, 8901, 15613],
#  [18390, 29797, 16983, 31571, 13655, 10928, 10999, 13466, 14541, 31132],
#  [883, 32929, 883, 32929, 12486, 27402, 13168, 883, 32929, 7553, 21251],
#  [12687, 4103, 21795, 6669, 28805, 33134, 10664, 3346, 33134, 17758],
#  [27785, 11417, 956, 24338, 24012, 3498, 27785, 11417],
#  [4849, 7499, 22091, 6669],
#  [12486,
#   29454,
#   8669,
#   32631,
#   13741,
#   25833,
#   19480,
#   3346,
#   13741,
#   14900,
#   15424,
#   3951,
#   8841,
#   32455],
#  [32461, 19480, 34014, 6378, 28404, 14873, 30853, 24614, 30853, 16648, 15452],
#  [13195, 15613, 18100, 111, 12362, 27273, 10909, 3556],
#  [32531,
#   14798,
#   31028,
#   15613,
#   9611,
#   7284,
#   12932,
#   7284,
#   3551,
#   15843,
#   9877,
#   27195,
#   26518],
#  [4892, 9255, 26765, 13655],
#  [33987, 5137, 1937, 12310, 31358, 18551, 21062, 31910, 35745, 20417, 19225],
#  [20925, 10671, 30853, 30019, 33089, 14798, 10909, 13410, 14499, 1454],
#  [24993, 28509, 18390, 35745, 13034, 27718, 3923, 4177, 27617],
#  [21607, 35076, 18677, 4735, 8830, 32452, 16396, 14798, 11540, 9696],
#  [6169, 29161, 24338, 8076, 6669, 14014, 27718, 29161, 18815, 29178],
#  [6578, 15981, 19151, 24661, 4007, 32303, 25396, 14818, 29375, 26916],
#  [3556, 12378, 23054, 30368, 26952, 16160, 17758, 22342, 22095, 34938],
#  [32929, 13398, 16230, 15365, 1583, 9296, 28745, 19740, 14233, 22170],
#  [19480, 20587, 25812, 4735, 8830, 32452, 28613, 15541, 23423, 15156],
#  [1357,
#   24864,
#   16639,
#   20418,
#   10113,
#   3767,
#   27642,
#   35587,
#   21795,
#   24181,
#   27624,
#   29929],
#  [2171,
#   6725,
#   21469,
#   35999,
#   15613,
#   30565,
#   22527,
#   23008,
#   5764,
#   26696,
#   35999,
#   20380,
#   11997,
#   35494],
#  [30853,
#   9133,
#   34462,
#   9371,
#   26952,
#   17928,
#   19174,
#   21139,
#   16782,
#   17221,
#   28745,
#   15541,
#   16316,
#   31132],
#  [22185,
#   8901,
#   35288,
#   11205,
#   6232,
#   5058,
#   4648,
#   27694,
#   8077,
#   21909,
#   8536,
#   33690,
#   8077],
#  [20648, 24065, 33954, 28863, 20242, 23028, 21282],
#  [15365, 33186, 33136, 22512, 28008, 15541, 6669],
#  [24211, 27701, 20648, 11084, 2922, 31961, 21305, 12053, 14905, 17745],
#  [5594, 21913, 27790, 30364, 11445, 26468, 20996],
#  [34597, 27124, 28721, 23311, 23578, 15786, 30001],
#  [4999, 17758, 25919, 23331, 8103, 29697],
#  [21813, 4530, 15033, 16395, 22017, 3384, 28509, 14214, 34014, 27921],
#  [12378,
#   5764,
#   16396,
#   32830,
#   31038,
#   1244,
#   33186,
#   9548,
#   15229,
#   29621,
#   29412,
#   21282,
#   33158],
#  [6669, 31028, 7550, 13398],
#  [3697, 708, 30848, 12973, 30413, 11123, 3697, 7553],
#  [23328, 11919, 18486, 27295, 35082, 31461, 14667, 21740, 13658, 6669],
#  [15365, 4892, 5664, 28745, 29701, 11594, 12687, 12237],
#  [3587,
#   708,
#   35801,
#   14233,
#   3436,
#   31148,
#   8077,
#   19813,
#   16084,
#   28256,
#   19680,
#   16084,
#   6669],
#  [9611, 7284, 11575, 8795, 9611, 7284],
#  [14670, 20848, 376, 32502, 18234, 16497, 34128, 18815, 7447, 32443],
#  [27723, 5724, 29237, 26910, 18593, 18534],
#  [27716, 22870, 19884, 6669],
#  [1671, 11575, 20702, 12217, 28780, 28745, 28963, 33075, 27723],
#  [780,
#   28225,
#   23882,
#   24935,
#   7167,
#   708,
#   27309,
#   16639,
#   10507,
#   28069,
#   4450,
#   13451,
#   24637],
#  [33987,
#   30364,
#   14162,
#   17312,
#   15116,
#   12146,
#   19182,
#   7702,
#   29575,
#   4315,
#   23118,
#   31045],
#  [24661,
#   22297,
#   22054,
#   35082,
#   30848,
#   12114,
#   28594,
#   29522,
#   3811,
#   24661,
#   4007,
#   18588,
#   33947],
#  [3970, 5404, 20848, 18522, 33934, 14491, 11936, 1034, 31132],
#  [32929, 10876, 14063, 7102, 11569, 24737, 32977],
#  [33070, 18718, 3456, 10909, 8930, 16685, 28009, 7829, 25478],
#  [6669, 35082, 20702, 11084, 25561, 23399, 30243, 1777, 30942, 29092],
#  [31771,
#   27857,
#   25086,
#   24324,
#   8197,
#   28745,
#   25611,
#   69,
#   23472,
#   4910,
#   9792,
#   28963,
#   19368],
#  [30234, 3633, 18745, 35340, 35714],
#  [6199,
#   24406,
#   607,
#   8901,
#   4785,
#   24860,
#   18706,
#   28206,
#   12486,
#   29454,
#   27568,
#   10350,
#   14588,
#   5916],
#  [2856, 13655, 12361, 21303, 26952, 16591, 15116, 17865, 21236, 4723, 28239],
#  [12378, 33917, 19292, 19900, 21282, 10664, 13451, 13451],
#  [13034, 14674, 4352, 18589, 31686, 28628, 19480, 2516, 24358, 25264, 16685],
#  [12378,
#   29307,
#   28974,
#   24406,
#   20491,
#   17862,
#   12358,
#   20238,
#   28745,
#   10664,
#   15613,
#   27739],
#  [5764,
#   2058,
#   13657,
#   6669,
#   742,
#   35898,
#   31262,
#   6169,
#   11361,
#   29315,
#   11361,
#   11426],
#  [7553, 3346, 16, 9255, 11575, 19680, 826, 3174, 30642, 1309],
#  [23104, 11259, 19328, 20590, 18534, 10909, 26684],
#  [26428, 3346, 14233, 708, 18738, 3976, 31148, 27228],
#  [708,
#   25271,
#   24227,
#   21244,
#   9611,
#   24981,
#   9529,
#   1872,
#   34479,
#   5814,
#   28745,
#   16781,
#   20887],
#  [30559, 16866, 33900, 27273, 29307, 9548, 13755, 13788, 25214, 20002],
#  [2246,
#   11841,
#   10251,
#   4384,
#   5110,
#   25582,
#   2501,
#   14905,
#   7499,
#   5764,
#   7653,
#   32394,
#   5764],
#  [27273, 10909, 35102, 32303, 24738, 17230, 12837, 12837, 32795],
#  [17000, 23259, 14253, 10485, 14905, 2758, 24611, 25939, 23453, 4439],
#  [24065, 1583, 9296, 27827, 18018, 14905, 18669, 9076, 18018, 24474, 16756],
#  [6939, 17273, 22413, 9495, 15612, 29092, 267, 899, 29515, 1769],
#  [15773,
#   4540,
#   15541,
#   13415,
#   6669,
#   25650,
#   27273,
#   15541,
#   31435,
#   25812,
#   14905,
#   21634,
#   13655,
#   26952,
#   14295,
#   23104,
#   27260],
#  [27977, 8180, 3456, 14026, 27624, 15727, 27921, 15717],
#  [35168, 13655, 25919, 15129, 20590, 13655, 23104, 10820, 10999],
#  [26281, 29323, 24406, 13717, 30270, 24338, 24012, 28745, 15613, 13724],
#  [15365, 29357, 18310, 17000, 14149, 1229, 6169, 3843, 25454],
#  [16535, 3460, 12486, 27827, 5966, 5593, 27532, 26836],
#  [5764,
#   33007,
#   13034,
#   32360,
#   34649,
#   9660,
#   35393,
#   23311,
#   3434,
#   24318,
#   10691,
#   32623,
#   34360,
#   4785,
#   1138],
#  [1192, 3556, 28316, 28316, 285, 19706, 28745, 28316, 30383],
#  [30234, 26052, 4284, 28377, 13286, 18959, 13729, 19201],
#  [30559, 11577, 17125, 14536, 17268, 6669, 2222],
#  [16591, 17069, 17320, 17069, 1815, 15865, 21761, 708, 23289, 31470, 29307],
#  [14690,
#   26842,
#   10087,
#   15122,
#   22536,
#   15259,
#   27228,
#   20480,
#   13599,
#   19884,
#   13132,
#   16640,
#   34427],
#  [4648, 10507, 30559, 24354, 23354, 28255, 29395, 7901, 28767, 32379],
#  [4648, 8901, 31148, 24738, 17230, 29621, 32303],
#  [30112, 23354, 24916, 17549, 25744, 9611, 7284],
#  [29742, 13398, 19110, 23904, 32455, 30559, 28745, 712],
#  [14798, 32757, 11288, 17611, 23480, 6691, 18838, 17268, 21282],
#  [1759,
#   19940,
#   16159,
#   35755,
#   7463,
#   10546,
#   27605,
#   32837,
#   4699,
#   18567,
#   7015,
#   35314,
#   21282],
#  [2313, 9548, 14798, 10909, 13410, 27193, 11800, 3888, 17837],
#  [3346, 19629, 6932, 28203, 29307, 16396, 7553, 13655, 18534],
#  [31832, 22687, 31859, 14265, 27827, 7075, 25582, 3346, 6890, 464, 24477],
#  [956, 19954, 1064, 3209, 13796, 13398, 31028, 18518, 9133, 12486],
#  [33526, 35082, 7553, 26962, 9877, 17069, 14873, 16193],
#  [20007, 30019, 34109, 607, 14233, 6199, 4146, 1411, 28226, 29725],
#  [18390, 27273, 10909, 29250, 25272],
#  [19609, 15090, 9977, 27624, 13381, 5540, 33134, 16763, 11495, 13619],
#  [27975, 17485, 24387, 26952, 29250, 19635, 24387],
#  [20886, 1583, 9296, 14905, 15010, 6669, 28630, 1576, 7505],
#  [4739,
#   8077,
#   8901,
#   17487,
#   23952,
#   29574,
#   16982,
#   17082,
#   33478,
#   6469,
#   23311,
#   29307,
#   8532,
#   13415,
#   4493,
#   11856,
#   1452],
#  [708,
#   20534,
#   559,
#   936,
#   17472,
#   13733,
#   13254,
#   15584,
#   35992,
#   28545,
#   34798,
#   14991],
#  [28985,
#   15298,
#   11902,
#   30642,
#   7346,
#   10328,
#   11495,
#   14306,
#   34257,
#   32325,
#   23421,
#   4973,
#   18698,
#   27064,
#   899,
#   27534,
#   25215,
#   13655,
#   21730],
#  [9241, 23619, 21305, 27624, 8248, 9996, 998, 29742, 26637, 32303],
#  [20876, 25676, 7705, 18581, 9548, 27087, 23675, 21881, 5404, 4254],
#  [30559, 4849, 31496, 3767, 2584, 28521, 6669],
#  [13398,
#   8823,
#   8172,
#   11344,
#   27190,
#   5764,
#   24678,
#   23675,
#   29146,
#   33934,
#   28745,
#   23311],
#  [14809, 13657, 28156, 9464, 20242, 19480],
#  [32475, 31028, 12865, 29697, 8178, 30393, 7015],
#  [27534, 14581, 28780, 15116, 6401, 12973, 12393, 26139, 10939, 17268, 11298],
#  [13678,
#   12358,
#   1811,
#   13373,
#   3630,
#   34262,
#   745,
#   13921,
#   28255,
#   31503,
#   8561,
#   7264,
#   6839,
#   8901,
#   10909,
#   169,
#   21909,
#   15632,
#   33984,
#   11002,
#   29391,
#   13373,
#   32258],
#  [7283, 35082, 6669, 4835, 16882],
#  [27949,
#   20192,
#   15364,
#   12114,
#   10664,
#   10079,
#   2638,
#   3828,
#   4638,
#   4951,
#   4951,
#   22342,
#   15810],
#  [33526, 29307, 10909],
#  [18018,
#   13410,
#   13534,
#   26836,
#   34973,
#   20925,
#   10671,
#   14156,
#   13678,
#   4511,
#   34537,
#   29220],
#  [32574, 30576, 27821, 26836, 12393, 33780, 26758],
#  [33007, 13398, 28408, 27578, 24522, 13898, 15249, 15865],
#  [12997, 15613, 5882, 30559, 451, 17125],
#  [18018, 4781, 19480, 27975, 17485, 9060, 18369],
#  [6068, 670, 29090, 1769, 28256, 8077, 7803, 9641, 19797, 28576, 18592, 32849],
#  [26052,
#   14083,
#   23311,
#   8077,
#   6669,
#   18401,
#   606,
#   14083,
#   19480,
#   31978,
#   16854,
#   14798],
#  [2947, 29307, 10909, 23086, 12378, 25389],
#  [28780,
#   12117,
#   2603,
#   7468,
#   31028,
#   27624,
#   21236,
#   19167,
#   26753,
#   4999,
#   29515,
#   24969,
#   15505],
#  [26052, 23963, 30926, 31710, 17320, 4026, 33589, 31047, 14670, 10006],
#  [17487, 35168, 13655, 35675, 13655, 35082, 12572],
#  [16750,
#   2633,
#   13464,
#   10411,
#   28008,
#   22564,
#   4530,
#   24487,
#   10861,
#   22564,
#   29288,
#   18534],
#  [20126,
#   30862,
#   25467,
#   434,
#   19884,
#   11084,
#   17069,
#   27056,
#   18534,
#   29341,
#   22643,
#   10353,
#   25326],
#  [13398, 27301, 259, 16983, 25389, 21006],
#  [29278, 8077, 6769, 22513, 10507, 10909, 16685],
#  [7569, 15270, 17733, 27578, 29375, 30191, 1192, 23069, 9886, 26637],
#  [33996,
#   11495,
#   16544,
#   4545,
#   24050,
#   17639,
#   13373,
#   5764,
#   3346,
#   17402,
#   31028,
#   11129],
#  [35999, 15613, 12102, 23755, 6423, 7434, 10664, 3275, 26952, 31383],
#  [32929,
#   28408,
#   4225,
#   25713,
#   18205,
#   7452,
#   12358,
#   33089,
#   15365,
#   7452,
#   12358,
#   26066,
#   35026],
#  [25887,
#   28881,
#   16591,
#   16599,
#   17320,
#   17069,
#   13070,
#   21759,
#   35779,
#   10664,
#   2719,
#   27908,
#   12361],
#  [19442, 4108, 6367, 2660, 11610, 4739, 11923, 19623, 4973, 24604],
#  [5645, 13796, 27014, 13655, 35082, 12295, 33089, 13796],
#  [21282,
#   34997,
#   6669,
#   3976,
#   30556,
#   31702,
#   14798,
#   35082,
#   13733,
#   26952,
#   10507,
#   32021],
#  [13195, 899, 17975, 30763, 33186, 33136, 15365, 23086, 14798],
#  [29250,
#   19900,
#   14536,
#   32409,
#   19969,
#   13882,
#   664,
#   18354,
#   16035,
#   18718,
#   21765,
#   11648,
#   190,
#   12053],
#  [29157, 29278, 34901, 17493, 31176],
#  [10465, 28860, 18328, 10664, 26688, 29621, 10465, 29279, 23311, 27316],
#  [4034,
#   28721,
#   1576,
#   14245,
#   15306,
#   5311,
#   10698,
#   25151,
#   19480,
#   21617,
#   20380,
#   28178,
#   24981],
#  [5859, 10949, 7942, 4301, 25744, 24699, 22344, 20242, 3970, 22527],
#  [27412, 21761, 19870, 27624, 22338, 31148, 23269, 11032, 34015, 27273, 11556],
#  [13678, 19905, 32771, 12467, 2122, 16084, 27705, 12160, 3164],
#  [13714,
#   12951,
#   28408,
#   7868,
#   31275,
#   5882,
#   24860,
#   33440,
#   30853,
#   26173,
#   26765,
#   27790],
#  [9586,
#   24354,
#   3346,
#   5882,
#   12362,
#   19083,
#   1723,
#   27228,
#   15613,
#   22712,
#   18518,
#   13636,
#   12362],
#  [19451, 6669, 33037, 18488, 11084, 27571, 69, 33463, 14499, 3528],
#  [4026, 13883, 5413, 2522, 25300, 28745, 13398, 19954],
#  [31262, 27921, 24354, 14488, 26038, 18534, 17125, 20702],
#  [25758,
#   7415,
#   3346,
#   27273,
#   28256,
#   13782,
#   16209,
#   32396,
#   30853,
#   28576,
#   12295,
#   20848],
#  [25582, 26052, 5311, 24289, 8077, 13657, 5764, 473, 12486, 13465, 6882],
#  [27975, 17485, 24611, 5604, 11376, 4810, 27624, 30853, 13410],
#  [18879,
#   28745,
#   35082,
#   13655,
#   23578,
#   22808,
#   69,
#   24050,
#   10664,
#   30001,
#   33591,
#   16830],
#  [32929, 9548, 9604, 2081, 19407, 20242, 14667, 3942],
#  [27716, 6097, 6669, 1192],
#  [34481, 6666, 14960, 11577, 23467, 27273, 1571],
#  [13479, 3578, 6669, 11610, 35485],
#  [25357, 30848, 35779, 22527, 17320, 21530, 3694, 17664, 16869, 14339],
#  [24522, 12486, 11806, 28195, 16396, 26000, 28717, 6281],
#  [5770, 1480, 12843, 18587, 10203, 13655, 21202, 29836, 52, 25625],
#  [32837, 4999, 28509, 30559, 19966, 961],
#  [25528, 13937, 27651, 22786, 18617, 18815, 4444, 15632, 17758, 19480],
#  [1585,
#   12323,
#   22266,
#   26952,
#   15029,
#   17217,
#   11172,
#   14282,
#   2128,
#   14722,
#   26707,
#   14722,
#   26707,
#   29891,
#   10664,
#   34830],
#  [7198, 26371, 8722, 27472, 27228, 33954, 10472],
#  [17268, 29203, 31686, 16936, 14083, 16591, 6669, 22974],
#  [8077,
#   14419,
#   27968,
#   11575,
#   8843,
#   8302,
#   708,
#   29528,
#   27707,
#   25151,
#   13655,
#   27968,
#   11575],
#  [12378,
#   8,
#   10452,
#   9109,
#   8077,
#   8761,
#   6592,
#   34234,
#   31771,
#   25712,
#   20806,
#   23104,
#   4739],
#  [14407, 21574, 14900, 34447, 8901, 30853, 13007, 29397],
#  [22527, 26836, 1938, 14802, 26952, 27377, 11123, 30559, 24738, 8399],
#  [742,
#   35898,
#   12787,
#   22952,
#   24993,
#   10507,
#   13449,
#   29307,
#   34747,
#   33680,
#   11157,
#   6288,
#   20848],
#  [32929,
#   32929,
#   19480,
#   5385,
#   10785,
#   13659,
#   13398,
#   5594,
#   18100,
#   111,
#   4529,
#   24981],
#  [35168, 22991, 35189, 21759, 20491, 35314, 4352, 10507, 22690],
#  [16591, 2081, 1815, 10192, 17069, 21940, 1815, 16685, 17069],
#  [19629, 23311, 24084, 16854, 22357, 14779, 10507, 8986, 4129, 31148, 23837],
#  [32744, 13655, 6333, 27559, 34193, 24765, 19110, 23904, 30050, 13451, 17369],
#  [3346, 8953, 16779, 34205, 22974, 20848, 22746, 8230, 23028, 18093, 8457],
#  [30001, 33591, 6669, 17273],
#  [29518, 32553, 22357, 28780, 976, 20590, 6669, 28255, 29395, 31262],
#  [32574,
#   20592,
#   32303,
#   19110,
#   11321,
#   11432,
#   21730,
#   26952,
#   30031,
#   22991,
#   19314,
#   20592],
#  [29157,
#   9486,
#   31435,
#   12934,
#   31435,
#   13655,
#   6669,
#   11053,
#   28576,
#   30321,
#   106,
#   25289],
#  [9977, 34479, 27078, 8172, 15613, 31411, 24406, 14905],
#  [31755, 18234, 6524, 6528, 10507, 31689, 22357, 34830, 3535, 3535, 7553],
#  [18539,
#   11891,
#   13429,
#   3346,
#   35214,
#   24765,
#   2922,
#   6165,
#   14282,
#   25919,
#   4951,
#   10124,
#   14233,
#   18539],
#  [11610, 34469, 29305, 21955, 12806, 14103, 8532, 3549],
#  [3346, 6429, 24860, 31148, 451, 26615, 22357, 20242, 27056],
#  [10664,
#   3456,
#   13678,
#   4511,
#   24838,
#   33555,
#   7116,
#   190,
#   16497,
#   34128,
#   4570,
#   34633],
#  [2087, 4785, 8901, 17217],
#  [11610, 20702, 3635, 29011, 13655, 15521, 12352],
#  [30534,
#   23626,
#   31879,
#   17631,
#   30534,
#   8532,
#   6621,
#   34102,
#   29307,
#   10909,
#   12567,
#   10909],
#  [34301, 6669, 10664, 15981, 3605, 35347, 12419, 24903, 3346, 16320, 24856],
#  [33468,
#   31877,
#   30853,
#   35082,
#   30559,
#   15613,
#   69,
#   14798,
#   10909,
#   8722,
#   6199,
#   30458,
#   9495,
#   32502,
#   33763],
#  [7970, 8901, 6097, 15967],
#  [25961, 17517, 12997, 23311, 17424, 4999, 14718, 13724, 34557],
#  [14536, 13733, 4320, 35925, 23963, 19210, 16396, 4648, 8901],
#  [1123, 9604, 2081, 9035, 17554, 28239, 7788, 9035, 11665, 26380],
#  [28255, 29395, 33950, 12951, 20648, 33950, 3346, 22564, 6669, 11415, 3528],
#  [26842, 26188, 29725, 29307, 9937, 31472, 13655, 6669],
#  [32574, 8125, 27809, 11376, 17523, 20762, 33491, 16330, 21623, 5764, 35773],
#  [12363, 13254, 8840, 4439, 20648, 13655, 1811, 6100, 28695],
#  [6701,
#   32366,
#   29198,
#   20574,
#   34014,
#   29125,
#   20848,
#   28408,
#   33282,
#   5764,
#   31500,
#   24429,
#   26952,
#   22960],
#  [15613, 1245, 976, 15613, 3751, 12312, 12312, 7693, 20848, 29307],
#  [13398, 20174, 27402, 15365, 17268, 6669],
#  [13247,
#   9110,
#   17664,
#   16869,
#   13655,
#   24322,
#   27969,
#   30504,
#   23837,
#   33947,
#   6277,
#   35434,
#   27102],
#  [29315, 22395, 24012, 13655, 708, 4785, 8901, 33089, 13869],
#  [2742, 769, 19399, 13209, 8901, 17221, 20932, 35739, 12913, 32840],
#  [9255,
#   6669,
#   24227,
#   16235,
#   21244,
#   9611,
#   21623,
#   487,
#   10396,
#   33991,
#   25395,
#   24227,
#   7873,
#   20164,
#   24227],
#  [4539, 6578, 6259, 12917, 8131, 12154, 33658, 21865],
#  [24354, 9758, 35314, 1695, 31472, 6669, 16357, 24793, 13398, 29608, 12687],
#  [11648,
#   607,
#   21607,
#   11495,
#   2880,
#   27949,
#   10664,
#   6691,
#   18339,
#   10507,
#   29341,
#   34475,
#   25624,
#   7803,
#   13655],
#  [34516, 2340, 15351, 2087, 9548, 6983, 13451, 969, 13655, 27792],
#  [14670, 845, 22026, 18637, 23805, 24486, 19480, 2516, 4352, 18589],
#  [20144,
#   24505,
#   24661,
#   4007,
#   16806,
#   30973,
#   13501,
#   1652,
#   4342,
#   27457,
#   16806,
#   30973,
#   13501,
#   2488],
#  [24354, 16235, 9977, 20174, 16756, 8901],
#  [26490,
#   17878,
#   35418,
#   23986,
#   17878,
#   491,
#   16084,
#   17878,
#   30034,
#   17878,
#   21006,
#   8722,
#   23338,
#   17320,
#   6669,
#   16259,
#   6169,
#   31148,
#   32455,
#   25656],
#  [1843, 5859, 23311, 33526, 16685, 708, 607, 29307, 4121, 6627],
#  [2641,
#   8901,
#   22357,
#   32000,
#   21282,
#   5770,
#   13655,
#   31715,
#   18687,
#   10664,
#   7167,
#   34475],
#  [28780, 23882, 24935, 15967, 29843, 19480, 5935, 23480, 30964],
#  [14905, 8901, 10909, 169, 69, 11432, 31028, 15613, 35551, 21761, 24556, 8077],
#  [9990, 32422, 22279, 7553, 17487, 29088, 32422, 27475],
#  [15365, 12932, 27510, 34294, 16316],
#  [23259,
#   14253,
#   22643,
#   15613,
#   34051,
#   16396,
#   9417,
#   34854,
#   25939,
#   10575,
#   25390,
#   28978],
#  [18583, 29495, 35805, 6669, 10909, 7553, 28721, 2758, 16677, 7553, 304, 5865],
#  [5664, 11274, 10482, 6914, 22342, 21031, 1044, 19480, 33526],
#  [28537, 29953, 12896, 6669, 443, 17268, 12687],
#  [28521,
#   29241,
#   13070,
#   22564,
#   17189,
#   15613,
#   19780,
#   13070,
#   29157,
#   7223,
#   30694,
#   16021,
#   29081],
#  [17268, 6669, 26820, 13398, 3456, 14536, 6691],
#  [12053, 2777, 14349, 24821, 13655, 25582, 6669, 26952, 33186, 33136],
#  [25324, 12951, 32227, 25758, 30423, 15430, 3],
#  [17758,
#   14715,
#   1899,
#   6669,
#   25812,
#   9370,
#   33509,
#   35801,
#   28780,
#   30669,
#   16278,
#   4710],
#  [3346, 6669, 25440, 21303, 26909, 3821, 9548, 13147, 27949, 10664],
#  [28863, 26736, 33807, 13398, 35724, 17731, 7223, 24496],
#  [23493,
#   6096,
#   28408,
#   32761,
#   19604,
#   31028,
#   13340,
#   7015,
#   8722,
#   318,
#   3234,
#   11129],
#  [34576,
#   13398,
#   19900,
#   17791,
#   1299,
#   13936,
#   8533,
#   4297,
#   30006,
#   5594,
#   30335,
#   5770],
#  [22397, 26842, 33774, 1019, 24227, 7084, 18418, 8285, 27624, 1231],
#  [19480, 10909, 13441, 20242, 27739, 27723, 32455],
#  [15657,
#   34901,
#   13733,
#   15584,
#   12169,
#   28662,
#   10349,
#   32526,
#   28745,
#   31028,
#   5764,
#   12323,
#   15327,
#   13451],
#  [3346, 27949, 15116, 28156, 16648, 32536, 16287],
#  [29731,
#   21305,
#   5030,
#   17069,
#   21759,
#   12323,
#   9660,
#   9969,
#   11084,
#   29731,
#   21305,
#   17069,
#   21759,
#   4973,
#   17487],
#  [318, 32757, 15613, 16497, 34128, 3404, 6574, 30299],
#  [29625, 21081, 18539, 10001, 15364, 25876, 19480, 27190],
#  [29528,
#   28415,
#   769,
#   29324,
#   308,
#   31148,
#   7167,
#   6669,
#   31148,
#   6669,
#   4304,
#   29528,
#   14017,
#   6367],
#  [31334,
#   31473,
#   2195,
#   5333,
#   20370,
#   3839,
#   28129,
#   9048,
#   6932,
#   4352,
#   31262,
#   34633],
#  [24450, 26067, 111, 24558, 24371],
#  [28630, 32461, 8901, 10909, 30763, 24738, 17230, 4878, 29315],
#  [19954, 3346, 28239, 14282, 28269, 6669],
#  [23882,
#   24935,
#   18606,
#   21525,
#   18606,
#   18745,
#   10437,
#   17204,
#   14014,
#   4320,
#   21730,
#   33203],
# ...
#  [28613,
#   23505,
#   21305,
#   8431,
#   9996,
#   14362,
#   33089,
#   28780,
#   8162,
#   27272,
#   19724,
#   6518,
#   35429,
#   6725],
#  [10542, 15116, 16501, 16029, 30337, 28780, 33850],
#  [33186, 33136, 22564, 31028, 6669, 14536],
#  [3556, 21251, 21251, 21251, 21251, 33612, 69],
#  [10849,
#   24635,
#   14441,
#   35253,
#   16084,
#   14282,
#   34830,
#   20242,
#   27739,
#   11577,
#   3346,
#   8503,
#   1702],
#  [34795, 6669],
#  [33987,
#   5385,
#   10437,
#   15464,
#   5770,
#   26404,
#   21210,
#   13766,
#   16380,
#   14604,
#   4483,
#   4956,
#   27094],
#  [3642, 21765, 19291, 7109, 7553, 25582, 14536, 29718, 35024, 9540],
#  [28780, 4785, 8901, 4785, 8901, 33134, 24338, 24012, 13655, 5764, 4785, 8901],
#  [11936, 13655, 21202, 30853, 31377],
#  [32929, 34481, 6669, 13655, 28442, 35423, 6167],
#  [12323, 19442, 27799, 899, 15613, 15838, 28780, 13398],
#  [24522,
#   9977,
#   9758,
#   15613,
#   27509,
#   20844,
#   17671,
#   17939,
#   21886,
#   7198,
#   19292,
#   12307,
#   24856,
#   6669],
#  [28473, 20925, 10671, 18358, 14662, 9548, 14798, 14905, 1917, 3888, 13410],
#  [13733, 7803, 24864, 16983, 16632, 1357, 14103],
#  [4142,
#   25131,
#   18745,
#   4142,
#   13526,
#   13655,
#   29157,
#   8901,
#   34201,
#   3578,
#   1149,
#   27578],
#  [12687,
#   6515,
#   4602,
#   11669,
#   19460,
#   4697,
#   25155,
#   26397,
#   34051,
#   13195,
#   22413,
#   24702,
#   22564],
#  [16591,
#   17069,
#   30559,
#   15365,
#   25233,
#   13398,
#   28316,
#   1804,
#   3153,
#   21759,
#   31028,
#   16591],
#  [12378, 7553, 304, 12378, 12378, 34744, 21662, 17842, 9641, 19480],
#  [20702, 28745, 33526, 10654, 1413, 3549, 14905],
#  [23950, 16034, 12217, 26461, 25905, 779, 14875, 10842, 35585],
#  [13084, 24838, 20971, 32574],
#  [34453, 13254, 26156, 14349, 4177, 22417, 14905, 3346, 32929, 20534],
#  [15364, 34208, 15029, 11855, 19736, 8077],
#  [14059, 13728, 7779, 13655, 6669, 12997, 4638, 31921, 35280, 708, 11617],
#  [15408, 7499, 10595, 14404, 17781, 22091, 26586, 33075, 27272, 23440, 12312],
#  [10643, 13398, 6669, 11278, 5882, 28970, 11148],
#  [28780, 25919, 30287, 6697, 35110, 26591, 11610, 32623, 35350, 17973, 13850],
#  [32795, 3549, 33, 2998, 13417, 12796, 17549, 6932, 25425],
#  [769, 19399, 1386, 8901, 12362],
#  [27273, 3346, 5867, 19159, 4739, 35574, 8365, 28408, 25664, 15033, 16395],
#  [9758,
#   15688,
#   33652,
#   31520,
#   33075,
#   19912,
#   27228,
#   9758,
#   19098,
#   11304,
#   17755,
#   26758,
#   24903,
#   6541,
#   3346],
#  [7496, 6307, 32303, 5101, 9991, 29836],
#  [27723, 11996, 15613, 30559, 601, 27273, 23439, 3582, 3533, 27315],
#  [26736, 29307, 12362, 16983, 7437],
#  [32929, 7223, 30559, 15613, 10476, 8077, 34452, 10141, 27273],
#  [4539,
#   28156,
#   20848,
#   10507,
#   11936,
#   12362,
#   29307,
#   26952,
#   20691,
#   26952,
#   11936,
#   15229,
#   20848,
#   5661],
#  [7516, 13195, 23328, 15364, 11123, 628],
#  [15365, 20457, 16700, 3734, 14802, 12767, 15600, 21886],
#  [21282, 29307, 13655, 6677, 6002, 17069, 28008, 7015, 14536, 28727],
#  [6669, 30968, 10278, 18203, 20242, 25850, 33089, 23311],
#  [30001,
#   33591,
#   33075,
#   13655,
#   2931,
#   30765,
#   3346,
#   34720,
#   7434,
#   6669,
#   20590,
#   3635,
#   21795],
#  [3346, 6469, 20848, 15834, 6528, 27578, 35999, 31132, 33037, 11847, 30028],
#  [18518, 5594, 5385, 8077, 1002, 3174, 15613, 3751, 8172, 27723],
#  [20925, 10671, 31148, 20932, 29157, 13410],
#  [14103, 28745, 10507, 13398, 15613, 30141, 30458],
#  [13917, 35009, 6669],
#  [19884, 22852, 19480, 14798, 16866, 33134, 18331, 25564],
#  [21765, 31067, 28156, 20848, 4352, 22932, 32702, 6669, 18203],
#  [17611, 14407, 21727, 22305, 21761, 28521, 399, 15810, 2312],
#  [26380,
#   15452,
#   17812,
#   11141,
#   8100,
#   11495,
#   7598,
#   31071,
#   899,
#   16599,
#   7774,
#   22388,
#   17878,
#   3362],
#  [22388, 22845, 7553, 16892, 16677, 29307, 29307, 16892, 20886],
#  [20534, 4473, 21000, 12932, 7284, 17464, 27457, 6691, 20242],
#  [1734, 11274, 21236, 15691, 28230, 19480, 19175, 2811, 22153, 3494],
#  [16756,
#   13655,
#   25824,
#   601,
#   29307,
#   23130,
#   34934,
#   10502,
#   3107,
#   33526,
#   27827,
#   3690,
#   25876,
#   7803],
#  [35056, 2633, 12929, 18548],
#  [28521,
#   22564,
#   11238,
#   28745,
#   9625,
#   208,
#   14892,
#   27949,
#   10664,
#   32929,
#   23311,
#   7329,
#   29307,
#   9977],
#  [8558, 26738, 12358, 24084, 23338, 22297, 24838, 23259, 14253, 18534, 10909],
#  [8722, 12217, 13655, 17615, 13655, 19533, 34770, 5449, 318, 28641],
#  [16873, 16866, 28780, 24370, 14233, 33292],
#  [28635, 34479, 14724, 17973, 31262, 27273, 30946, 22357, 28780],
#  [11445, 18518, 6220, 20986, 18059, 30299],
#  [24508,
#   16235,
#   34320,
#   19883,
#   15005,
#   2026,
#   14441,
#   7434,
#   2128,
#   18215,
#   12922,
#   30866,
#   19407],
#  [29735, 24860, 24044, 27273, 31702, 1671],
#  [15613, 12278, 15177, 22991, 8505, 21798, 25215, 8505, 19480],
#  [28721, 16905, 16685, 601, 24450, 601, 33119],
#  [18534,
#   10909,
#   24286,
#   21118,
#   17038,
#   18518,
#   27184,
#   909,
#   30383,
#   28613,
#   14913,
#   35999],
#  [30559, 35024, 29157, 11953, 13451, 969, 23959, 8852, 2572, 25876, 33134],
#  [9611, 7284, 5110, 21630, 14983, 18086, 5604],
#  [30559,
#   7167,
#   29139,
#   22845,
#   13678,
#   4511,
#   35265,
#   21347,
#   6669,
#   18018,
#   32396,
#   29616],
#  [17748, 21634, 19207, 24726, 16544, 35106, 12503, 33346, 22559, 28414, 17487],
#  [28605, 23152, 22527, 20242, 35736, 30848],
#  [28393,
#   31148,
#   21282,
#   4352,
#   15985,
#   8383,
#   3984,
#   6199,
#   8077,
#   6669,
#   5717,
#   17996,
#   19480],
#  [13678, 19905, 11359, 16330, 21856, 26275, 18534, 10909],
#  [22346,
#   18551,
#   26941,
#   5811,
#   15505,
#   30980,
#   13733,
#   27273,
#   30586,
#   27361,
#   7897,
#   4999,
#   6784,
#   24726,
#   14233],
#  [22346,
#   18551,
#   27190,
#   14491,
#   13170,
#   17841,
#   26941,
#   22346,
#   18551,
#   10269,
#   11727,
#   8174],
#  [11188,
#   20592,
#   22643,
#   14561,
#   30631,
#   27190,
#   27273,
#   28974,
#   11188,
#   1695,
#   20005,
#   21305],
#  [4539, 2584, 11361, 14905, 20005, 28985],
#  [15365, 17973, 21331, 5172, 15804, 25921, 18247, 899, 19220, 32336, 12687],
#  [15822, 9277, 24518, 17487, 13398, 27402],
#  [27317,
#   28721,
#   17069,
#   34294,
#   32553,
#   4199,
#   3831,
#   34294,
#   10909,
#   30765,
#   3346,
#   8901],
#  [9578,
#   35127,
#   9605,
#   27503,
#   9890,
#   30880,
#   33533,
#   27997,
#   2122,
#   13741,
#   19480,
#   17487],
#  [17878, 30559, 8722, 17369, 13655, 6669, 29237, 15981, 17685],
#  [13398, 23028, 8722, 7990, 21795, 26909, 19870, 8722, 24161, 17662, 14905],
#  [9316,
#   28263,
#   21043,
#   14975,
#   18216,
#   23313,
#   21871,
#   15955,
#   28136,
#   27228,
#   16024,
#   29167,
#   18659,
#   27272,
#   8921],
#  [16591, 20521, 35761, 12687, 16685, 8077, 10849, 3746, 14233, 14905],
#  [30763,
#   4500,
#   27377,
#   10909,
#   12973,
#   15365,
#   27141,
#   34257,
#   31262,
#   17329,
#   26952,
#   29186],
#  [2777, 28544, 17517, 13451, 6769, 6907, 26336, 6907, 27949, 10664, 20350],
#  [31148, 26586, 1245, 2866, 19954, 4197],
#  [6669,
#   12889,
#   22809,
#   13655,
#   28745,
#   7299,
#   12889,
#   8248,
#   22809,
#   13655,
#   18518,
#   13132,
#   31771,
#   4575],
#  [24661,
#   4007,
#   14245,
#   7146,
#   5311,
#   15985,
#   23346,
#   28008,
#   34633,
#   8064,
#   5648,
#   837,
#   8230,
#   20886],
#  [25676, 7705, 21881, 22338, 18534, 8901, 4146, 34146],
#  [28590, 27624, 26188, 7499, 20507, 6008, 4225, 29136],
#  [35650, 34552, 11495, 12486, 33118, 20242, 16316],
#  [24505,
#   24505,
#   27478,
#   708,
#   25190,
#   6412,
#   19098,
#   19638,
#   10488,
#   27094,
#   24505,
#   25564,
#   5838],
#  [28963, 16396, 769, 29324, 308, 12889, 769, 29324, 13655, 19480, 11197],
#  [7015, 14491, 2770, 3984, 34268],
#  [29307, 35541, 30559, 18567, 18328, 18234, 35082, 8722, 34479, 33526],
#  [11376, 10507, 7223, 35779, 2083, 32631, 4342, 1734, 11274, 28163, 13945],
#  [12486, 10664, 17396, 16218, 29157, 6669, 34294, 26380, 29666],
#  [28745, 13415, 16986, 12352, 28745, 23990, 6669],
#  [9394, 12884, 20886, 21760, 15811, 35799, 18234, 9611, 7284, 1886],
#  [23963, 19210, 22342, 9746, 6519, 14905],
#  [17771, 897, 12047, 9996, 13678, 15822, 31829, 15116, 12687, 4734],
#  [4988,
#   2187,
#   15873,
#   29455,
#   27624,
#   30559,
#   22060,
#   5546,
#   32303,
#   2719,
#   35026,
#   35026,
#   31921,
#   936,
#   21861,
#   20848,
#   9792],
#  [13398, 14488, 26038, 26836],
#  [13034, 32360, 23327, 33658, 11376, 15365, 30383, 26700],
#  [13398,
#   9977,
#   19407,
#   34479,
#   20242,
#   22346,
#   18551,
#   2584,
#   27228,
#   29307,
#   15137,
#   11665,
#   3195],
#  [31248, 27402, 14674, 34774, 5811, 16318, 19626, 26175, 24951],
#  [34974,
#   25241,
#   33934,
#   899,
#   25454,
#   18324,
#   7734,
#   23311,
#   15865,
#   13016,
#   28745,
#   27094,
#   14897],
#  [33987, 33605, 19332, 11849, 14667, 190, 13409, 4373, 432, 24430, 26435],
#  [23327, 6212, 20848, 11577, 3021, 4648, 28509],
#  [3346,
#   35656,
#   34346,
#   31493,
#   14672,
#   8457,
#   21282,
#   3346,
#   35656,
#   11577,
#   15862,
#   6655],
#  [4999, 6169, 26105, 16357, 18234],
#  [32804,
#   19104,
#   7690,
#   11215,
#   29139,
#   11724,
#   35286,
#   32612,
#   26855,
#   22514,
#   13602,
#   16640,
#   8959],
#  [7167, 13655, 13415, 6669, 33987, 6933, 35146],
#  [14638, 26903, 11432, 814, 52, 6254, 12932, 7284, 24726, 28721, 3231],
#  [34481, 2058, 14491, 14690, 28268, 24838, 992, 30013, 20242, 35036],
#  [13657, 34997, 23982, 6669, 5594],
#  [30559, 15408, 26909, 26952, 1755, 31470, 27827, 16591, 17320, 190],
#  [6669, 13655, 29011],
#  [3174, 12524, 4575, 29250, 9076, 6669, 20242, 1671],
#  [29731,
#   31700,
#   11319,
#   24769,
#   28863,
#   18137,
#   13898,
#   30198,
#   21730,
#   18137,
#   13898,
#   1963,
#   26275,
#   19480,
#   10909,
#   29731,
#   2081],
#  [33194, 25676, 7705, 23282, 27087, 25582, 2752, 16910, 23311, 13770],
#  [15613, 15541, 5882, 18548, 26794],
#  [4146,
#   22395,
#   601,
#   376,
#   19129,
#   18770,
#   33087,
#   23803,
#   35132,
#   7386,
#   4409,
#   26952,
#   16005,
#   4602,
#   2707],
#  [25847, 16631, 12863, 14805, 20597, 31477],
#  [13936,
#   8533,
#   4297,
#   11376,
#   29923,
#   18262,
#   33330,
#   14499,
#   13415,
#   35155,
#   31771,
#   14103],
#  [23882, 24935, 13429, 780, 28745, 11175, 30191, 20463],
#  [20242, 4126, 23311, 15363, 10124, 4575, 24860, 12524, 12687, 23578, 10255],
#  [6669,
#   10909,
#   14062,
#   24726,
#   4785,
#   24860,
#   2995,
#   17791,
#   20242,
#   25608,
#   24860,
#   29732,
#   35272,
#   20242,
#   3414],
#  [11750,
#   15869,
#   24012,
#   22054,
#   1138,
#   28829,
#   10615,
#   3209,
#   30976,
#   21252,
#   22725,
#   18373],
#  [23269, 22438, 9758, 29278, 32832, 18015],
#  [34205,
#   22974,
#   20848,
#   11123,
#   13323,
#   26952,
#   34014,
#   15005,
#   16605,
#   421,
#   32825,
#   22746,
#   14572,
#   23380],
#  [1192, 32455, 30848, 742, 35898, 6669, 10909],
#  [29397, 27273, 19884, 21614, 29246],
#  [29751, 4085, 14282, 19480, 25919, 12150],
#  [11432, 34479, 15613, 4095, 4575, 24860, 106, 35154, 35851, 11891, 22233],
#  [18534, 10909, 13398, 23472, 29608, 10437, 24046, 10849, 17217, 25876, 11432],
#  [12217, 23320, 27718, 2201, 8986, 2727, 33136, 11936, 14900, 23965],
#  [28521, 34566, 32716, 464, 22564, 7553, 28582],
#  [12997, 23086, 17959, 32326, 7085, 13655, 13655, 12997, 31028, 28378, 20460],
#  [8909, 25758, 25656, 19480, 33319, 30853, 13655, 26952, 4648, 7087],
#  [17664, 28469, 8230, 25528, 10411, 28069, 3967],
#  [33186, 18281, 5565, 14798, 10909, 23453, 12868, 4638, 33282],
#  [14488,
#   12687,
#   19797,
#   21282,
#   10304,
#   35286,
#   21282,
#   13195,
#   4648,
#   12908,
#   28613,
#   1938],
#  [6669, 6677, 22830, 13733, 9710, 899, 10570, 7407, 23380, 16898, 22687],
#  [34869, 24860, 19727, 29678, 35274],
#  [4648, 21202, 2789, 30234, 25656],
#  [742, 35898, 8077, 1055, 779, 6669],
#  [15657, 11575, 10664, 23882, 24935],
#  [34597,
#   35691,
#   32326,
#   7085,
#   17069,
#   14081,
#   7015,
#   25389,
#   5043,
#   20913,
#   24227,
#   25092,
#   21244,
#   9611,
#   17517,
#   8722],
#  [34481, 20005, 899, 12292, 9110, 12687, 7111, 34731, 20005, 24838, 27735],
#  [33987,
#   9343,
#   20888,
#   30887,
#   14491,
#   22151,
#   19702,
#   7244,
#   14905,
#   5245,
#   20869,
#   28143],
#  [20242,
#   13796,
#   17870,
#   9648,
#   13104,
#   17765,
#   27774,
#   18552,
#   11298,
#   21000,
#   28745,
#   12411],
#  [16591, 15981, 29528, 24084, 12361, 12486, 35574, 2546],
#  [14905,
#   20574,
#   25032,
#   19110,
#   13429,
#   14905,
#   32574,
#   25032,
#   19110,
#   20648,
#   21282,
#   26952,
#   6669,
#   12789,
#   12789],
#  [3813, 18518, 13254, 8840, 14103, 3346, 14233, 31148, 15541, 14491],
#  [9602, 12486, 13665, 23118, 4739, 32304, 15922],
#  [25876, 30586, 8532, 19884, 19637, 35761, 16, 18328, 5321, 14798, 28974],
#  [32837, 24888, 26052, 33135, 3456, 12997, 28780, 25677],
#  [14761, 3597, 4003, 24406, 30212, 12217, 23472, 33509, 34478, 16761, 21282],
#  [23963, 19210, 13906, 6669],
#  [28780, 14491, 28745, 17268, 32502, 33763, 18018],
#  [5594, 26952, 9777, 35288, 11205, 26327, 29893],
#  [28805, 2770, 6669],
#  [30385, 12217, 10116, 12061, 28856, 16177, 12217, 14905, 18534, 10116, 10762],
#  [197, 11647, 4197, 165, 13733, 11610, 26096, 18417],
#  [6558, 24376, 622, 6558, 26765, 16866, 15568, 20068],
#  [30458, 33094, 17424, 15099, 2719, 27228],
#  [26052, 4013, 23269, 14798, 13234, 3346, 6469, 13741, 8488],
#  [29307,
#   19809,
#   18518,
#   11775,
#   22952,
#   32716,
#   22845,
#   22845,
#   12997,
#   22952,
#   32716,
#   11775],
#  [17828, 3241, 8036, 28545, 4545, 12486, 4648, 28545, 7779, 13655, 540],
#  [19248, 32984, 27624, 35082, 21623, 26295, 13062, 28780, 19609, 35165, 27301],
#  [13451, 15613, 13254, 24450, 1769, 8077, 2237, 4508, 5404, 27301, 259, 1357],
#  [32461, 26380, 15613, 10323, 14538, 8232, 1687, 21950, 33262],
#  [5627, 25919],
#  [28613, 17370, 14670, 3346, 28393, 23069, 5215, 30182, 13030, 7015],
#  [26599, 4925, 21108, 6669, 21282, 29307, 13655, 27867],
#  [34301, 31270, 10636, 21114, 26514, 28745, 29701, 8161, 9792, 32238, 1190],
#  [4785, 8901, 28521, 18967, 23472, 30763],
#  [3284, 32199, 24406],
#  [35679, 25552, 8557, 2183, 9809, 17975, 3284, 28509, 4648, 8901],
#  [31148, 15613, 13254, 8840, 13655, 13657, 24101, 5349],
#  [26281,
#   12934,
#   14233,
#   9255,
#   26765,
#   31881,
#   15751,
#   11432,
#   4604,
#   6669,
#   35082,
#   13655,
#   33488],
#  [10507, 14282, 13449, 34837, 33900, 30141, 30458, 8664, 22438],
#  [19340, 13255, 33516, 15865, 23311, 4352, 18661, 21098],
#  [26070, 30948, 29803, 35494, 20380, 4739, 20702, 27402, 22018],
#  [25542, 32984, 31262, 30383, 23480, 5770, 23687],
#  [30743,
#   14230,
#   7244,
#   12843,
#   13132,
#   11175,
#   23453,
#   14233,
#   6199,
#   7109,
#   17220,
#   26836],
#  [18390,
#   29687,
#   8638,
#   32574,
#   35346,
#   21909,
#   859,
#   30234,
#   25656,
#   26952,
#   17069,
#   22991,
#   16536],
#  [31028, 27273, 16632, 4444, 15632, 4146, 376, 24898, 30458, 31829, 31262],
#  [6669, 23405, 26052, 5311, 8830, 14083, 14083, 24289, 5311, 22991, 473],
#  [11129, 899, 23578, 2777, 28544, 18137, 13898],
#  [20854,
#   21761,
#   28415,
#   27921,
#   32502,
#   24406,
#   11002,
#   3339,
#   34025,
#   29307,
#   8901,
#   3436,
#   18687],
#  [19270,
#   4689,
#   19626,
#   32039,
#   13874,
#   11575,
#   32039,
#   28630,
#   27590,
#   33330,
#   27827,
#   3967,
#   26052,
#   5311,
#   25808,
#   20164],
#  [106, 8077, 28877, 20921, 35423, 2596, 6669],
#  [15613,
#   14905,
#   20380,
#   33001,
#   1769,
#   29307,
#   22008,
#   8132,
#   20632,
#   6169,
#   15613,
#   14572,
#   34515],
#  [31148, 15613, 1357, 5094, 22071, 899, 12362],
#  [26052, 4284, 7385, 31686, 3653, 20702, 12213, 23086, 15613, 31028, 31496],
#  [35082,
#   20648,
#   35288,
#   17973,
#   31262,
#   35082,
#   21282,
#   13655,
#   6669,
#   13195,
#   23990,
#   6960,
#   16893],
#  [21783, 33186, 33136, 22564, 19083, 28008, 6669, 33509, 26380, 8722, 21308],
#  [24354, 23472, 5439, 34205, 28509, 31071, 32929, 13655, 28509, 28881],
#  [23488,
#   6169,
#   23990,
#   35012,
#   23480,
#   18216,
#   16599,
#   9751,
#   34612,
#   19884,
#   19025,
#   34447,
#   35026,
#   5673],
#  [26096, 6669, 8901, 23990, 20642, 21760, 14905],
#  [32368, 19480, 708, 28662, 28136, 11594, 28208, 31476, 8125, 34035],
#  [26052, 33135, 16654, 31312, 15074, 708, 20242, 12744, 23453, 19480],
#  [10507,
#   10909,
#   20848,
#   13741,
#   2081,
#   165,
#   16290,
#   4999,
#   35168,
#   10909,
#   15541,
#   29307,
#   29161,
#   29386,
#   18234],
#  [5272, 32192, 9548, 6592, 1357, 12362],
#  [30559, 2931, 21282, 29011, 13655, 31771, 6169, 28780],
#  [15972, 32771, 12467, 4835, 32929, 15962, 17724, 25503, 28745, 13619, 6521],
#  [12378, 34744, 21662, 26380, 9641, 19480, 30673, 28863],
#  [35082, 14798, 28745, 31028, 6097, 31028],
#  [9758, 33853, 24903, 27790, 23047, 24878, 30590, 26000, 29161, 6541, 10242],
#  [15613, 26736],
#  [10472, 4161, 6592, 25582, 12295],
#  [2777, 17320, 2542, 9810],
#  [5222, 8412, 6669, 33577, 961, 17501, 23259, 6960, 3456, 20242, 12362],
#  [16544, 4545, 12973, 4958, 11376, 5964, 33671, 12486, 20702],
#  [10909, 17289, 8901, 14667, 29307, 24367, 165],
#  [32771, 12467, 28745, 32771, 13678, 22357, 11415, 21305, 11674],
#  [31877, 23311, 31715, 27846, 27056, 27624, 26188, 25892, 28764],
#  ...]

# %%
# Example
tweets[0]
# Out:
# 'arirang simply kpop kim hyung jun cross ha yeong playback'

# %%
# Onehot representation of tweets[0]
onehot_repr[0]
# Out:
# [34022, 13415, 25650, 2777, 17095, 15230, 30631, 17220, 6963, 3518]

# %%
# Next, we need to make our sentences to be of the same length
# To do this, we need to know the sentence with the most words in it
from nltk import word_tokenize
max_len = 0
for i in range(len(tweets)):
    word_tokens = word_tokenize(tweets[i])
    length = len(word_tokens)
    if length > max_len:
        max_len = length
max_len
# Out:
# 27

# %%
import numpy as np
# It's good to know the average number of tokens per tweet
# So we can have an idea what a good window size is for our tweets
from nltk import word_tokenize
tweets_length = []
for i in range(len(tweets)):
    word_tokens = word_tokenize(tweets[i])
    length = len(word_tokens)
    tweets_length.append(length)
tweets_ave = np.mean(np.array(tweets_length))
tweets_ave
# Out:
# 9.503210870659286

# %%
# We can use pad_sequences, and it will add zeros to each sentence with less than 27 words
# We can choose if it will be added at the beginning or at the end
# using the `padding` parameter which takes `pre` or `post`
padded_tweets = pad_sequences(onehot_repr, padding='pre',maxlen=max_len)
padded_tweets
# Out:
# array([[    0,     0,     0, ..., 17220,  6963,  3518],
#        [    0,     0,     0, ..., 21087, 33330, 24450],
#        [    0,     0,     0, ...,   867,  1354, 32762],
#        ...,
#        [    0,     0,     0, ...,  3339,  6669, 22932],
#        [    0,     0,     0, ..., 34137, 25977, 30586],
#        [    0,     0,     0, ...,  3883, 27273, 11962]])

# %% [markdown]
# Keras offers an **Embedding** layer that can be used for neural networks on text data.
#
# It requires that the input data be **integer encoded**, so that each word is represented by a unique integer.
#
# The Embedding layer is initialized with random weights and will learn an embedding for all of the words in the training dataset.
#
# It is a flexible layer that can be used in a variety of ways, such as:
#
# * It can be used alone to learn a word embedding that can be saved and used in another model later.
# * It can be used as part of a deep learning model where the embedding is learned along with the model itself.
# * It can be used to load a pre-trained word embedding model, a type of transfer learning.
#
# The Embedding layer is defined as the first hidden layer of a network. It must specify 3 arguments:
#
# 1. **input_dim**: This is the size of the vocabulary in the text data. For example, if your data is integer encoded to values between 0-10, then the size of the vocabulary would be 11 words.
# 2. **output_dim**: This is the size of the vector space in which words will be embedded. It defines the size of the output vectors from this layer for each word. For example, it could be 32 or 100 or even larger. Test different values for your problem.
# 3. **input_length**: This is the length of input sequences, as you would define for any input layer of a Keras model. For example, if all of your input documents are comprised of 1000 words, this would be 1000.

# %%
# How many features do we want to describe each word?
# We can set this using `dim`, we can experiment with this

# We just need the output of the embedding layer, because it contains the weights that we want
# We need to flatten it, because each word will has its own vector which will create a 2d-matrix for each tweet
# We just need a 1-dimensional representation for each tweet
dim = 10
keras_model = Sequential()
keras_model.add(Embedding(vocab_size, dim, input_length=max_len))
keras_model.add(Flatten())
keras_model.compile('rmsprop',loss="categorical_crossentropy", metrics=['accuracy'])
keras_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 27, 10)            360000
#
#  flatten (Flatten)           (None, 270)               0
#
# =================================================================
# Total params: 360,000
# Trainable params: 360,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras_model_tweets = keras_model.predict(padded_tweets)
keras_model_tweets
# Out:
# 1553/1553 [==============================] - 2s 816us/step
# array([[ 0.02011312, -0.00384263, -0.03569106, ...,  0.02549319,
#          0.03361343, -0.00767218],
#        [ 0.02011312, -0.00384263, -0.03569106, ...,  0.0429675 ,
#          0.03223759, -0.04315708],
#        [ 0.02011312, -0.00384263, -0.03569106, ..., -0.0283402 ,
#         -0.02560207, -0.009534  ],
#        ...,
#        [ 0.02011312, -0.00384263, -0.03569106, ..., -0.01660419,
#         -0.03300374,  0.00409142],
#        [ 0.02011312, -0.00384263, -0.03569106, ...,  0.03942401,
#         -0.04004568, -0.00603427],
#        [ 0.02011312, -0.00384263, -0.03569106, ...,  0.0034272 ,
#         -0.02500931,  0.04393745]], dtype=float32)

# %%
keras_model_tweets.shape
# Out:
# (49675, 270)

# %%
import joblib
# Save the keras model to disk
keras_model_file = 'vectors/keras_model.sav'
joblib.dump(keras_model, keras_model_file)
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\embedding
# ......vars
# .........0
# ...layers\flatten
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-01-20 18:35:09         1083
# metadata.json                                  2023-01-20 18:35:09           64
# variables.h5                                   2023-01-20 18:35:09      1450288
# ['vectors/keras_model.sav']

# %%
import joblib
# Save the tfidvectorizer to disk
keras_model_tweets_file = 'vectors/keras_model_tweets.sav'
joblib.dump(keras_model_tweets, keras_model_tweets_file)
# Out:
# ['vectors/keras_model_tweets.sav']

# %% [markdown]
# **c.2. Word2Vec**
#
# Word2Vec is the combination of two techniques:
# a. Continuous Bag of Words
# b. Skipgram
#
# Both of these are shallow neural networks (1 hidden layer) which learn the weights, which then act as word vector representations when multiplied to the onehot-encoded versions of the target vocabulary.
#
# Predicting a target word (CBOW), and predicting the context/surrounding words given a word (Skipgram) are just **"fake problems"** we are trying to solve. What we are interested in is the **side effect**, which is the **word embedding vector**, or the weights generated by the neural network in solving that fake problems.
#
# Word2Vec is not a true *unsupervised learning* technique (since there is some sort of error backpropagation taking place through correct and incorrect predictions), they are a **self-supervised technique**, a specific instance of *supervised learning* where the targets are generated from the input data. In order to get self-supervised models to learn interesting features, you have to come up with an interesting synthetic target and loss function.

# %% [markdown]
# *Self-supervised* methods rely heavily on the **The Distributional Hypothesis** derived from the *semantic theory*, and the basis for **statistical semantics**. The hypothesis states that:
#
#     - Words that are used and occur in the same contexts tend to convey similar meanings.

# %% [markdown]
# The crux of a self-supervised model is that word representations learned while learning to predict the context of a word from the word itself (or vice versa) represent a vector space capturing **deep semantic and syntactic concepts and phenomena.** Meaning, learning from the context of a word can teach us about both its meaning and its syntactic role.

# %%
# import image module
from IPython.display import Image

# get the image
Image(url="pictures/word2vec-1.png", width=700, height=700)
# Out:
# <img src="pictures/word2vec-1.png" width="700" height="700"/>

# %%
# import image module
from IPython.display import Image

# get the image
Image(url="pictures/word2vec-2.png", width=700, height=500)
# Out:
# <img src="pictures/word2vec-2.png" width="700" height="500"/>

# %%
# import image module
from IPython.display import Image

# get the image
Image(url="pictures/word2vec-3.png", width=700, height=550)
# Out:
# <img src="pictures/word2vec-3.png" width="700" height="550"/>

# %% [markdown]
# With CBOW, the word embedding is **between the hidden layer and the output layer**, while with Skipgram, the word embedding is **between the input layer and the hidden layer**.

# %%
import gensim
### Lets train Word2vec from scratch
# min_count ignores all words with frequency less than min_count
# window size is determined by `window`
# the number of dimensions for each word vector is given by `vector_size`
vector_size = 10
window = 9
w2v_model=gensim.models.Word2Vec(words,window=window,vector_size=vector_size, min_count=1)
word2vec_model_file = './vectors/' +'word2vec_' + str(window) + str(vector_size) + '.model'
w2v_model.save(word2vec_model_file)

# %%
# All word vectors need to be averaged with respect to each sentences
# We should be getting the final vector for each sentence
import numpy as np
def avg_word2vec(doc):
    # remove out-of-vocabulary words
    #sent = [word for word in doc if word in model.wv.index_to_key]
    #print(sent)
    
    return np.mean([w2v_model.wv[word] for word in doc if word in w2v_model.wv.index_to_key],axis=0)

# %%
from tqdm import tqdm

#apply for the entire sentences
X=[]
for i in tqdm(range(len(words))):
    X.append(avg_word2vec(words[i]))
# Out:
# 100%|██████████| 49675/49675 [00:36<00:00, 1344.51it/s]

# %%
word2vec_tweets=np.array(X)
word2vec_tweets
# Out:
# array([[ 0.43820262, -0.4754556 ,  0.11711419, ...,  0.8534837 ,
#         -1.470024  , -0.72018313],
#        [ 0.8019137 , -1.0742214 ,  0.6273    , ...,  0.96964335,
#         -2.5701778 , -1.698925  ],
#        [ 0.7749731 , -0.4721202 ,  0.4301789 , ...,  1.0060902 ,
#         -1.4998134 , -0.62398565],
#        ...,
#        [ 1.2551143 , -0.6130551 ,  0.83693   , ...,  1.9660778 ,
#         -1.5066313 , -1.1546358 ],
#        [ 1.0965337 , -0.71529126,  0.89206046, ...,  1.8730817 ,
#         -1.32547   , -0.6296154 ],
#        [ 0.16459951, -0.8970738 ,  0.19940762, ...,  2.136376  ,
#         -0.63419354,  0.01595367]], dtype=float32)

# %%
word2vec_tweets.shape
# Out:
# (49675, 10)

# %%
import joblib
# Save the tfidvectorizer to disk
word2vec_tweets_file = 'vectors/word2vec_tweets.sav'
joblib.dump(word2vec_tweets, word2vec_tweets_file)
# Out:
# ['vectors/word2vec_tweets.sav']

# %% [markdown]
# **c.3. fastText**

# %% [markdown]
# FastText splits out words using n-gram characters. Contrary to other popular models that learn word representations by assigning a distinct vector to each word, FastText is based on the skipgram model, where each word is represented as a bag of character n-grams. A vector representation is associated to each character n-gram; words being represented as the sum of these representations.
#
# This approach is a significant improvement over word2vec and GloVe for two reasons:
#
# * The ability to infer **out-of-vocabulary** words. Example, ‘England’ is related to ‘Netherlands’ because of land present in both as ‘lan’ and ‘and’.
#
# * The robustness to spelling mistakes and typos.
#
# Word2Vec is trained using **words**. while;
#
# fastText is trained using **character n-gram**. Example: *capable n_gram=3* ==> *cap*, *apa*, *pab*, *abl*, *ble*
#
# fastText is also often the **first choice** when you want to train **custom word embeddings** for your *domain*.
#
# fastText is a **technique** similar to word2vec as well as a **library**. It is also lightweight and faster than others, but with performance metrics comparable to fancy models.

# %%
from gensim.models import FastText
window = 9
vector_size = 10
ft_model = FastText(window=window, min_count=2, sentences=words, vector_size=vector_size)
ft_model_file = './vectors/' +'fasttext_' + str(window) + str(vector_size) + '.model'
ft_model.save(ft_model_file)

# %%
# All word vectors need to be averaged with respect to each sentences
# We should be getting the final vector for each sentence
import numpy as np
def avg_fasttext(doc):
    # remove out-of-vocabulary words
    #sent = [word for word in doc if word in model.wv.index_to_key]
    #print(sent)
    
    return np.mean([ft_model.wv[word] for word in doc],axis=0)

# %%
from tqdm import tqdm

#apply for the entire sentences
X_fast=[]
for i in tqdm(range(len(words))):
    X_fast.append(avg_fasttext(words[i]))
# Out:
# 100%|██████████| 49675/49675 [00:02<00:00, 21143.10it/s]

# %%
ft_tweets = np.array(X_fast)
ft_tweets
# Out:
# array([[ 1.7083393 ,  0.16257861, -0.3256186 , ...,  1.6048752 ,
#         -0.6958239 , -0.861176  ],
#        [ 1.4671383 ,  0.27155647, -2.1007617 , ...,  2.8497617 ,
#         -0.8527399 , -0.83536667],
#        [ 1.7470719 ,  0.10171478, -0.4181965 , ...,  1.5183479 ,
#         -0.21019751, -0.65540004],
#        ...,
#        [ 1.5684685 , -0.18233915, -0.61222434, ...,  1.6030623 ,
#         -1.0378721 , -1.6156934 ],
#        [ 1.7817134 ,  0.7445152 , -0.77702844, ...,  2.0351388 ,
#         -0.6231385 , -1.0140816 ],
#        [ 1.2703185 ,  1.3933463 , -0.4189272 , ...,  2.0525815 ,
#         -0.8890051 , -1.0568657 ]], dtype=float32)

# %%
ft_tweets.shape
# Out:
# (49675, 10)

# %%
import joblib
# Save the tfidvectorizer to disk
ft_tweets_file = 'vectors/fasttext_tweets.sav'
joblib.dump(ft_tweets,ft_tweets_file)
# Out:
# ['vectors/fasttext_tweets.sav']

# %% [markdown]
# #### **End. Thank you!**
